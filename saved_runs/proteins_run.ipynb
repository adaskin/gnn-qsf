# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'PROTEINS',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [32,64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'PROTEINS', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([901, 4096])
# train_phases shape: torch.Size([901, 12, 12])
# train_labs shape: torch.Size([901])
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# [PROTEINS] Epoch 001 | Train Loss 0.6028 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5722 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5459 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 3]
# [PROTEINS] Epoch 004 | Train Loss 0.5457 | Val Acc 0.7900 | LR 1.0e-02 [Best Val Acc: 0.7900 @ Epoch 4]
# [PROTEINS] Epoch 005 | Train Loss 0.5350 | Val Acc 0.8000 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 006 | Train Loss 0.5217 | Val Acc 0.7700 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 007 | Train Loss 0.5222 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 008 | Train Loss 0.4962 | Val Acc 0.5400 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 009 | Train Loss 0.4706 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 010 | Train Loss 0.4919 | Val Acc 0.6600 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 011 | Train Loss 0.4764 | Val Acc 0.6500 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 012 | Train Loss 0.5229 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 013 | Train Loss 0.4636 | Val Acc 0.7600 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 014 | Train Loss 0.4493 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 015 | Train Loss 0.4428 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 016 | Train Loss 0.4360 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 017 | Train Loss 0.4561 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 018 | Train Loss 0.4351 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# [PROTEINS] Epoch 019 | Train Loss 0.4577 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 5]
# Early stop @ epoch 20 | Best val_acc=0.8000
# [PROTEINS] Fold Test Acc: 0.6339
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([901, 4096])
# train_phases shape: torch.Size([901, 12, 12])
# train_labs shape: torch.Size([901])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6095 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5839 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5652 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 004 | Train Loss 0.5384 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 005 | Train Loss 0.5411 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 006 | Train Loss 0.4938 | Val Acc 0.5100 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 007 | Train Loss 0.5174 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 008 | Train Loss 0.4898 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 009 | Train Loss 0.4944 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 010 | Train Loss 0.5118 | Val Acc 0.6500 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 011 | Train Loss 0.4631 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 012 | Train Loss 0.4604 | Val Acc 0.5600 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 013 | Train Loss 0.4636 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 014 | Train Loss 0.4723 | Val Acc 0.5600 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 015 | Train Loss 0.4717 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 016 | Train Loss 0.4698 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# Early stop @ epoch 17 | Best val_acc=0.7300
# [PROTEINS] Fold Test Acc: 0.6607
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([901, 4096])
# train_phases shape: torch.Size([901, 12, 12])
# train_labs shape: torch.Size([901])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6037 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5792 | Val Acc 0.7600 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5585 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 004 | Train Loss 0.5514 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 005 | Train Loss 0.5491 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 006 | Train Loss 0.5351 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 007 | Train Loss 0.5331 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 008 | Train Loss 0.5186 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 009 | Train Loss 0.5263 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 010 | Train Loss 0.5068 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 011 | Train Loss 0.4899 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 012 | Train Loss 0.4897 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 013 | Train Loss 0.4632 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 014 | Train Loss 0.4724 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 015 | Train Loss 0.4872 | Val Acc 0.5700 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# [PROTEINS] Epoch 016 | Train Loss 0.4684 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 2]
# Early stop @ epoch 17 | Best val_acc=0.7600
# [PROTEINS] Fold Test Acc: 0.7143
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6111 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5740 | Val Acc 0.6600 | LR 1.0e-02 [Best Val Acc: 0.6600 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5592 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.6800 @ Epoch 3]
# [PROTEINS] Epoch 004 | Train Loss 0.5411 | Val Acc 0.5900 | LR 1.0e-02 [Best Val Acc: 0.6800 @ Epoch 3]
# [PROTEINS] Epoch 005 | Train Loss 0.5370 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.6800 @ Epoch 3]
# [PROTEINS] Epoch 006 | Train Loss 0.5426 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 007 | Train Loss 0.5116 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 008 | Train Loss 0.5077 | Val Acc 0.5600 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 009 | Train Loss 0.4961 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 010 | Train Loss 0.4997 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 011 | Train Loss 0.4926 | Val Acc 0.5900 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 012 | Train Loss 0.4883 | Val Acc 0.5700 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 013 | Train Loss 0.4955 | Val Acc 0.5400 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 014 | Train Loss 0.4858 | Val Acc 0.5600 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 015 | Train Loss 0.4832 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 016 | Train Loss 0.4634 | Val Acc 0.5500 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 017 | Train Loss 0.4818 | Val Acc 0.5300 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 018 | Train Loss 0.4560 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 019 | Train Loss 0.4603 | Val Acc 0.5700 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# [PROTEINS] Epoch 020 | Train Loss 0.4644 | Val Acc 0.5400 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 6]
# Early stop @ epoch 21 | Best val_acc=0.7000
# [PROTEINS] Fold Test Acc: 0.6396
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6100 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5680 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.6800 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5661 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 004 | Train Loss 0.5427 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [PROTEINS] Epoch 005 | Train Loss 0.5357 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 5]
# [PROTEINS] Epoch 006 | Train Loss 0.5307 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 5]
# [PROTEINS] Epoch 007 | Train Loss 0.5228 | Val Acc 0.4500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 5]
# [PROTEINS] Epoch 008 | Train Loss 0.5189 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 5]
# [PROTEINS] Epoch 009 | Train Loss 0.5071 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 5]
# [PROTEINS] Epoch 010 | Train Loss 0.5044 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 5]
# [PROTEINS] Epoch 011 | Train Loss 0.4944 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 11]
# [PROTEINS] Epoch 012 | Train Loss 0.4907 | Val Acc 0.5900 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 11]
# [PROTEINS] Epoch 013 | Train Loss 0.4757 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 11]
# [PROTEINS] Epoch 014 | Train Loss 0.4797 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 11]
# [PROTEINS] Epoch 015 | Train Loss 0.4765 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 11]
# [PROTEINS] Epoch 016 | Train Loss 0.4737 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 11]
# [PROTEINS] Epoch 017 | Train Loss 0.4542 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 17]
# [PROTEINS] Epoch 018 | Train Loss 0.4601 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 17]
# [PROTEINS] Epoch 019 | Train Loss 0.4533 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 17]
# [PROTEINS] Epoch 020 | Train Loss 0.4350 | Val Acc 0.6900 | LR 1.0e-03 [Best Val Acc: 0.7500 @ Epoch 17]
# [PROTEINS] Epoch 021 | Train Loss 0.4022 | Val Acc 0.7600 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 21]
# [PROTEINS] Epoch 022 | Train Loss 0.3856 | Val Acc 0.7600 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 023 | Train Loss 0.3704 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 024 | Train Loss 0.3673 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 025 | Train Loss 0.3630 | Val Acc 0.7400 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 026 | Train Loss 0.3698 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 027 | Train Loss 0.3679 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 028 | Train Loss 0.3643 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 029 | Train Loss 0.3374 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 030 | Train Loss 0.3508 | Val Acc 0.7400 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 031 | Train Loss 0.3454 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 032 | Train Loss 0.3235 | Val Acc 0.7400 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 033 | Train Loss 0.3405 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 034 | Train Loss 0.3316 | Val Acc 0.7100 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 035 | Train Loss 0.3294 | Val Acc 0.7100 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# [PROTEINS] Epoch 036 | Train Loss 0.3216 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7600 @ Epoch 22]
# Early stop @ epoch 37 | Best val_acc=0.7600
# [PROTEINS] Fold Test Acc: 0.6937
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6196 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5793 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.6300 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5648 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.6400 @ Epoch 3]
# [PROTEINS] Epoch 004 | Train Loss 0.5330 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.6400 @ Epoch 3]
# [PROTEINS] Epoch 005 | Train Loss 0.5318 | Val Acc 0.6200 | LR 1.0e-02 [Best Val Acc: 0.6400 @ Epoch 3]
# [PROTEINS] Epoch 006 | Train Loss 0.5341 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.6400 @ Epoch 3]
# [PROTEINS] Epoch 007 | Train Loss 0.5291 | Val Acc 0.6200 | LR 1.0e-02 [Best Val Acc: 0.6400 @ Epoch 3]
# [PROTEINS] Epoch 008 | Train Loss 0.5110 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6400 @ Epoch 3]
# [PROTEINS] Epoch 009 | Train Loss 0.5127 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 010 | Train Loss 0.5173 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 011 | Train Loss 0.4971 | Val Acc 0.6500 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 012 | Train Loss 0.4990 | Val Acc 0.6500 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 013 | Train Loss 0.4807 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 014 | Train Loss 0.4675 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 015 | Train Loss 0.4899 | Val Acc 0.6200 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 016 | Train Loss 0.4620 | Val Acc 0.5100 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 017 | Train Loss 0.4593 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 018 | Train Loss 0.4689 | Val Acc 0.5900 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 019 | Train Loss 0.4785 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 020 | Train Loss 0.4464 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 021 | Train Loss 0.4687 | Val Acc 0.6200 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 022 | Train Loss 0.4329 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# [PROTEINS] Epoch 023 | Train Loss 0.4552 | Val Acc 0.6200 | LR 1.0e-02 [Best Val Acc: 0.7000 @ Epoch 9]
# Early stop @ epoch 24 | Best val_acc=0.7000
# [PROTEINS] Fold Test Acc: 0.7477
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6111 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5644 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5606 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 004 | Train Loss 0.5439 | Val Acc 0.5900 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 005 | Train Loss 0.5344 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 006 | Train Loss 0.5263 | Val Acc 0.6500 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 007 | Train Loss 0.5125 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 008 | Train Loss 0.5007 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 009 | Train Loss 0.4991 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 010 | Train Loss 0.5047 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 011 | Train Loss 0.4927 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 012 | Train Loss 0.4878 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 013 | Train Loss 0.4835 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 014 | Train Loss 0.4634 | Val Acc 0.6600 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 015 | Train Loss 0.4546 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 2]
# [PROTEINS] Epoch 016 | Train Loss 0.4087 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7300 @ Epoch 16]
# [PROTEINS] Epoch 017 | Train Loss 0.4679 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 17]
# [PROTEINS] Epoch 018 | Train Loss 0.4548 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 17]
# [PROTEINS] Epoch 019 | Train Loss 0.4443 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 17]
# [PROTEINS] Epoch 020 | Train Loss 0.4444 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 20]
# [PROTEINS] Epoch 021 | Train Loss 0.4322 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 20]
# [PROTEINS] Epoch 022 | Train Loss 0.4206 | Val Acc 0.5300 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 20]
# [PROTEINS] Epoch 023 | Train Loss 0.4346 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 024 | Train Loss 0.3925 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 025 | Train Loss 0.4387 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 026 | Train Loss 0.4248 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 027 | Train Loss 0.4243 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 028 | Train Loss 0.4409 | Val Acc 0.4700 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 029 | Train Loss 0.4075 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 030 | Train Loss 0.4281 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 031 | Train Loss 0.4097 | Val Acc 0.6500 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 032 | Train Loss 0.4236 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 033 | Train Loss 0.4235 | Val Acc 0.6400 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 034 | Train Loss 0.3879 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 035 | Train Loss 0.3392 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 23]
# [PROTEINS] Epoch 036 | Train Loss 0.3452 | Val Acc 0.7400 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 037 | Train Loss 0.3367 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 038 | Train Loss 0.3353 | Val Acc 0.7100 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 039 | Train Loss 0.3115 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 040 | Train Loss 0.3414 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 041 | Train Loss 0.3052 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 042 | Train Loss 0.2943 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 043 | Train Loss 0.2965 | Val Acc 0.7100 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 044 | Train Loss 0.3088 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 045 | Train Loss 0.2765 | Val Acc 0.6900 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 046 | Train Loss 0.3001 | Val Acc 0.7200 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 047 | Train Loss 0.2937 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 048 | Train Loss 0.2964 | Val Acc 0.7300 | LR 1.0e-03 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 049 | Train Loss 0.3019 | Val Acc 0.7200 | LR 1.0e-04 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Epoch 050 | Train Loss 0.3049 | Val Acc 0.7100 | LR 1.0e-04 [Best Val Acc: 0.7400 @ Epoch 36]
# [PROTEINS] Fold Test Acc: 0.7297
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6156 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5898 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5746 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7400 @ Epoch 2]
# [PROTEINS] Epoch 004 | Train Loss 0.5558 | Val Acc 0.7600 | LR 1.0e-02 [Best Val Acc: 0.7600 @ Epoch 4]
# [PROTEINS] Epoch 005 | Train Loss 0.5430 | Val Acc 0.7700 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 006 | Train Loss 0.5299 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 007 | Train Loss 0.5196 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 008 | Train Loss 0.4863 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 009 | Train Loss 0.4986 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 010 | Train Loss 0.4860 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 011 | Train Loss 0.5127 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 012 | Train Loss 0.5054 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 013 | Train Loss 0.4646 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 014 | Train Loss 0.4625 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 015 | Train Loss 0.4708 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 016 | Train Loss 0.4412 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 017 | Train Loss 0.4585 | Val Acc 0.5600 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 018 | Train Loss 0.4293 | Val Acc 0.5300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# [PROTEINS] Epoch 019 | Train Loss 0.4255 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 5]
# Early stop @ epoch 20 | Best val_acc=0.7700
# [PROTEINS] Fold Test Acc: 0.6486
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6179 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5911 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7100 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5658 | Val Acc 0.7200 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 004 | Train Loss 0.5338 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 005 | Train Loss 0.5198 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 006 | Train Loss 0.5118 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 007 | Train Loss 0.4975 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 008 | Train Loss 0.4935 | Val Acc 0.6900 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 009 | Train Loss 0.4791 | Val Acc 0.6400 | LR 1.0e-02 [Best Val Acc: 0.7200 @ Epoch 3]
# [PROTEINS] Epoch 010 | Train Loss 0.4819 | Val Acc 0.7700 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 011 | Train Loss 0.4703 | Val Acc 0.4300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 012 | Train Loss 0.4594 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 013 | Train Loss 0.4606 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 014 | Train Loss 0.4520 | Val Acc 0.6600 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 015 | Train Loss 0.4466 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 016 | Train Loss 0.4384 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 017 | Train Loss 0.4461 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 018 | Train Loss 0.4455 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 019 | Train Loss 0.4304 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 020 | Train Loss 0.4274 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 021 | Train Loss 0.4374 | Val Acc 0.6300 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 022 | Train Loss 0.3899 | Val Acc 0.5800 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 023 | Train Loss 0.3985 | Val Acc 0.7000 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# [PROTEINS] Epoch 024 | Train Loss 0.3849 | Val Acc 0.6800 | LR 1.0e-02 [Best Val Acc: 0.7700 @ Epoch 10]
# Early stop @ epoch 25 | Best val_acc=0.7700
# [PROTEINS] Fold Test Acc: 0.6306
#
# number of qubits 12
# number of nodes 620
# number of features 4
# train_feats shape: torch.Size([902, 4096])
# train_phases shape: torch.Size([902, 12, 12])
# train_labs shape: torch.Size([902])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [PROTEINS] Epoch 001 | Train Loss 0.6125 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.6000 @ Epoch 1]
# [PROTEINS] Epoch 002 | Train Loss 0.5767 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.7100 @ Epoch 2]
# [PROTEINS] Epoch 003 | Train Loss 0.5664 | Val Acc 0.8000 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 004 | Train Loss 0.5582 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 005 | Train Loss 0.5381 | Val Acc 0.7600 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 006 | Train Loss 0.5353 | Val Acc 0.7900 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 007 | Train Loss 0.5336 | Val Acc 0.7400 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 008 | Train Loss 0.5188 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 009 | Train Loss 0.5047 | Val Acc 0.7800 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 010 | Train Loss 0.4978 | Val Acc 0.7800 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 011 | Train Loss 0.4963 | Val Acc 0.7700 | LR 1.0e-02 [Best Val Acc: 0.8000 @ Epoch 3]
# [PROTEINS] Epoch 012 | Train Loss 0.4967 | Val Acc 0.8300 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 013 | Train Loss 0.4733 | Val Acc 0.7600 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 014 | Train Loss 0.5002 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 015 | Train Loss 0.4921 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 016 | Train Loss 0.4911 | Val Acc 0.7100 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 017 | Train Loss 0.4736 | Val Acc 0.6000 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 018 | Train Loss 0.4709 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 019 | Train Loss 0.4719 | Val Acc 0.8000 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 020 | Train Loss 0.4512 | Val Acc 0.7600 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 021 | Train Loss 0.4327 | Val Acc 0.5700 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 022 | Train Loss 0.4635 | Val Acc 0.6700 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 023 | Train Loss 0.4538 | Val Acc 0.7300 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 024 | Train Loss 0.4269 | Val Acc 0.5700 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 025 | Train Loss 0.4414 | Val Acc 0.7700 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# [PROTEINS] Epoch 026 | Train Loss 0.4645 | Val Acc 0.6100 | LR 1.0e-02 [Best Val Acc: 0.8300 @ Epoch 12]
# Early stop @ epoch 27 | Best val_acc=0.8300
# [PROTEINS] Fold Test Acc: 0.6036
#
#
# === Cross-Validation Results for PROTEINS ===
# Per-fold Accuracies: [0.6339285714285714, 0.6607142857142857, 0.7142857142857143, 0.6396396396396397, 0.6936936936936937, 0.7477477477477478, 0.7297297297297297, 0.6486486486486487, 0.6306306306306306, 0.6036036036036037]
# Mean Test Acc: 0.6703 ± 0.0457
