# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'Letter-high',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        # "hidden_dims": [32, 16],  # Hidden dimensions for classical head
         "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'Letter-high', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8531 | Val Acc 0.7673 | LR 1.0e-02 [Best Val Acc: 0.7673 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1314 | Val Acc 0.8366 | LR 1.0e-02 [Best Val Acc: 0.8366 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9372 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 3]
# [Letter-high] Epoch 004 | Train Loss 0.8245 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 3]
# [Letter-high] Epoch 005 | Train Loss 0.7942 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 5]
# [Letter-high] Epoch 006 | Train Loss 0.7341 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7021 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 7]
# [Letter-high] Epoch 008 | Train Loss 0.7233 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 7]
# [Letter-high] Epoch 009 | Train Loss 0.6779 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-high] Epoch 010 | Train Loss 0.6541 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-high] Epoch 011 | Train Loss 0.6706 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-high] Epoch 012 | Train Loss 0.6292 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 12]
# [Letter-high] Epoch 013 | Train Loss 0.6205 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 12]
# [Letter-high] Epoch 014 | Train Loss 0.5422 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 12]
# [Letter-high] Epoch 015 | Train Loss 0.5838 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 12]
# [Letter-high] Epoch 016 | Train Loss 0.5848 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 12]
# [Letter-high] Epoch 017 | Train Loss 0.5737 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 17]
# [Letter-high] Epoch 018 | Train Loss 0.5704 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 18]
# [Letter-high] Epoch 019 | Train Loss 0.5707 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 18]
# [Letter-high] Epoch 020 | Train Loss 0.5644 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 18]
# [Letter-high] Epoch 021 | Train Loss 0.5451 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 21]
# [Letter-high] Epoch 022 | Train Loss 0.5610 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 21]
# [Letter-high] Epoch 023 | Train Loss 0.5068 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 21]
# [Letter-high] Epoch 024 | Train Loss 0.5560 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 21]
# [Letter-high] Epoch 025 | Train Loss 0.5480 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 21]
# [Letter-high] Epoch 026 | Train Loss 0.5375 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 26]
# [Letter-high] Epoch 027 | Train Loss 0.5539 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 26]
# [Letter-high] Epoch 028 | Train Loss 0.5307 | Val Acc 0.9109 | LR 1.0e-03 [Best Val Acc: 0.9208 @ Epoch 26]
# [Letter-high] Epoch 029 | Train Loss 0.5100 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 29]
# [Letter-high] Epoch 030 | Train Loss 0.4846 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 30]
# [Letter-high] Epoch 031 | Train Loss 0.4503 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 30]
# [Letter-high] Epoch 032 | Train Loss 0.4619 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 32]
# [Letter-high] Epoch 033 | Train Loss 0.4745 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 32]
# [Letter-high] Epoch 034 | Train Loss 0.4712 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 32]
# [Letter-high] Epoch 035 | Train Loss 0.4911 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 32]
# [Letter-high] Epoch 036 | Train Loss 0.4529 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 32]
# [Letter-high] Epoch 037 | Train Loss 0.4568 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 32]
# [Letter-high] Epoch 038 | Train Loss 0.4592 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-high] Epoch 039 | Train Loss 0.4454 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 040 | Train Loss 0.4269 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 041 | Train Loss 0.4329 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 042 | Train Loss 0.4658 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 043 | Train Loss 0.4492 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 044 | Train Loss 0.4455 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Epoch 045 | Train Loss 0.4667 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Epoch 046 | Train Loss 0.4538 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Epoch 047 | Train Loss 0.4582 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Epoch 048 | Train Loss 0.4328 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Epoch 049 | Train Loss 0.4283 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Epoch 050 | Train Loss 0.4245 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 44]
# [Letter-high] Fold Test Acc: 0.9289
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8952 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8663 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1033 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9486 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 2]
# [Letter-high] Epoch 004 | Train Loss 0.8332 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 2]
# [Letter-high] Epoch 005 | Train Loss 0.7492 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 006 | Train Loss 0.7470 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 007 | Train Loss 0.7242 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 008 | Train Loss 0.7164 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 009 | Train Loss 0.6917 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 010 | Train Loss 0.6814 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 011 | Train Loss 0.6809 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 012 | Train Loss 0.6913 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 013 | Train Loss 0.6232 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 014 | Train Loss 0.6338 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 5]
# [Letter-high] Epoch 015 | Train Loss 0.6177 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 016 | Train Loss 0.6307 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 017 | Train Loss 0.6168 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 018 | Train Loss 0.6038 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 019 | Train Loss 0.5944 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 020 | Train Loss 0.5952 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 021 | Train Loss 0.6013 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 022 | Train Loss 0.5743 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 023 | Train Loss 0.5498 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 15]
# [Letter-high] Epoch 024 | Train Loss 0.5639 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 025 | Train Loss 0.5551 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 026 | Train Loss 0.5803 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 027 | Train Loss 0.5892 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 028 | Train Loss 0.5309 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 029 | Train Loss 0.5387 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 030 | Train Loss 0.5517 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 031 | Train Loss 0.5602 | Val Acc 0.8861 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-high] Epoch 032 | Train Loss 0.5042 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 32]
# [Letter-high] Epoch 033 | Train Loss 0.4876 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 32]
# [Letter-high] Epoch 034 | Train Loss 0.4787 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 32]
# [Letter-high] Epoch 035 | Train Loss 0.4535 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-high] Epoch 036 | Train Loss 0.4461 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-high] Epoch 037 | Train Loss 0.4715 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-high] Epoch 038 | Train Loss 0.4906 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-high] Epoch 039 | Train Loss 0.4643 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-high] Epoch 040 | Train Loss 0.4528 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-high] Epoch 041 | Train Loss 0.4770 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-high] Epoch 042 | Train Loss 0.4857 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-high] Epoch 043 | Train Loss 0.4475 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 43]
# [Letter-high] Epoch 044 | Train Loss 0.4051 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Epoch 045 | Train Loss 0.4846 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Epoch 046 | Train Loss 0.4658 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Epoch 047 | Train Loss 0.4368 | Val Acc 0.9505 | LR 1.0e-04 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Epoch 048 | Train Loss 0.4687 | Val Acc 0.9505 | LR 1.0e-04 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Epoch 049 | Train Loss 0.4433 | Val Acc 0.9455 | LR 1.0e-04 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Epoch 050 | Train Loss 0.4344 | Val Acc 0.9554 | LR 1.0e-04 [Best Val Acc: 0.9554 @ Epoch 44]
# [Letter-high] Fold Test Acc: 0.9556
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8699 | Val Acc 0.7772 | LR 1.0e-02 [Best Val Acc: 0.7772 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1088 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9469 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 3]
# [Letter-high] Epoch 004 | Train Loss 0.8561 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 4]
# [Letter-high] Epoch 005 | Train Loss 0.7733 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 4]
# [Letter-high] Epoch 006 | Train Loss 0.7346 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7348 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 6]
# [Letter-high] Epoch 008 | Train Loss 0.7471 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 6]
# [Letter-high] Epoch 009 | Train Loss 0.7026 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 010 | Train Loss 0.6944 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 011 | Train Loss 0.6934 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 012 | Train Loss 0.7050 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 013 | Train Loss 0.6397 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 014 | Train Loss 0.6240 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 015 | Train Loss 0.6209 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 016 | Train Loss 0.6196 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 9]
# [Letter-high] Epoch 017 | Train Loss 0.6234 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-high] Epoch 018 | Train Loss 0.6728 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-high] Epoch 019 | Train Loss 0.6012 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-high] Epoch 020 | Train Loss 0.6203 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-high] Epoch 021 | Train Loss 0.6177 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 21]
# [Letter-high] Epoch 022 | Train Loss 0.6130 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 21]
# [Letter-high] Epoch 023 | Train Loss 0.5812 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 21]
# [Letter-high] Epoch 024 | Train Loss 0.6123 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 21]
# [Letter-high] Epoch 025 | Train Loss 0.5961 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 25]
# [Letter-high] Epoch 026 | Train Loss 0.5435 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9604 @ Epoch 26]
# [Letter-high] Epoch 027 | Train Loss 0.5320 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 028 | Train Loss 0.5470 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 029 | Train Loss 0.4972 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 030 | Train Loss 0.5151 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 031 | Train Loss 0.5316 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 032 | Train Loss 0.5036 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 033 | Train Loss 0.4980 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 034 | Train Loss 0.4965 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 035 | Train Loss 0.5050 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 036 | Train Loss 0.5193 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 27]
# [Letter-high] Epoch 037 | Train Loss 0.4915 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 038 | Train Loss 0.5250 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 039 | Train Loss 0.5143 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 040 | Train Loss 0.5067 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 041 | Train Loss 0.5109 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 042 | Train Loss 0.5132 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 043 | Train Loss 0.5242 | Val Acc 0.9554 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 044 | Train Loss 0.4955 | Val Acc 0.9653 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 045 | Train Loss 0.5152 | Val Acc 0.9554 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 046 | Train Loss 0.5251 | Val Acc 0.9653 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 047 | Train Loss 0.4858 | Val Acc 0.9554 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 048 | Train Loss 0.5116 | Val Acc 0.9653 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 049 | Train Loss 0.4752 | Val Acc 0.9604 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Epoch 050 | Train Loss 0.4799 | Val Acc 0.9505 | LR 1.0e-04 [Best Val Acc: 0.9653 @ Epoch 37]
# [Letter-high] Fold Test Acc: 0.9511
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8433 | Val Acc 0.8069 | LR 1.0e-02 [Best Val Acc: 0.8069 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1196 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9846 | Val Acc 0.7921 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 2]
# [Letter-high] Epoch 004 | Train Loss 0.8775 | Val Acc 0.8317 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 2]
# [Letter-high] Epoch 005 | Train Loss 0.7809 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 5]
# [Letter-high] Epoch 006 | Train Loss 0.7593 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7616 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 6]
# [Letter-high] Epoch 008 | Train Loss 0.7320 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 8]
# [Letter-high] Epoch 009 | Train Loss 0.7117 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 8]
# [Letter-high] Epoch 010 | Train Loss 0.6952 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 10]
# [Letter-high] Epoch 011 | Train Loss 0.6736 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 10]
# [Letter-high] Epoch 012 | Train Loss 0.6761 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 12]
# [Letter-high] Epoch 013 | Train Loss 0.6376 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 12]
# [Letter-high] Epoch 014 | Train Loss 0.6013 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 12]
# [Letter-high] Epoch 015 | Train Loss 0.6092 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 15]
# [Letter-high] Epoch 016 | Train Loss 0.5975 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 16]
# [Letter-high] Epoch 017 | Train Loss 0.6208 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 16]
# [Letter-high] Epoch 018 | Train Loss 0.5682 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 16]
# [Letter-high] Epoch 019 | Train Loss 0.5842 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-high] Epoch 020 | Train Loss 0.5566 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-high] Epoch 021 | Train Loss 0.5649 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-high] Epoch 022 | Train Loss 0.5678 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-high] Epoch 023 | Train Loss 0.5564 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 23]
# [Letter-high] Epoch 024 | Train Loss 0.5350 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 23]
# [Letter-high] Epoch 025 | Train Loss 0.5403 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 23]
# [Letter-high] Epoch 026 | Train Loss 0.5094 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 23]
# [Letter-high] Epoch 027 | Train Loss 0.5962 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 23]
# [Letter-high] Epoch 028 | Train Loss 0.5488 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 029 | Train Loss 0.5608 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 030 | Train Loss 0.5324 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 031 | Train Loss 0.5390 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 032 | Train Loss 0.5090 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 033 | Train Loss 0.5622 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 034 | Train Loss 0.5412 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 28]
# [Letter-high] Epoch 035 | Train Loss 0.5202 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 35]
# [Letter-high] Epoch 036 | Train Loss 0.5299 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 35]
# [Letter-high] Epoch 037 | Train Loss 0.4975 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 038 | Train Loss 0.5332 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 039 | Train Loss 0.4809 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 040 | Train Loss 0.4608 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 041 | Train Loss 0.5405 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 042 | Train Loss 0.5390 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 043 | Train Loss 0.5190 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 044 | Train Loss 0.4923 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 37]
# [Letter-high] Epoch 045 | Train Loss 0.5386 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 45]
# [Letter-high] Epoch 046 | Train Loss 0.4991 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 45]
# [Letter-high] Epoch 047 | Train Loss 0.5257 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 45]
# [Letter-high] Epoch 048 | Train Loss 0.4970 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 45]
# [Letter-high] Epoch 049 | Train Loss 0.4729 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 45]
# [Letter-high] Epoch 050 | Train Loss 0.5106 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 45]
# [Letter-high] Fold Test Acc: 0.9067
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8640 | Val Acc 0.8218 | LR 1.0e-02 [Best Val Acc: 0.8218 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.0886 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9360 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 3]
# [Letter-high] Epoch 004 | Train Loss 0.8479 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 3]
# [Letter-high] Epoch 005 | Train Loss 0.7678 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 3]
# [Letter-high] Epoch 006 | Train Loss 0.7380 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7360 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 7]
# [Letter-high] Epoch 008 | Train Loss 0.7052 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 8]
# [Letter-high] Epoch 009 | Train Loss 0.6899 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 8]
# [Letter-high] Epoch 010 | Train Loss 0.7239 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 8]
# [Letter-high] Epoch 011 | Train Loss 0.6618 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 11]
# [Letter-high] Epoch 012 | Train Loss 0.7170 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 11]
# [Letter-high] Epoch 013 | Train Loss 0.6472 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 11]
# [Letter-high] Epoch 014 | Train Loss 0.6270 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 015 | Train Loss 0.6421 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 016 | Train Loss 0.6316 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 017 | Train Loss 0.6395 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 018 | Train Loss 0.6490 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 019 | Train Loss 0.6297 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 020 | Train Loss 0.5987 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 021 | Train Loss 0.5915 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 022 | Train Loss 0.6282 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 023 | Train Loss 0.5617 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 024 | Train Loss 0.5602 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 025 | Train Loss 0.5913 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 026 | Train Loss 0.6159 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 027 | Train Loss 0.6062 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# [Letter-high] Epoch 028 | Train Loss 0.6006 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 14]
# Early stop @ epoch 29 | Best val_acc=0.9554
# [Letter-high] Fold Test Acc: 0.8889
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8925 | Val Acc 0.8069 | LR 1.0e-02 [Best Val Acc: 0.8069 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1041 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9608 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 3]
# [Letter-high] Epoch 004 | Train Loss 0.8588 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 3]
# [Letter-high] Epoch 005 | Train Loss 0.7886 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 3]
# [Letter-high] Epoch 006 | Train Loss 0.7559 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7282 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 008 | Train Loss 0.7547 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 009 | Train Loss 0.6730 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 010 | Train Loss 0.6695 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 011 | Train Loss 0.6929 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 012 | Train Loss 0.6971 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 013 | Train Loss 0.5978 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 014 | Train Loss 0.5831 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 015 | Train Loss 0.6610 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 016 | Train Loss 0.6056 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 6]
# [Letter-high] Epoch 017 | Train Loss 0.6062 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 018 | Train Loss 0.6099 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 019 | Train Loss 0.5975 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 020 | Train Loss 0.5456 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 021 | Train Loss 0.5255 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 022 | Train Loss 0.5276 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 023 | Train Loss 0.4998 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 024 | Train Loss 0.5255 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 025 | Train Loss 0.5179 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 026 | Train Loss 0.5079 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 027 | Train Loss 0.5627 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 028 | Train Loss 0.5329 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 029 | Train Loss 0.5152 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 030 | Train Loss 0.5074 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 031 | Train Loss 0.4939 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 17]
# Early stop @ epoch 32 | Best val_acc=0.9307
# [Letter-high] Fold Test Acc: 0.9467
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8761 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8515 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1354 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9694 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 2]
# [Letter-high] Epoch 004 | Train Loss 0.8631 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 2]
# [Letter-high] Epoch 005 | Train Loss 0.8374 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 5]
# [Letter-high] Epoch 006 | Train Loss 0.7891 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7725 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 7]
# [Letter-high] Epoch 008 | Train Loss 0.7598 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 8]
# [Letter-high] Epoch 009 | Train Loss 0.7323 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 010 | Train Loss 0.6865 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 011 | Train Loss 0.7002 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 012 | Train Loss 0.7337 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 013 | Train Loss 0.6555 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 014 | Train Loss 0.6406 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 015 | Train Loss 0.6569 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 016 | Train Loss 0.6323 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 017 | Train Loss 0.6247 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 018 | Train Loss 0.6362 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 019 | Train Loss 0.5994 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 020 | Train Loss 0.6375 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 021 | Train Loss 0.5872 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 022 | Train Loss 0.6123 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# [Letter-high] Epoch 023 | Train Loss 0.5500 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 9]
# Early stop @ epoch 24 | Best val_acc=0.9703
# [Letter-high] Fold Test Acc: 0.9378
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8869 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8168 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.0872 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9314 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 2]
# [Letter-high] Epoch 004 | Train Loss 0.8401 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 4]
# [Letter-high] Epoch 005 | Train Loss 0.7814 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 4]
# [Letter-high] Epoch 006 | Train Loss 0.7296 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.6899 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 008 | Train Loss 0.6956 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 009 | Train Loss 0.7018 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 010 | Train Loss 0.6224 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 011 | Train Loss 0.6675 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 012 | Train Loss 0.6269 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 013 | Train Loss 0.6117 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-high] Epoch 014 | Train Loss 0.6050 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 14]
# [Letter-high] Epoch 015 | Train Loss 0.5786 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 14]
# [Letter-high] Epoch 016 | Train Loss 0.6022 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 14]
# [Letter-high] Epoch 017 | Train Loss 0.5687 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 018 | Train Loss 0.5910 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 019 | Train Loss 0.5362 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 020 | Train Loss 0.5652 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 021 | Train Loss 0.5564 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 022 | Train Loss 0.5305 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 023 | Train Loss 0.5312 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 024 | Train Loss 0.5344 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 17]
# [Letter-high] Epoch 025 | Train Loss 0.5402 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 026 | Train Loss 0.5539 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 027 | Train Loss 0.5670 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 028 | Train Loss 0.5151 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 029 | Train Loss 0.5038 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 030 | Train Loss 0.5235 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 031 | Train Loss 0.5160 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 032 | Train Loss 0.5100 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 033 | Train Loss 0.5560 | Val Acc 0.9010 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 25]
# [Letter-high] Epoch 034 | Train Loss 0.4943 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9356 @ Epoch 34]
# [Letter-high] Epoch 035 | Train Loss 0.4622 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9356 @ Epoch 35]
# [Letter-high] Epoch 036 | Train Loss 0.4547 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9356 @ Epoch 36]
# [Letter-high] Epoch 037 | Train Loss 0.4519 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 038 | Train Loss 0.4744 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-high] Epoch 039 | Train Loss 0.4084 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 040 | Train Loss 0.4276 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 39]
# [Letter-high] Epoch 041 | Train Loss 0.4074 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 042 | Train Loss 0.4352 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 043 | Train Loss 0.4553 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 044 | Train Loss 0.4156 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 045 | Train Loss 0.4485 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 046 | Train Loss 0.4552 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 047 | Train Loss 0.4301 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 048 | Train Loss 0.4421 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 049 | Train Loss 0.4272 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Epoch 050 | Train Loss 0.4010 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 41]
# [Letter-high] Fold Test Acc: 0.9556
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8962 | Val Acc 0.7624 | LR 1.0e-02 [Best Val Acc: 0.7624 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1085 | Val Acc 0.8366 | LR 1.0e-02 [Best Val Acc: 0.8366 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9204 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 3]
# [Letter-high] Epoch 004 | Train Loss 0.8331 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 4]
# [Letter-high] Epoch 005 | Train Loss 0.7812 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 4]
# [Letter-high] Epoch 006 | Train Loss 0.7127 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 6]
# [Letter-high] Epoch 007 | Train Loss 0.7127 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 6]
# [Letter-high] Epoch 008 | Train Loss 0.7303 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 6]
# [Letter-high] Epoch 009 | Train Loss 0.6814 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-high] Epoch 010 | Train Loss 0.6625 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-high] Epoch 011 | Train Loss 0.6755 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 012 | Train Loss 0.6705 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 013 | Train Loss 0.6547 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 014 | Train Loss 0.5857 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 015 | Train Loss 0.6138 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 016 | Train Loss 0.6045 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 017 | Train Loss 0.6341 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 018 | Train Loss 0.5788 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 019 | Train Loss 0.5893 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 020 | Train Loss 0.5664 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-high] Epoch 021 | Train Loss 0.5819 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 21]
# [Letter-high] Epoch 022 | Train Loss 0.5310 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 21]
# [Letter-high] Epoch 023 | Train Loss 0.5078 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 21]
# [Letter-high] Epoch 024 | Train Loss 0.5755 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 21]
# [Letter-high] Epoch 025 | Train Loss 0.6032 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 21]
# [Letter-high] Epoch 026 | Train Loss 0.5804 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 027 | Train Loss 0.5864 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 028 | Train Loss 0.5416 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 029 | Train Loss 0.5401 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 030 | Train Loss 0.5339 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 031 | Train Loss 0.5322 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 032 | Train Loss 0.5359 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 033 | Train Loss 0.5021 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-high] Epoch 034 | Train Loss 0.5500 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 34]
# [Letter-high] Epoch 035 | Train Loss 0.5673 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 34]
# [Letter-high] Epoch 036 | Train Loss 0.5426 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 34]
# [Letter-high] Epoch 037 | Train Loss 0.5240 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 038 | Train Loss 0.5630 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 039 | Train Loss 0.5121 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 040 | Train Loss 0.5156 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 041 | Train Loss 0.5642 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 042 | Train Loss 0.5327 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 043 | Train Loss 0.5317 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 044 | Train Loss 0.4907 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 045 | Train Loss 0.5175 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 046 | Train Loss 0.5223 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 37]
# [Letter-high] Epoch 047 | Train Loss 0.5351 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 47]
# [Letter-high] Epoch 048 | Train Loss 0.5243 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 47]
# [Letter-high] Epoch 049 | Train Loss 0.5221 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 47]
# [Letter-high] Epoch 050 | Train Loss 0.5156 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 47]
# [Letter-high] Fold Test Acc: 0.9378
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-high] Epoch 001 | Train Loss 1.8487 | Val Acc 0.7970 | LR 1.0e-02 [Best Val Acc: 0.7970 @ Epoch 1]
# [Letter-high] Epoch 002 | Train Loss 1.1089 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 2]
# [Letter-high] Epoch 003 | Train Loss 0.9561 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 2]
# [Letter-high] Epoch 004 | Train Loss 0.8605 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 4]
# [Letter-high] Epoch 005 | Train Loss 0.7720 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 4]
# [Letter-high] Epoch 006 | Train Loss 0.7228 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 4]
# [Letter-high] Epoch 007 | Train Loss 0.7074 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 4]
# [Letter-high] Epoch 008 | Train Loss 0.7223 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 4]
# [Letter-high] Epoch 009 | Train Loss 0.6988 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 4]
# [Letter-high] Epoch 010 | Train Loss 0.6626 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 10]
# [Letter-high] Epoch 011 | Train Loss 0.6703 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 10]
# [Letter-high] Epoch 012 | Train Loss 0.6728 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 12]
# [Letter-high] Epoch 013 | Train Loss 0.6288 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 12]
# [Letter-high] Epoch 014 | Train Loss 0.6086 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 12]
# [Letter-high] Epoch 015 | Train Loss 0.6345 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 12]
# [Letter-high] Epoch 016 | Train Loss 0.6220 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 16]
# [Letter-high] Epoch 017 | Train Loss 0.6233 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 16]
# [Letter-high] Epoch 018 | Train Loss 0.5980 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 16]
# [Letter-high] Epoch 019 | Train Loss 0.6076 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 19]
# [Letter-high] Epoch 020 | Train Loss 0.6057 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 20]
# [Letter-high] Epoch 021 | Train Loss 0.5827 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 20]
# [Letter-high] Epoch 022 | Train Loss 0.6097 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 20]
# [Letter-high] Epoch 023 | Train Loss 0.5276 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 20]
# [Letter-high] Epoch 024 | Train Loss 0.5889 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 24]
# [Letter-high] Epoch 025 | Train Loss 0.5553 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 24]
# [Letter-high] Epoch 026 | Train Loss 0.5495 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 24]
# [Letter-high] Epoch 027 | Train Loss 0.5924 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 24]
# [Letter-high] Epoch 028 | Train Loss 0.5671 | Val Acc 0.9752 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 029 | Train Loss 0.5594 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 030 | Train Loss 0.5330 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 031 | Train Loss 0.5600 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 032 | Train Loss 0.5398 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 033 | Train Loss 0.5384 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 034 | Train Loss 0.5506 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 035 | Train Loss 0.6002 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 036 | Train Loss 0.5270 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 037 | Train Loss 0.5072 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 038 | Train Loss 0.5319 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 039 | Train Loss 0.5588 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 040 | Train Loss 0.5205 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9752 @ Epoch 28]
# [Letter-high] Epoch 041 | Train Loss 0.5557 | Val Acc 0.9802 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 042 | Train Loss 0.5810 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 043 | Train Loss 0.5327 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 044 | Train Loss 0.5085 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 045 | Train Loss 0.5782 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 046 | Train Loss 0.5002 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 047 | Train Loss 0.5103 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 048 | Train Loss 0.5293 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 049 | Train Loss 0.5315 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Epoch 050 | Train Loss 0.5035 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9802 @ Epoch 41]
# [Letter-high] Fold Test Acc: 0.9156
#
#
# === Cross-Validation Results for Letter-high ===
# Per-fold Accuracies: [0.9288888888888889, 0.9555555555555556, 0.9511111111111111, 0.9066666666666666, 0.8888888888888888, 0.9466666666666667, 0.9377777777777778, 0.9555555555555556, 0.9377777777777778, 0.9155555555555556]
# Mean Test Acc: 0.9324 ± 0.0213
