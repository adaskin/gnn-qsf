# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'ENZYMES',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [32,64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'ENZYMES', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/ENZYMES.zip
# Processing...
# Done!
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.7970 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7103 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6510 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.2222 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5967 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5219 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5081 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 007 | Train Loss 1.4652 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 008 | Train Loss 1.4541 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 009 | Train Loss 1.4344 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 010 | Train Loss 1.3950 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3598 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 012 | Train Loss 1.3491 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 013 | Train Loss 1.2629 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 014 | Train Loss 1.2552 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 015 | Train Loss 1.2583 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 016 | Train Loss 1.2489 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 017 | Train Loss 1.2516 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 018 | Train Loss 1.1358 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 019 | Train Loss 1.2041 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 020 | Train Loss 1.2313 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
# [ENZYMES] Epoch 021 | Train Loss 1.1727 | Val Acc 0.5185 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 022 | Train Loss 1.1921 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 023 | Train Loss 1.0862 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 024 | Train Loss 1.1297 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 025 | Train Loss 1.1220 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 026 | Train Loss 1.0369 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 027 | Train Loss 1.0909 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 028 | Train Loss 1.1155 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 21]
# [ENZYMES] Epoch 029 | Train Loss 1.0285 | Val Acc 0.5556 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 030 | Train Loss 1.0208 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 031 | Train Loss 1.0435 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 032 | Train Loss 1.0806 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 033 | Train Loss 1.0231 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 034 | Train Loss 0.9996 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 035 | Train Loss 1.0001 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 036 | Train Loss 0.9548 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 037 | Train Loss 1.0319 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 038 | Train Loss 1.0211 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 039 | Train Loss 1.0505 | Val Acc 0.5556 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 040 | Train Loss 0.9672 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 041 | Train Loss 1.0109 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 042 | Train Loss 0.9821 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 29]
# [ENZYMES] Epoch 043 | Train Loss 0.9281 | Val Acc 0.5556 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 43]
# [ENZYMES] Epoch 044 | Train Loss 0.9479 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 43]
# [ENZYMES] Epoch 045 | Train Loss 0.9081 | Val Acc 0.5370 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 43]
# [ENZYMES] Epoch 046 | Train Loss 0.9154 | Val Acc 0.5370 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 43]
# [ENZYMES] Epoch 047 | Train Loss 0.8240 | Val Acc 0.5556 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 47]
# [ENZYMES] Epoch 048 | Train Loss 0.8385 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 47]
# [ENZYMES] Epoch 049 | Train Loss 0.8021 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 47]
# [ENZYMES] Epoch 050 | Train Loss 0.8051 | Val Acc 0.5741 | LR 1.0e-03 [Best Val Acc: 0.5741 @ Epoch 50]
# [ENZYMES] Fold Test Acc: 0.5333
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.7709 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6951 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6115 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.2407 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5651 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5498 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.4918 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 007 | Train Loss 1.4288 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 008 | Train Loss 1.4572 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 009 | Train Loss 1.4172 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 010 | Train Loss 1.3936 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 011 | Train Loss 1.3218 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 012 | Train Loss 1.3083 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 013 | Train Loss 1.2787 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 014 | Train Loss 1.2527 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 015 | Train Loss 1.2340 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 016 | Train Loss 1.1358 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 017 | Train Loss 1.1750 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 018 | Train Loss 1.1540 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 019 | Train Loss 1.1885 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 020 | Train Loss 1.1886 | Val Acc 0.2037 | LR 1.0e-03 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 021 | Train Loss 1.0740 | Val Acc 0.3519 | LR 1.0e-03 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 022 | Train Loss 1.0984 | Val Acc 0.4444 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 023 | Train Loss 1.0524 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 024 | Train Loss 1.0500 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 025 | Train Loss 1.0447 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 026 | Train Loss 0.9771 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 027 | Train Loss 0.9439 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 028 | Train Loss 1.0113 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 029 | Train Loss 0.9529 | Val Acc 0.3519 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 030 | Train Loss 0.9831 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 031 | Train Loss 0.9920 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 032 | Train Loss 1.0001 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 033 | Train Loss 0.9724 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 034 | Train Loss 0.9519 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 035 | Train Loss 0.9046 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 036 | Train Loss 0.9575 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 22]
# [ENZYMES] Epoch 037 | Train Loss 1.0007 | Val Acc 0.4444 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 038 | Train Loss 0.9503 | Val Acc 0.3704 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 039 | Train Loss 0.9883 | Val Acc 0.3704 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 040 | Train Loss 0.9395 | Val Acc 0.3704 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 041 | Train Loss 0.9955 | Val Acc 0.3889 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 042 | Train Loss 0.9456 | Val Acc 0.3704 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 043 | Train Loss 0.9311 | Val Acc 0.3889 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 044 | Train Loss 0.9166 | Val Acc 0.3519 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 045 | Train Loss 0.9407 | Val Acc 0.3519 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 046 | Train Loss 0.9888 | Val Acc 0.3889 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 047 | Train Loss 0.8880 | Val Acc 0.3519 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 048 | Train Loss 0.9299 | Val Acc 0.3889 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 049 | Train Loss 0.9575 | Val Acc 0.3704 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Epoch 050 | Train Loss 0.9283 | Val Acc 0.3889 | LR 1.0e-04 [Best Val Acc: 0.4444 @ Epoch 37]
# [ENZYMES] Fold Test Acc: 0.3833
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8037 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7005 | Val Acc 0.1852 | LR 1.0e-02 [Best Val Acc: 0.1852 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6461 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5792 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 3]
# [ENZYMES] Epoch 005 | Train Loss 1.5507 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5124 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4610 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4542 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.4220 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 010 | Train Loss 1.4200 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 011 | Train Loss 1.4169 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 11]
# [ENZYMES] Epoch 012 | Train Loss 1.3536 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 11]
# [ENZYMES] Epoch 013 | Train Loss 1.3512 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 11]
# [ENZYMES] Epoch 014 | Train Loss 1.2970 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 14]
# [ENZYMES] Epoch 015 | Train Loss 1.2596 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 14]
# [ENZYMES] Epoch 016 | Train Loss 1.2361 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 14]
# [ENZYMES] Epoch 017 | Train Loss 1.2329 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 14]
# [ENZYMES] Epoch 018 | Train Loss 1.2131 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 18]
# [ENZYMES] Epoch 019 | Train Loss 1.1946 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 18]
# [ENZYMES] Epoch 020 | Train Loss 1.1998 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 18]
# [ENZYMES] Epoch 021 | Train Loss 1.0877 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 18]
# [ENZYMES] Epoch 022 | Train Loss 1.1900 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 023 | Train Loss 1.1511 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 024 | Train Loss 1.1793 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 025 | Train Loss 1.1583 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 026 | Train Loss 1.0770 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 027 | Train Loss 1.0980 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 028 | Train Loss 1.0876 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 029 | Train Loss 1.0998 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 22]
# [ENZYMES] Epoch 030 | Train Loss 1.0067 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 031 | Train Loss 1.0354 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 032 | Train Loss 1.0906 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 033 | Train Loss 0.9779 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 034 | Train Loss 1.0324 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 035 | Train Loss 1.0144 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 036 | Train Loss 1.0244 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 037 | Train Loss 1.0576 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 038 | Train Loss 0.9551 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4815 @ Epoch 30]
# [ENZYMES] Epoch 039 | Train Loss 0.9786 | Val Acc 0.5000 | LR 1.0e-03 [Best Val Acc: 0.5000 @ Epoch 39]
# [ENZYMES] Epoch 040 | Train Loss 0.9015 | Val Acc 0.5000 | LR 1.0e-03 [Best Val Acc: 0.5000 @ Epoch 40]
# [ENZYMES] Epoch 041 | Train Loss 0.9188 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 41]
# [ENZYMES] Epoch 042 | Train Loss 0.8315 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 42]
# [ENZYMES] Epoch 043 | Train Loss 0.8240 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 43]
# [ENZYMES] Epoch 044 | Train Loss 0.8171 | Val Acc 0.5000 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 43]
# [ENZYMES] Epoch 045 | Train Loss 0.8189 | Val Acc 0.5370 | LR 1.0e-03 [Best Val Acc: 0.5370 @ Epoch 45]
# [ENZYMES] Epoch 046 | Train Loss 0.8472 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5370 @ Epoch 45]
# [ENZYMES] Epoch 047 | Train Loss 0.7641 | Val Acc 0.5370 | LR 1.0e-03 [Best Val Acc: 0.5370 @ Epoch 47]
# [ENZYMES] Epoch 048 | Train Loss 0.8065 | Val Acc 0.5185 | LR 1.0e-03 [Best Val Acc: 0.5370 @ Epoch 47]
# [ENZYMES] Epoch 049 | Train Loss 0.7971 | Val Acc 0.5556 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 49]
# [ENZYMES] Epoch 050 | Train Loss 0.8038 | Val Acc 0.5370 | LR 1.0e-03 [Best Val Acc: 0.5556 @ Epoch 49]
# [ENZYMES] Fold Test Acc: 0.4333
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8148 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7259 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6650 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.2963 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.6126 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5751 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.5460 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 007 | Train Loss 1.4886 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 008 | Train Loss 1.4913 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 009 | Train Loss 1.4011 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 010 | Train Loss 1.3850 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3741 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 10]
# [ENZYMES] Epoch 012 | Train Loss 1.3213 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 12]
# [ENZYMES] Epoch 013 | Train Loss 1.3456 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 12]
# [ENZYMES] Epoch 014 | Train Loss 1.3406 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 12]
# [ENZYMES] Epoch 015 | Train Loss 1.2430 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 12]
# [ENZYMES] Epoch 016 | Train Loss 1.2196 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 017 | Train Loss 1.2577 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 018 | Train Loss 1.1878 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 019 | Train Loss 1.2548 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 020 | Train Loss 1.2085 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 021 | Train Loss 1.1825 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 022 | Train Loss 1.1978 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 16]
# [ENZYMES] Epoch 023 | Train Loss 1.1313 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 23]
# [ENZYMES] Epoch 024 | Train Loss 1.1752 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 23]
# [ENZYMES] Epoch 025 | Train Loss 1.1423 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 026 | Train Loss 1.1865 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 027 | Train Loss 1.0901 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 028 | Train Loss 1.0886 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 029 | Train Loss 1.0823 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 030 | Train Loss 1.0957 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 031 | Train Loss 1.1311 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 032 | Train Loss 1.0894 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 033 | Train Loss 0.9964 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 034 | Train Loss 1.0302 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 035 | Train Loss 1.0298 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 036 | Train Loss 1.0319 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 037 | Train Loss 1.0642 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 038 | Train Loss 1.0262 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# [ENZYMES] Epoch 039 | Train Loss 1.0628 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 25]
# Early stop @ epoch 40 | Best val_acc=0.4630
# [ENZYMES] Fold Test Acc: 0.2000
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8034 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6837 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6170 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.2963 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5914 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.2963 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5281 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.4934 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4770 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4846 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.4243 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 010 | Train Loss 1.4019 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 011 | Train Loss 1.3410 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 012 | Train Loss 1.3448 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 013 | Train Loss 1.3076 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 014 | Train Loss 1.2835 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 015 | Train Loss 1.2136 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 016 | Train Loss 1.2165 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 017 | Train Loss 1.2823 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 018 | Train Loss 1.1863 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 019 | Train Loss 1.1960 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 020 | Train Loss 1.2268 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 021 | Train Loss 1.2165 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 022 | Train Loss 1.1983 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 023 | Train Loss 1.1571 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 024 | Train Loss 1.1567 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 025 | Train Loss 1.1456 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 026 | Train Loss 1.1108 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 027 | Train Loss 1.0901 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 028 | Train Loss 1.1158 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 029 | Train Loss 1.0973 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 15]
# [ENZYMES] Epoch 030 | Train Loss 1.0985 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 031 | Train Loss 1.0262 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 032 | Train Loss 1.0827 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 033 | Train Loss 1.0461 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 034 | Train Loss 1.0346 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 035 | Train Loss 1.0266 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 036 | Train Loss 0.9961 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 037 | Train Loss 1.0393 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 038 | Train Loss 1.0172 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 039 | Train Loss 1.0594 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 040 | Train Loss 1.0130 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 041 | Train Loss 0.9955 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 042 | Train Loss 0.9761 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 043 | Train Loss 0.9290 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# [ENZYMES] Epoch 044 | Train Loss 0.9828 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 30]
# Early stop @ epoch 45 | Best val_acc=0.5000
# [ENZYMES] Fold Test Acc: 0.3500
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.7960 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6719 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.2407 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6250 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5717 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 3]
# [ENZYMES] Epoch 005 | Train Loss 1.5493 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5115 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4813 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4630 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.4250 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 010 | Train Loss 1.4011 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3564 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 10]
# [ENZYMES] Epoch 012 | Train Loss 1.3262 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 10]
# [ENZYMES] Epoch 013 | Train Loss 1.3039 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 10]
# [ENZYMES] Epoch 014 | Train Loss 1.3015 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 015 | Train Loss 1.2411 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 016 | Train Loss 1.2424 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 017 | Train Loss 1.2455 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 018 | Train Loss 1.1597 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 019 | Train Loss 1.2124 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 020 | Train Loss 1.1897 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 021 | Train Loss 1.1167 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 022 | Train Loss 1.1822 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 023 | Train Loss 1.1473 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 024 | Train Loss 1.1081 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 025 | Train Loss 1.0994 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 026 | Train Loss 1.0482 | Val Acc 0.2593 | LR 1.0e-03 [Best Val Acc: 0.4074 @ Epoch 14]
# [ENZYMES] Epoch 027 | Train Loss 0.9909 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4074 @ Epoch 27]
# [ENZYMES] Epoch 028 | Train Loss 0.9695 | Val Acc 0.4630 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 029 | Train Loss 0.9462 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 030 | Train Loss 0.9483 | Val Acc 0.4444 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 031 | Train Loss 0.9572 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 032 | Train Loss 0.9226 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 033 | Train Loss 0.9223 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 034 | Train Loss 0.9384 | Val Acc 0.3333 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 035 | Train Loss 0.8986 | Val Acc 0.3519 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 036 | Train Loss 0.8990 | Val Acc 0.3704 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 037 | Train Loss 0.9255 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 038 | Train Loss 0.8782 | Val Acc 0.3519 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 039 | Train Loss 0.9545 | Val Acc 0.3333 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 040 | Train Loss 0.9090 | Val Acc 0.3704 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 041 | Train Loss 0.9028 | Val Acc 0.3519 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# [ENZYMES] Epoch 042 | Train Loss 0.9155 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 28]
# Early stop @ epoch 43 | Best val_acc=0.4630
# [ENZYMES] Fold Test Acc: 0.3667
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8011 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6727 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6014 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2778 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5639 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5389 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.4674 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4462 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4309 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.3590 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 010 | Train Loss 1.3542 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 011 | Train Loss 1.3298 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 012 | Train Loss 1.3013 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 013 | Train Loss 1.2782 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 014 | Train Loss 1.2216 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 015 | Train Loss 1.1895 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 016 | Train Loss 1.1855 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 017 | Train Loss 1.1846 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 018 | Train Loss 1.1494 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# [ENZYMES] Epoch 019 | Train Loss 1.1826 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 5]
# Early stop @ epoch 20 | Best val_acc=0.4259
# [ENZYMES] Fold Test Acc: 0.2500
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8127 | Val Acc 0.1481 | LR 1.0e-02 [Best Val Acc: 0.1481 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7202 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6598 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2778 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.6003 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5871 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.5099 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 007 | Train Loss 1.4861 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 008 | Train Loss 1.4169 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 009 | Train Loss 1.4132 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 010 | Train Loss 1.3691 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 011 | Train Loss 1.3140 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 012 | Train Loss 1.3428 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 013 | Train Loss 1.2461 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 6]
# [ENZYMES] Epoch 014 | Train Loss 1.3243 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 14]
# [ENZYMES] Epoch 015 | Train Loss 1.2196 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 14]
# [ENZYMES] Epoch 016 | Train Loss 1.1905 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 16]
# [ENZYMES] Epoch 017 | Train Loss 1.2509 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 16]
# [ENZYMES] Epoch 018 | Train Loss 1.1142 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 16]
# [ENZYMES] Epoch 019 | Train Loss 1.1745 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 19]
# [ENZYMES] Epoch 020 | Train Loss 1.2250 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 20]
# [ENZYMES] Epoch 021 | Train Loss 1.0831 | Val Acc 0.1852 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 20]
# [ENZYMES] Epoch 022 | Train Loss 1.1669 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 20]
# [ENZYMES] Epoch 023 | Train Loss 1.1003 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 20]
# [ENZYMES] Epoch 024 | Train Loss 1.1046 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 24]
# [ENZYMES] Epoch 025 | Train Loss 1.1433 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 24]
# [ENZYMES] Epoch 026 | Train Loss 1.0966 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 027 | Train Loss 1.0642 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 028 | Train Loss 1.1078 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 029 | Train Loss 1.0550 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 030 | Train Loss 1.0527 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 031 | Train Loss 1.0571 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 032 | Train Loss 1.0168 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 033 | Train Loss 0.9890 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 034 | Train Loss 0.9863 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 035 | Train Loss 0.9537 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 036 | Train Loss 0.9716 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 037 | Train Loss 0.9239 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 038 | Train Loss 0.9829 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 26]
# [ENZYMES] Epoch 039 | Train Loss 1.0577 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 040 | Train Loss 1.0343 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 041 | Train Loss 0.9243 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 042 | Train Loss 0.8898 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 043 | Train Loss 0.8370 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 044 | Train Loss 0.8089 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 045 | Train Loss 0.8032 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 39]
# [ENZYMES] Epoch 046 | Train Loss 0.7738 | Val Acc 0.4444 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 46]
# [ENZYMES] Epoch 047 | Train Loss 0.7795 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 46]
# [ENZYMES] Epoch 048 | Train Loss 0.8127 | Val Acc 0.4444 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 46]
# [ENZYMES] Epoch 049 | Train Loss 0.7989 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 46]
# [ENZYMES] Epoch 050 | Train Loss 0.7375 | Val Acc 0.4444 | LR 1.0e-03 [Best Val Acc: 0.4444 @ Epoch 50]
# [ENZYMES] Fold Test Acc: 0.4833
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8163 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7108 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6655 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5973 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5509 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.5404 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 007 | Train Loss 1.4540 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 008 | Train Loss 1.4740 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 009 | Train Loss 1.4141 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 010 | Train Loss 1.3828 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 011 | Train Loss 1.3702 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 11]
# [ENZYMES] Epoch 012 | Train Loss 1.3694 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 11]
# [ENZYMES] Epoch 013 | Train Loss 1.3419 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 13]
# [ENZYMES] Epoch 014 | Train Loss 1.3032 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 015 | Train Loss 1.2643 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 016 | Train Loss 1.2695 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 017 | Train Loss 1.2758 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 018 | Train Loss 1.2217 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 019 | Train Loss 1.2593 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 020 | Train Loss 1.1932 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 021 | Train Loss 1.2065 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 022 | Train Loss 1.2525 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 023 | Train Loss 1.1922 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 024 | Train Loss 1.1799 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 025 | Train Loss 1.1495 | Val Acc 0.2037 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 026 | Train Loss 1.1457 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 027 | Train Loss 1.0784 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 028 | Train Loss 1.0952 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# Early stop @ epoch 29 | Best val_acc=0.4444
# [ENZYMES] Fold Test Acc: 0.1833
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8126 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7000 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.2407 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6533 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.6249 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5882 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.4964 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4869 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4414 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 009 | Train Loss 1.4394 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 010 | Train Loss 1.3415 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3847 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 012 | Train Loss 1.3586 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 013 | Train Loss 1.2908 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 014 | Train Loss 1.3237 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 015 | Train Loss 1.2887 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 016 | Train Loss 1.2807 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 017 | Train Loss 1.2477 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 018 | Train Loss 1.1899 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 10]
# [ENZYMES] Epoch 019 | Train Loss 1.2216 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 19]
# [ENZYMES] Epoch 020 | Train Loss 1.1528 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 021 | Train Loss 1.1548 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 022 | Train Loss 1.1825 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 023 | Train Loss 1.0925 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 024 | Train Loss 1.1612 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 025 | Train Loss 1.1537 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 026 | Train Loss 1.0955 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 027 | Train Loss 1.0945 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 028 | Train Loss 1.1559 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 029 | Train Loss 1.0466 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 030 | Train Loss 1.0492 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4815 @ Epoch 20]
# [ENZYMES] Epoch 031 | Train Loss 1.1115 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 032 | Train Loss 1.1055 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 033 | Train Loss 1.0003 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 034 | Train Loss 1.0259 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 035 | Train Loss 0.9776 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 036 | Train Loss 0.9994 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 037 | Train Loss 1.0385 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 038 | Train Loss 0.9561 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 039 | Train Loss 1.0202 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 040 | Train Loss 0.9475 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 041 | Train Loss 1.0255 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 042 | Train Loss 1.0123 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 043 | Train Loss 0.9406 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 044 | Train Loss 0.9307 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 31]
# [ENZYMES] Epoch 045 | Train Loss 0.9263 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 45]
# [ENZYMES] Epoch 046 | Train Loss 0.9585 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 45]
# [ENZYMES] Epoch 047 | Train Loss 0.9122 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.5000 @ Epoch 45]
# [ENZYMES] Epoch 048 | Train Loss 0.8296 | Val Acc 0.3704 | LR 1.0e-03 [Best Val Acc: 0.5000 @ Epoch 45]
# [ENZYMES] Epoch 049 | Train Loss 0.8511 | Val Acc 0.4630 | LR 1.0e-03 [Best Val Acc: 0.5000 @ Epoch 45]
# [ENZYMES] Epoch 050 | Train Loss 0.7796 | Val Acc 0.4815 | LR 1.0e-03 [Best Val Acc: 0.5000 @ Epoch 45]
# [ENZYMES] Fold Test Acc: 0.4333
#
#
# === Cross-Validation Results for ENZYMES ===
# Per-fold Accuracies: [0.5333333333333333, 0.38333333333333336, 0.43333333333333335, 0.2, 0.35, 0.36666666666666664, 0.25, 0.48333333333333334, 0.18333333333333332, 0.43333333333333335]
# Mean Test Acc: 0.3617 ± 0.1121
