# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'MSRC_9',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [32,64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 16,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'MSRC_9', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 16, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/MSRC_9.zip
# Processing...
# Done!
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([179, 1024])
# train_phases shape: torch.Size([179, 10, 10])
# train_labs shape: torch.Size([179])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0156 | Val Acc 0.0526 | LR 1.0e-02 [Best Val Acc: 0.0526 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6413 | Val Acc 0.2632 | LR 1.0e-02 [Best Val Acc: 0.2632 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4644 | Val Acc 0.4737 | LR 1.0e-02 [Best Val Acc: 0.4737 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2232 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0835 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 1.0258 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.9474 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 008 | Train Loss 0.8980 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 009 | Train Loss 0.7119 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 010 | Train Loss 0.6681 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 10]
# [MSRC_9] Epoch 011 | Train Loss 0.6189 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 10]
# [MSRC_9] Epoch 012 | Train Loss 0.5926 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 12]
# [MSRC_9] Epoch 013 | Train Loss 0.4938 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 014 | Train Loss 0.5868 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 015 | Train Loss 0.5992 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 016 | Train Loss 0.3713 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 017 | Train Loss 0.5845 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 018 | Train Loss 0.4210 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 019 | Train Loss 0.4743 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 020 | Train Loss 0.3332 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 021 | Train Loss 0.3965 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 022 | Train Loss 0.3533 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 023 | Train Loss 0.4066 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 024 | Train Loss 0.3957 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 025 | Train Loss 0.3412 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 026 | Train Loss 0.4838 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# [MSRC_9] Epoch 027 | Train Loss 0.3391 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 13]
# Early stop @ epoch 28 | Best val_acc=0.8421
# [MSRC_9] Fold Test Acc: 0.7391
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0192 | Val Acc 0.1053 | LR 1.0e-02 [Best Val Acc: 0.1053 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6810 | Val Acc 0.2105 | LR 1.0e-02 [Best Val Acc: 0.2105 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4556 | Val Acc 0.2632 | LR 1.0e-02 [Best Val Acc: 0.2632 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2298 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5263 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0596 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5263 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 0.9629 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.7933 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 008 | Train Loss 0.6964 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 009 | Train Loss 0.6155 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 010 | Train Loss 0.6726 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 011 | Train Loss 0.7401 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 012 | Train Loss 0.6552 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 013 | Train Loss 0.6499 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 014 | Train Loss 0.5448 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 015 | Train Loss 0.6369 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 9]
# [MSRC_9] Epoch 016 | Train Loss 0.5495 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 16]
# [MSRC_9] Epoch 017 | Train Loss 0.4370 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 16]
# [MSRC_9] Epoch 018 | Train Loss 0.4609 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 16]
# [MSRC_9] Epoch 019 | Train Loss 0.4308 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 19]
# [MSRC_9] Epoch 020 | Train Loss 0.4830 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 19]
# [MSRC_9] Epoch 021 | Train Loss 0.4258 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 19]
# [MSRC_9] Epoch 022 | Train Loss 0.4598 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 19]
# [MSRC_9] Epoch 023 | Train Loss 0.3995 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 19]
# [MSRC_9] Epoch 024 | Train Loss 0.3933 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 24]
# [MSRC_9] Epoch 025 | Train Loss 0.3549 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 026 | Train Loss 0.3756 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 26]
# [MSRC_9] Epoch 027 | Train Loss 0.3925 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 26]
# [MSRC_9] Epoch 028 | Train Loss 0.3899 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 26]
# [MSRC_9] Epoch 029 | Train Loss 0.4244 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 26]
# [MSRC_9] Epoch 030 | Train Loss 0.3000 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 031 | Train Loss 0.3463 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 032 | Train Loss 0.3450 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 033 | Train Loss 0.4055 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 034 | Train Loss 0.2777 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 035 | Train Loss 0.3260 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 036 | Train Loss 0.3048 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 037 | Train Loss 0.3517 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 038 | Train Loss 0.2755 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 039 | Train Loss 0.3637 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 30]
# [MSRC_9] Epoch 040 | Train Loss 0.2458 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 041 | Train Loss 0.3449 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 042 | Train Loss 0.3182 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 043 | Train Loss 0.2584 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 044 | Train Loss 0.4369 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 045 | Train Loss 0.2854 | Val Acc 0.7368 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 046 | Train Loss 0.2503 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 047 | Train Loss 0.2492 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 048 | Train Loss 0.3075 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 049 | Train Loss 0.3273 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Epoch 050 | Train Loss 0.2798 | Val Acc 0.7895 | LR 1.0e-04 [Best Val Acc: 0.7895 @ Epoch 40]
# [MSRC_9] Fold Test Acc: 0.7273
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 1.9875 | Val Acc 0.2105 | LR 1.0e-02 [Best Val Acc: 0.2105 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6164 | Val Acc 0.2632 | LR 1.0e-02 [Best Val Acc: 0.2632 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4203 | Val Acc 0.4737 | LR 1.0e-02 [Best Val Acc: 0.4737 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.1906 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0196 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 006 | Train Loss 0.9281 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 007 | Train Loss 0.8502 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.7606 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 009 | Train Loss 0.6661 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 010 | Train Loss 0.7075 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 011 | Train Loss 0.6915 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 012 | Train Loss 0.5738 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 013 | Train Loss 0.6288 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 014 | Train Loss 0.5669 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 015 | Train Loss 0.5769 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 016 | Train Loss 0.5879 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 017 | Train Loss 0.4479 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 018 | Train Loss 0.4876 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 019 | Train Loss 0.5465 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 020 | Train Loss 0.4576 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# [MSRC_9] Epoch 021 | Train Loss 0.4897 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 7]
# Early stop @ epoch 22 | Best val_acc=0.9474
# [MSRC_9] Fold Test Acc: 0.9091
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0235 | Val Acc 0.2105 | LR 1.0e-02 [Best Val Acc: 0.2105 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6871 | Val Acc 0.3158 | LR 1.0e-02 [Best Val Acc: 0.3158 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4321 | Val Acc 0.3158 | LR 1.0e-02 [Best Val Acc: 0.3158 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2151 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0324 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 1.0268 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.8435 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.6734 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 8]
# [MSRC_9] Epoch 009 | Train Loss 0.7227 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 8]
# [MSRC_9] Epoch 010 | Train Loss 0.6562 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 10]
# [MSRC_9] Epoch 011 | Train Loss 0.7567 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 10]
# [MSRC_9] Epoch 012 | Train Loss 0.5549 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 12]
# [MSRC_9] Epoch 013 | Train Loss 0.6430 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 12]
# [MSRC_9] Epoch 014 | Train Loss 0.5081 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 015 | Train Loss 0.5630 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 016 | Train Loss 0.5472 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 017 | Train Loss 0.4301 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 018 | Train Loss 0.4282 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 019 | Train Loss 0.4955 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 020 | Train Loss 0.4953 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 021 | Train Loss 0.5123 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 022 | Train Loss 0.3987 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 023 | Train Loss 0.3687 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 024 | Train Loss 0.3722 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 025 | Train Loss 0.3349 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 026 | Train Loss 0.3709 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 027 | Train Loss 0.2657 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 028 | Train Loss 0.3708 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.8421 @ Epoch 14]
# Early stop @ epoch 29 | Best val_acc=0.8421
# [MSRC_9] Fold Test Acc: 0.6364
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0043 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6587 | Val Acc 0.2105 | LR 1.0e-02 [Best Val Acc: 0.2105 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.3728 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.1744 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0211 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 4]
# [MSRC_9] Epoch 006 | Train Loss 0.9164 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.8244 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.6789 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 009 | Train Loss 0.6107 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 010 | Train Loss 0.5820 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 011 | Train Loss 0.6894 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 012 | Train Loss 0.4616 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 013 | Train Loss 0.5417 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 014 | Train Loss 0.4809 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 015 | Train Loss 0.5498 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 016 | Train Loss 0.4545 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 017 | Train Loss 0.4061 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 018 | Train Loss 0.3799 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 019 | Train Loss 0.3819 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 020 | Train Loss 0.3969 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 021 | Train Loss 0.3524 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 022 | Train Loss 0.3915 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 023 | Train Loss 0.3474 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 024 | Train Loss 0.2773 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 025 | Train Loss 0.3503 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 026 | Train Loss 0.3452 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 027 | Train Loss 0.2962 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 028 | Train Loss 0.3217 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# [MSRC_9] Epoch 029 | Train Loss 0.3944 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 15]
# Early stop @ epoch 30 | Best val_acc=0.7895
# [MSRC_9] Fold Test Acc: 0.7727
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0320 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.7233 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4766 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2575 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.1026 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 006 | Train Loss 1.0238 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.8397 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.6569 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 009 | Train Loss 0.6697 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 010 | Train Loss 0.6721 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 10]
# [MSRC_9] Epoch 011 | Train Loss 0.6593 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 11]
# [MSRC_9] Epoch 012 | Train Loss 0.5035 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 12]
# [MSRC_9] Epoch 013 | Train Loss 0.5836 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 12]
# [MSRC_9] Epoch 014 | Train Loss 0.5316 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 12]
# [MSRC_9] Epoch 015 | Train Loss 0.5641 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 016 | Train Loss 0.5289 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 017 | Train Loss 0.4306 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 018 | Train Loss 0.5481 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 019 | Train Loss 0.5197 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 020 | Train Loss 0.4299 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 021 | Train Loss 0.4913 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 022 | Train Loss 0.4334 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 023 | Train Loss 0.3971 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 024 | Train Loss 0.3182 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 025 | Train Loss 0.3996 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 026 | Train Loss 0.3448 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 027 | Train Loss 0.3378 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 028 | Train Loss 0.4392 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# [MSRC_9] Epoch 029 | Train Loss 0.4960 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 15]
# Early stop @ epoch 30 | Best val_acc=0.8421
# [MSRC_9] Fold Test Acc: 0.7727
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 1.9930 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6829 | Val Acc 0.2632 | LR 1.0e-02 [Best Val Acc: 0.2632 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4276 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2131 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 3]
# [MSRC_9] Epoch 005 | Train Loss 1.0399 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 0.9153 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 5]
# [MSRC_9] Epoch 007 | Train Loss 0.8230 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.7522 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 009 | Train Loss 0.7018 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 010 | Train Loss 0.6773 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 011 | Train Loss 0.6493 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 11]
# [MSRC_9] Epoch 012 | Train Loss 0.4870 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 013 | Train Loss 0.6634 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 014 | Train Loss 0.5133 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 015 | Train Loss 0.5599 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 12]
# [MSRC_9] Epoch 016 | Train Loss 0.5192 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 017 | Train Loss 0.4883 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 018 | Train Loss 0.4753 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 019 | Train Loss 0.4524 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 020 | Train Loss 0.3799 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 021 | Train Loss 0.4224 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 022 | Train Loss 0.3760 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 023 | Train Loss 0.3160 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 024 | Train Loss 0.3218 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 16]
# [MSRC_9] Epoch 025 | Train Loss 0.3220 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 026 | Train Loss 0.3363 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 027 | Train Loss 0.2611 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 028 | Train Loss 0.5141 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 029 | Train Loss 0.4378 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 030 | Train Loss 0.2604 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 031 | Train Loss 0.3605 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 032 | Train Loss 0.3648 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 033 | Train Loss 0.3787 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 034 | Train Loss 0.2906 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 035 | Train Loss 0.3224 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 036 | Train Loss 0.2362 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 037 | Train Loss 0.3725 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 038 | Train Loss 0.2043 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# [MSRC_9] Epoch 039 | Train Loss 0.3456 | Val Acc 0.7895 | LR 1.0e-03 [Best Val Acc: 0.8947 @ Epoch 25]
# Early stop @ epoch 40 | Best val_acc=0.8947
# [MSRC_9] Fold Test Acc: 0.7273
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0438 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6886 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4985 | Val Acc 0.3684 | LR 1.0e-02 [Best Val Acc: 0.3684 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2898 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0968 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 0.9688 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.8767 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.7111 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 8]
# [MSRC_9] Epoch 009 | Train Loss 0.6633 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7895 @ Epoch 8]
# [MSRC_9] Epoch 010 | Train Loss 0.6830 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 10]
# [MSRC_9] Epoch 011 | Train Loss 0.6222 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 11]
# [MSRC_9] Epoch 012 | Train Loss 0.5358 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 11]
# [MSRC_9] Epoch 013 | Train Loss 0.6827 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 11]
# [MSRC_9] Epoch 014 | Train Loss 0.4840 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 015 | Train Loss 0.5709 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 016 | Train Loss 0.5387 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.8421 @ Epoch 14]
# [MSRC_9] Epoch 017 | Train Loss 0.4898 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 17]
# [MSRC_9] Epoch 018 | Train Loss 0.4002 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 17]
# [MSRC_9] Epoch 019 | Train Loss 0.5458 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 17]
# [MSRC_9] Epoch 020 | Train Loss 0.4013 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.8947 @ Epoch 20]
# [MSRC_9] Epoch 021 | Train Loss 0.3377 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 21]
# [MSRC_9] Epoch 022 | Train Loss 0.3247 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 21]
# [MSRC_9] Epoch 023 | Train Loss 0.3953 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 21]
# [MSRC_9] Epoch 024 | Train Loss 0.3068 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 21]
# [MSRC_9] Epoch 025 | Train Loss 0.3199 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 25]
# [MSRC_9] Epoch 026 | Train Loss 0.3249 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 25]
# [MSRC_9] Epoch 027 | Train Loss 0.2622 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 25]
# [MSRC_9] Epoch 028 | Train Loss 0.4100 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 25]
# [MSRC_9] Epoch 029 | Train Loss 0.3953 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 25]
# [MSRC_9] Epoch 030 | Train Loss 0.2785 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 25]
# [MSRC_9] Epoch 031 | Train Loss 0.2954 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 032 | Train Loss 0.5007 | Val Acc 0.9474 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 033 | Train Loss 0.3142 | Val Acc 0.8947 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 034 | Train Loss 0.2818 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 035 | Train Loss 0.2887 | Val Acc 0.8421 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 036 | Train Loss 0.1874 | Val Acc 0.7895 | LR 1.0e-02 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 037 | Train Loss 0.2448 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 038 | Train Loss 0.2037 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 039 | Train Loss 0.2364 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 040 | Train Loss 0.1674 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 041 | Train Loss 0.2074 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 042 | Train Loss 0.1619 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 043 | Train Loss 0.2035 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 044 | Train Loss 0.2200 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# [MSRC_9] Epoch 045 | Train Loss 0.1455 | Val Acc 0.8421 | LR 1.0e-03 [Best Val Acc: 0.9474 @ Epoch 31]
# Early stop @ epoch 46 | Best val_acc=0.9474
# [MSRC_9] Fold Test Acc: 0.7273
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0231 | Val Acc 0.1579 | LR 1.0e-02 [Best Val Acc: 0.1579 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.6866 | Val Acc 0.2632 | LR 1.0e-02 [Best Val Acc: 0.2632 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4609 | Val Acc 0.3158 | LR 1.0e-02 [Best Val Acc: 0.3158 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2213 | Val Acc 0.4737 | LR 1.0e-02 [Best Val Acc: 0.4737 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0737 | Val Acc 0.4737 | LR 1.0e-02 [Best Val Acc: 0.4737 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 1.0055 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 6]
# [MSRC_9] Epoch 007 | Train Loss 0.9048 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 6]
# [MSRC_9] Epoch 008 | Train Loss 0.7244 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 6]
# [MSRC_9] Epoch 009 | Train Loss 0.7095 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 6]
# [MSRC_9] Epoch 010 | Train Loss 0.7047 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 10]
# [MSRC_9] Epoch 011 | Train Loss 0.6685 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5789 @ Epoch 10]
# [MSRC_9] Epoch 012 | Train Loss 0.5599 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 12]
# [MSRC_9] Epoch 013 | Train Loss 0.6121 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 12]
# [MSRC_9] Epoch 014 | Train Loss 0.5632 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 14]
# [MSRC_9] Epoch 015 | Train Loss 0.7244 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 14]
# [MSRC_9] Epoch 016 | Train Loss 0.5891 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 14]
# [MSRC_9] Epoch 017 | Train Loss 0.4370 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 14]
# [MSRC_9] Epoch 018 | Train Loss 0.4236 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 18]
# [MSRC_9] Epoch 019 | Train Loss 0.4083 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 19]
# [MSRC_9] Epoch 020 | Train Loss 0.5113 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 19]
# [MSRC_9] Epoch 021 | Train Loss 0.3926 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 21]
# [MSRC_9] Epoch 022 | Train Loss 0.4401 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 21]
# [MSRC_9] Epoch 023 | Train Loss 0.4530 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 21]
# [MSRC_9] Epoch 024 | Train Loss 0.4028 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.6842 @ Epoch 21]
# [MSRC_9] Epoch 025 | Train Loss 0.3809 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 026 | Train Loss 0.3373 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 027 | Train Loss 0.2462 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 028 | Train Loss 0.3892 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 029 | Train Loss 0.3631 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 030 | Train Loss 0.2594 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 25]
# [MSRC_9] Epoch 031 | Train Loss 0.3199 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 31]
# [MSRC_9] Epoch 032 | Train Loss 0.2745 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 31]
# [MSRC_9] Epoch 033 | Train Loss 0.2819 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 31]
# [MSRC_9] Epoch 034 | Train Loss 0.3324 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 31]
# [MSRC_9] Epoch 035 | Train Loss 0.2693 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 036 | Train Loss 0.2791 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 037 | Train Loss 0.3694 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 038 | Train Loss 0.2454 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 039 | Train Loss 0.3476 | Val Acc 0.4737 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 040 | Train Loss 0.2222 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 041 | Train Loss 0.3235 | Val Acc 0.5789 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 042 | Train Loss 0.2707 | Val Acc 0.5789 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 043 | Train Loss 0.2646 | Val Acc 0.5789 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 044 | Train Loss 0.2694 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 045 | Train Loss 0.2056 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 046 | Train Loss 0.1678 | Val Acc 0.5789 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 047 | Train Loss 0.1532 | Val Acc 0.5789 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 048 | Train Loss 0.1968 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# [MSRC_9] Epoch 049 | Train Loss 0.2781 | Val Acc 0.5789 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 35]
# Early stop @ epoch 50 | Best val_acc=0.7368
# [MSRC_9] Fold Test Acc: 0.8182
#
# number of qubits 10
# number of nodes 55
# number of features 10
# train_feats shape: torch.Size([180, 1024])
# train_phases shape: torch.Size([180, 10, 10])
# train_labs shape: torch.Size([180])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=8, bias=True)
#   )
# )
# Number of parameters: 1512
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MSRC_9] Epoch 001 | Train Loss 2.0290 | Val Acc 0.2105 | LR 1.0e-02 [Best Val Acc: 0.2105 @ Epoch 1]
# [MSRC_9] Epoch 002 | Train Loss 1.7168 | Val Acc 0.3158 | LR 1.0e-02 [Best Val Acc: 0.3158 @ Epoch 2]
# [MSRC_9] Epoch 003 | Train Loss 1.4333 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.5263 @ Epoch 3]
# [MSRC_9] Epoch 004 | Train Loss 1.2399 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.6316 @ Epoch 4]
# [MSRC_9] Epoch 005 | Train Loss 1.0288 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 5]
# [MSRC_9] Epoch 006 | Train Loss 0.9839 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 5]
# [MSRC_9] Epoch 007 | Train Loss 0.9081 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 7]
# [MSRC_9] Epoch 008 | Train Loss 0.7293 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 009 | Train Loss 0.7010 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 010 | Train Loss 0.6741 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 011 | Train Loss 0.7473 | Val Acc 0.6316 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 012 | Train Loss 0.5714 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 8]
# [MSRC_9] Epoch 013 | Train Loss 0.6882 | Val Acc 0.7368 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 014 | Train Loss 0.5687 | Val Acc 0.6842 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 015 | Train Loss 0.6532 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 016 | Train Loss 0.6474 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 017 | Train Loss 0.4917 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 018 | Train Loss 0.4443 | Val Acc 0.5789 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 019 | Train Loss 0.5118 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 020 | Train Loss 0.4775 | Val Acc 0.5263 | LR 1.0e-02 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 021 | Train Loss 0.5152 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 13]
# [MSRC_9] Epoch 022 | Train Loss 0.4276 | Val Acc 0.7368 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 023 | Train Loss 0.4304 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 024 | Train Loss 0.4154 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 025 | Train Loss 0.3938 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 026 | Train Loss 0.3884 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 027 | Train Loss 0.2855 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 028 | Train Loss 0.4471 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 029 | Train Loss 0.3878 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 030 | Train Loss 0.2806 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 031 | Train Loss 0.3448 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 032 | Train Loss 0.3928 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 033 | Train Loss 0.4076 | Val Acc 0.6842 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 034 | Train Loss 0.3125 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 035 | Train Loss 0.3318 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# [MSRC_9] Epoch 036 | Train Loss 0.2875 | Val Acc 0.6316 | LR 1.0e-03 [Best Val Acc: 0.7368 @ Epoch 22]
# Early stop @ epoch 37 | Best val_acc=0.7368
# [MSRC_9] Fold Test Acc: 0.6818
#
#
# === Cross-Validation Results for MSRC_9 ===
# Per-fold Accuracies: [0.7391304347826086, 0.7272727272727273, 0.9090909090909091, 0.6363636363636364, 0.7727272727272727, 0.7727272727272727, 0.7272727272727273, 0.7272727272727273, 0.8181818181818182, 0.6818181818181818]
# Mean Test Acc: 0.7512 ± 0.0709
