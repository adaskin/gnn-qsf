# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'ENZYMES',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [32,64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'ENZYMES', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8008 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7080 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6509 | Val Acc 0.2037 | LR 1.0e-02 [Best Val Acc: 0.2037 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5920 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.2963 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5315 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5274 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4588 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 008 | Train Loss 1.4430 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 009 | Train Loss 1.4472 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 7]
# [ENZYMES] Epoch 010 | Train Loss 1.3994 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3809 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 11]
# [ENZYMES] Epoch 012 | Train Loss 1.4141 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 12]
# [ENZYMES] Epoch 013 | Train Loss 1.3067 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 12]
# [ENZYMES] Epoch 014 | Train Loss 1.2742 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 12]
# [ENZYMES] Epoch 015 | Train Loss 1.2746 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 12]
# [ENZYMES] Epoch 016 | Train Loss 1.2272 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 12]
# [ENZYMES] Epoch 017 | Train Loss 1.2867 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 12]
# [ENZYMES] Epoch 018 | Train Loss 1.2108 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 18]
# [ENZYMES] Epoch 019 | Train Loss 1.1464 | Val Acc 0.5556 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 020 | Train Loss 1.2477 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 021 | Train Loss 1.1477 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 022 | Train Loss 1.2019 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 023 | Train Loss 1.1403 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 024 | Train Loss 1.1058 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 025 | Train Loss 1.1635 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 026 | Train Loss 1.0930 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 027 | Train Loss 1.0608 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 028 | Train Loss 1.1481 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 029 | Train Loss 1.0574 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 030 | Train Loss 1.0767 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 031 | Train Loss 1.1139 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 032 | Train Loss 1.0758 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# [ENZYMES] Epoch 033 | Train Loss 1.0064 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 19]
# Early stop @ epoch 34 | Best val_acc=0.5556
# [ENZYMES] Fold Test Acc: 0.3000
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.7723 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6829 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6110 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2778 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5604 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5178 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.4786 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 007 | Train Loss 1.4058 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 008 | Train Loss 1.4480 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 009 | Train Loss 1.3596 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 010 | Train Loss 1.3463 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3089 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 10]
# [ENZYMES] Epoch 012 | Train Loss 1.2848 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 013 | Train Loss 1.2528 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 014 | Train Loss 1.2237 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 015 | Train Loss 1.2284 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 016 | Train Loss 1.1954 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 017 | Train Loss 1.2343 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 018 | Train Loss 1.1216 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 019 | Train Loss 1.1513 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 020 | Train Loss 1.1899 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 021 | Train Loss 1.2060 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 022 | Train Loss 1.1211 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 023 | Train Loss 1.1437 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 024 | Train Loss 1.1373 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 025 | Train Loss 1.1291 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# [ENZYMES] Epoch 026 | Train Loss 1.0457 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 12]
# Early stop @ epoch 27 | Best val_acc=0.4630
# [ENZYMES] Fold Test Acc: 0.3333
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8016 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7013 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.2222 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6412 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5835 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 005 | Train Loss 1.5582 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 006 | Train Loss 1.5101 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 007 | Train Loss 1.4454 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 008 | Train Loss 1.4497 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 009 | Train Loss 1.4057 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 010 | Train Loss 1.3820 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 011 | Train Loss 1.3893 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 012 | Train Loss 1.3422 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 013 | Train Loss 1.2945 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 014 | Train Loss 1.2602 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 015 | Train Loss 1.2122 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 016 | Train Loss 1.1897 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# [ENZYMES] Epoch 017 | Train Loss 1.2270 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 3]
# Early stop @ epoch 18 | Best val_acc=0.4259
# [ENZYMES] Fold Test Acc: 0.4167
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8136 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7314 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6547 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.2593 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.6099 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5782 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.5450 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 007 | Train Loss 1.4867 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 008 | Train Loss 1.4716 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 009 | Train Loss 1.4283 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 010 | Train Loss 1.3667 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 011 | Train Loss 1.3500 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 012 | Train Loss 1.2860 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 013 | Train Loss 1.2938 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 014 | Train Loss 1.2828 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 015 | Train Loss 1.2363 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 016 | Train Loss 1.2057 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 017 | Train Loss 1.1902 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 018 | Train Loss 1.1290 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 019 | Train Loss 1.2518 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 020 | Train Loss 1.1713 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# Early stop @ epoch 21 | Best val_acc=0.4259
# [ENZYMES] Fold Test Acc: 0.1333
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8022 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6879 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6317 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2778 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5993 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5232 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.4951 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4915 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4750 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.4132 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 010 | Train Loss 1.4108 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 011 | Train Loss 1.3802 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 012 | Train Loss 1.3367 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 013 | Train Loss 1.2719 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 014 | Train Loss 1.3213 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 015 | Train Loss 1.1931 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 5]
# [ENZYMES] Epoch 016 | Train Loss 1.2089 | Val Acc 0.5556 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 017 | Train Loss 1.1932 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 018 | Train Loss 1.1465 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 019 | Train Loss 1.1623 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 020 | Train Loss 1.1443 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 021 | Train Loss 1.1812 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 022 | Train Loss 1.1197 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 023 | Train Loss 1.1389 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 024 | Train Loss 1.0584 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 025 | Train Loss 1.0925 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 026 | Train Loss 1.0857 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 027 | Train Loss 1.0342 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 028 | Train Loss 1.0749 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 029 | Train Loss 1.0461 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# [ENZYMES] Epoch 030 | Train Loss 1.0367 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5556 @ Epoch 16]
# Early stop @ epoch 31 | Best val_acc=0.5556
# [ENZYMES] Fold Test Acc: 0.3000
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.7975 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6855 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.2222 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6417 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.2593 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5877 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5814 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5329 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3333 @ Epoch 6]
# [ENZYMES] Epoch 007 | Train Loss 1.4749 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 7]
# [ENZYMES] Epoch 008 | Train Loss 1.4805 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 7]
# [ENZYMES] Epoch 009 | Train Loss 1.4129 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 7]
# [ENZYMES] Epoch 010 | Train Loss 1.3943 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 7]
# [ENZYMES] Epoch 011 | Train Loss 1.3671 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 11]
# [ENZYMES] Epoch 012 | Train Loss 1.3334 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 11]
# [ENZYMES] Epoch 013 | Train Loss 1.3797 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 11]
# [ENZYMES] Epoch 014 | Train Loss 1.3353 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 11]
# [ENZYMES] Epoch 015 | Train Loss 1.2789 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 11]
# [ENZYMES] Epoch 016 | Train Loss 1.2295 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 16]
# [ENZYMES] Epoch 017 | Train Loss 1.2307 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 16]
# [ENZYMES] Epoch 018 | Train Loss 1.1640 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 019 | Train Loss 1.1754 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 020 | Train Loss 1.2129 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 18]
# [ENZYMES] Epoch 021 | Train Loss 1.1132 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 21]
# [ENZYMES] Epoch 022 | Train Loss 1.2316 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 21]
# [ENZYMES] Epoch 023 | Train Loss 1.1941 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 21]
# [ENZYMES] Epoch 024 | Train Loss 1.1341 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 21]
# [ENZYMES] Epoch 025 | Train Loss 1.1344 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 026 | Train Loss 1.1351 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 027 | Train Loss 1.0605 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 028 | Train Loss 1.0672 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 029 | Train Loss 1.0989 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 030 | Train Loss 1.0776 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 031 | Train Loss 1.0826 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 032 | Train Loss 1.0686 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 033 | Train Loss 1.0228 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 034 | Train Loss 1.0413 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 035 | Train Loss 1.0084 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 036 | Train Loss 1.0463 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 037 | Train Loss 1.0327 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 038 | Train Loss 0.9770 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# [ENZYMES] Epoch 039 | Train Loss 1.0752 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 25]
# Early stop @ epoch 40 | Best val_acc=0.4259
# [ENZYMES] Fold Test Acc: 0.3333
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8025 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6769 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6121 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2778 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5648 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5438 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.4626 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4146 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4202 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.3496 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 9]
# [ENZYMES] Epoch 010 | Train Loss 1.3046 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 9]
# [ENZYMES] Epoch 011 | Train Loss 1.3507 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 9]
# [ENZYMES] Epoch 012 | Train Loss 1.2858 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 9]
# [ENZYMES] Epoch 013 | Train Loss 1.2816 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 13]
# [ENZYMES] Epoch 014 | Train Loss 1.2280 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 13]
# [ENZYMES] Epoch 015 | Train Loss 1.1860 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 13]
# [ENZYMES] Epoch 016 | Train Loss 1.1556 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 16]
# [ENZYMES] Epoch 017 | Train Loss 1.1583 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3889 @ Epoch 16]
# [ENZYMES] Epoch 018 | Train Loss 1.1285 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 18]
# [ENZYMES] Epoch 019 | Train Loss 1.1747 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 18]
# [ENZYMES] Epoch 020 | Train Loss 1.1462 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 021 | Train Loss 1.1377 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 022 | Train Loss 1.1139 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 023 | Train Loss 1.0936 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 024 | Train Loss 1.1330 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 025 | Train Loss 1.1085 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 026 | Train Loss 1.0831 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 027 | Train Loss 1.0452 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 028 | Train Loss 1.0164 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 029 | Train Loss 0.9881 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 20]
# [ENZYMES] Epoch 030 | Train Loss 0.9826 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 031 | Train Loss 0.9768 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 032 | Train Loss 0.9909 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 033 | Train Loss 0.9446 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 034 | Train Loss 0.9633 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 035 | Train Loss 0.9184 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 036 | Train Loss 0.9332 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 037 | Train Loss 1.0460 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 038 | Train Loss 0.9225 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 039 | Train Loss 0.9712 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 040 | Train Loss 0.8481 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 041 | Train Loss 0.8955 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 042 | Train Loss 0.9413 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 043 | Train Loss 0.9143 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 30]
# [ENZYMES] Epoch 044 | Train Loss 0.8774 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Epoch 045 | Train Loss 0.8710 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Epoch 046 | Train Loss 0.9587 | Val Acc 0.4259 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Epoch 047 | Train Loss 0.8421 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Epoch 048 | Train Loss 0.7851 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Epoch 049 | Train Loss 0.7905 | Val Acc 0.4074 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Epoch 050 | Train Loss 0.7593 | Val Acc 0.3889 | LR 1.0e-03 [Best Val Acc: 0.4630 @ Epoch 44]
# [ENZYMES] Fold Test Acc: 0.5000
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8126 | Val Acc 0.1481 | LR 1.0e-02 [Best Val Acc: 0.1481 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7076 | Val Acc 0.2037 | LR 1.0e-02 [Best Val Acc: 0.2037 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6448 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2778 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5868 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.2963 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5653 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.2963 @ Epoch 4]
# [ENZYMES] Epoch 006 | Train Loss 1.4862 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 6]
# [ENZYMES] Epoch 007 | Train Loss 1.4665 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 6]
# [ENZYMES] Epoch 008 | Train Loss 1.4234 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 6]
# [ENZYMES] Epoch 009 | Train Loss 1.3804 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 6]
# [ENZYMES] Epoch 010 | Train Loss 1.3429 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 10]
# [ENZYMES] Epoch 011 | Train Loss 1.3171 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 10]
# [ENZYMES] Epoch 012 | Train Loss 1.3117 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 10]
# [ENZYMES] Epoch 013 | Train Loss 1.2993 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 13]
# [ENZYMES] Epoch 014 | Train Loss 1.3344 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 015 | Train Loss 1.2197 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 016 | Train Loss 1.2012 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 017 | Train Loss 1.1692 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 018 | Train Loss 1.0866 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 019 | Train Loss 1.1407 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 020 | Train Loss 1.2222 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 021 | Train Loss 1.1308 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 022 | Train Loss 1.1357 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 023 | Train Loss 1.0886 | Val Acc 0.1481 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 024 | Train Loss 1.1011 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 025 | Train Loss 1.1182 | Val Acc 0.2593 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 026 | Train Loss 1.0380 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 027 | Train Loss 1.0551 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# [ENZYMES] Epoch 028 | Train Loss 1.0606 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 14]
# Early stop @ epoch 29 | Best val_acc=0.4444
# [ENZYMES] Fold Test Acc: 0.2833
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8146 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7067 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6658 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5988 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5517 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5344 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4425 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4074 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4648 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 009 | Train Loss 1.3938 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 010 | Train Loss 1.4122 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 011 | Train Loss 1.3482 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 012 | Train Loss 1.3535 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 013 | Train Loss 1.3143 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 014 | Train Loss 1.3128 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 015 | Train Loss 1.2497 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 016 | Train Loss 1.2898 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 017 | Train Loss 1.2625 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 018 | Train Loss 1.2197 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 019 | Train Loss 1.2460 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 020 | Train Loss 1.1959 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 021 | Train Loss 1.1795 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 022 | Train Loss 1.1881 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 023 | Train Loss 1.2440 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 024 | Train Loss 1.1992 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 025 | Train Loss 1.1807 | Val Acc 0.2778 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 026 | Train Loss 1.1497 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 13]
# [ENZYMES] Epoch 027 | Train Loss 1.1476 | Val Acc 0.5741 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 028 | Train Loss 1.0690 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 029 | Train Loss 1.0900 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 030 | Train Loss 1.0691 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 031 | Train Loss 1.1316 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 032 | Train Loss 1.0895 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 033 | Train Loss 1.0978 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 034 | Train Loss 1.1029 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 035 | Train Loss 1.0798 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 036 | Train Loss 1.0518 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 037 | Train Loss 1.0979 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 038 | Train Loss 1.0436 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 039 | Train Loss 1.0062 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 040 | Train Loss 1.0814 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# [ENZYMES] Epoch 041 | Train Loss 1.0686 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5741 @ Epoch 27]
# Early stop @ epoch 42 | Best val_acc=0.5741
# [ENZYMES] Fold Test Acc: 0.2333
#
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.8125 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.6995 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6622 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.3148 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.6039 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5585 | Val Acc 0.5000 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.4992 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 007 | Train Loss 1.4670 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 008 | Train Loss 1.4376 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 009 | Train Loss 1.4401 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 010 | Train Loss 1.3657 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 011 | Train Loss 1.3516 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 012 | Train Loss 1.3173 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 013 | Train Loss 1.2568 | Val Acc 0.2407 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 014 | Train Loss 1.2750 | Val Acc 0.3889 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 015 | Train Loss 1.2235 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 016 | Train Loss 1.2280 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 017 | Train Loss 1.1966 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 018 | Train Loss 1.1452 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 019 | Train Loss 1.1302 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5000 @ Epoch 5]
# [ENZYMES] Epoch 020 | Train Loss 1.1464 | Val Acc 0.5185 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 021 | Train Loss 1.1702 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 022 | Train Loss 1.1662 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 023 | Train Loss 1.1083 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 024 | Train Loss 1.1493 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 025 | Train Loss 1.1100 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 026 | Train Loss 1.0243 | Val Acc 0.4630 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 20]
# [ENZYMES] Epoch 027 | Train Loss 1.0809 | Val Acc 0.5185 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 028 | Train Loss 1.0813 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 029 | Train Loss 0.9964 | Val Acc 0.2963 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 030 | Train Loss 1.0218 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 031 | Train Loss 1.0704 | Val Acc 0.4815 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 032 | Train Loss 1.0504 | Val Acc 0.4074 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 033 | Train Loss 1.0114 | Val Acc 0.3148 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 034 | Train Loss 1.0284 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 035 | Train Loss 0.9792 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 036 | Train Loss 1.0176 | Val Acc 0.3519 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 037 | Train Loss 0.9799 | Val Acc 0.4815 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 038 | Train Loss 0.8925 | Val Acc 0.4815 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 039 | Train Loss 0.8243 | Val Acc 0.4815 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 040 | Train Loss 0.8452 | Val Acc 0.4815 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 27]
# [ENZYMES] Epoch 041 | Train Loss 0.8507 | Val Acc 0.4815 | LR 1.0e-03 [Best Val Acc: 0.5185 @ Epoch 27]
# Early stop @ epoch 42 | Best val_acc=0.5185
# [ENZYMES] Fold Test Acc: 0.4667
#
#
# === Cross-Validation Results for ENZYMES ===
# Per-fold Accuracies: [0.3, 0.3333333333333333, 0.4166666666666667, 0.13333333333333333, 0.3, 0.3333333333333333, 0.5, 0.2833333333333333, 0.23333333333333334, 0.4666666666666667]
# Mean Test Acc: 0.3300 ± 0.1035
