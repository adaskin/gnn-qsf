# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=200,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'Letter-low',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [128, 64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'Letter-low', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8786 | Val Acc 0.7525 | LR 1.0e-02 [Best Val Acc: 0.7525 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1580 | Val Acc 0.7772 | LR 1.0e-02 [Best Val Acc: 0.7772 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 1.0497 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8515 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9520 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.9154 | Val Acc 0.8416 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 4]
# [Letter-low] Epoch 006 | Train Loss 0.8652 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.8542 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 7]
# [Letter-low] Epoch 008 | Train Loss 0.8409 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 7]
# [Letter-low] Epoch 009 | Train Loss 0.7624 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 9]
# [Letter-low] Epoch 010 | Train Loss 0.7234 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.7277 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6658 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 11]
# [Letter-low] Epoch 013 | Train Loss 0.6873 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 13]
# [Letter-low] Epoch 014 | Train Loss 0.6481 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 015 | Train Loss 0.6513 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 016 | Train Loss 0.6529 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 017 | Train Loss 0.6412 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 018 | Train Loss 0.6367 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 019 | Train Loss 0.6081 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-low] Epoch 020 | Train Loss 0.6445 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-low] Epoch 021 | Train Loss 0.6562 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 19]
# [Letter-low] Epoch 022 | Train Loss 0.5978 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 22]
# [Letter-low] Epoch 023 | Train Loss 0.5764 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 22]
# [Letter-low] Epoch 024 | Train Loss 0.5760 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 22]
# [Letter-low] Epoch 025 | Train Loss 0.6082 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 22]
# [Letter-low] Epoch 026 | Train Loss 0.5863 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 26]
# [Letter-low] Epoch 027 | Train Loss 0.5752 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 028 | Train Loss 0.6063 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 029 | Train Loss 0.5815 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 030 | Train Loss 0.5908 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 031 | Train Loss 0.5524 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 032 | Train Loss 0.5902 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 033 | Train Loss 0.5605 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 034 | Train Loss 0.5757 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 035 | Train Loss 0.5464 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 036 | Train Loss 0.5573 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 037 | Train Loss 0.5416 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 038 | Train Loss 0.5542 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 27]
# [Letter-low] Epoch 039 | Train Loss 0.5536 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 39]
# [Letter-low] Epoch 040 | Train Loss 0.6055 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 041 | Train Loss 0.5510 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 042 | Train Loss 0.5548 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 043 | Train Loss 0.5787 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 044 | Train Loss 0.5714 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 045 | Train Loss 0.5700 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 046 | Train Loss 0.5350 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 047 | Train Loss 0.5298 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 048 | Train Loss 0.5260 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 049 | Train Loss 0.5325 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Epoch 050 | Train Loss 0.5276 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 40]
# [Letter-low] Fold Test Acc: 0.9644
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8382 | Val Acc 0.7673 | LR 1.0e-02 [Best Val Acc: 0.7673 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1295 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8168 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 0.9831 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9194 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8494 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8861 @ Epoch 4]
# [Letter-low] Epoch 006 | Train Loss 0.8029 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7760 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-low] Epoch 008 | Train Loss 0.7844 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-low] Epoch 009 | Train Loss 0.7197 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 7]
# [Letter-low] Epoch 010 | Train Loss 0.7338 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.7222 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6697 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 12]
# [Letter-low] Epoch 013 | Train Loss 0.6922 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 12]
# [Letter-low] Epoch 014 | Train Loss 0.6582 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 015 | Train Loss 0.6063 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 016 | Train Loss 0.6722 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 017 | Train Loss 0.6085 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 018 | Train Loss 0.6091 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 019 | Train Loss 0.6107 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 020 | Train Loss 0.6345 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 14]
# [Letter-low] Epoch 021 | Train Loss 0.6270 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 022 | Train Loss 0.6003 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 023 | Train Loss 0.5855 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 024 | Train Loss 0.5846 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 025 | Train Loss 0.5738 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 026 | Train Loss 0.5958 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 027 | Train Loss 0.5734 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 028 | Train Loss 0.5826 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 029 | Train Loss 0.5755 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 030 | Train Loss 0.5700 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 21]
# [Letter-low] Epoch 031 | Train Loss 0.5268 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 31]
# [Letter-low] Epoch 032 | Train Loss 0.5223 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 31]
# [Letter-low] Epoch 033 | Train Loss 0.4548 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 034 | Train Loss 0.5186 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 035 | Train Loss 0.5042 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 036 | Train Loss 0.5052 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 037 | Train Loss 0.4947 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 038 | Train Loss 0.4570 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 039 | Train Loss 0.4910 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 040 | Train Loss 0.4765 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 041 | Train Loss 0.5019 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 042 | Train Loss 0.5181 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 043 | Train Loss 0.4862 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 044 | Train Loss 0.5180 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 045 | Train Loss 0.4899 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 046 | Train Loss 0.4862 | Val Acc 0.9703 | LR 1.0e-04 [Best Val Acc: 0.9703 @ Epoch 33]
# [Letter-low] Epoch 047 | Train Loss 0.4727 | Val Acc 0.9703 | LR 1.0e-04 [Best Val Acc: 0.9703 @ Epoch 33]
# Early stop @ epoch 48 | Best val_acc=0.9703
# [Letter-low] Fold Test Acc: 0.9378
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8594 | Val Acc 0.7376 | LR 1.0e-02 [Best Val Acc: 0.7376 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1442 | Val Acc 0.7921 | LR 1.0e-02 [Best Val Acc: 0.7921 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 1.0057 | Val Acc 0.8020 | LR 1.0e-02 [Best Val Acc: 0.8020 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9488 | Val Acc 0.8267 | LR 1.0e-02 [Best Val Acc: 0.8267 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8677 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 5]
# [Letter-low] Epoch 006 | Train Loss 0.8223 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7922 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 6]
# [Letter-low] Epoch 008 | Train Loss 0.7863 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 6]
# [Letter-low] Epoch 009 | Train Loss 0.7567 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-low] Epoch 010 | Train Loss 0.7455 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-low] Epoch 011 | Train Loss 0.7216 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 9]
# [Letter-low] Epoch 012 | Train Loss 0.6782 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 12]
# [Letter-low] Epoch 013 | Train Loss 0.6992 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 13]
# [Letter-low] Epoch 014 | Train Loss 0.6867 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 13]
# [Letter-low] Epoch 015 | Train Loss 0.6452 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 15]
# [Letter-low] Epoch 016 | Train Loss 0.6439 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 16]
# [Letter-low] Epoch 017 | Train Loss 0.6469 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 018 | Train Loss 0.6175 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 019 | Train Loss 0.5999 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 020 | Train Loss 0.6123 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 021 | Train Loss 0.6153 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 022 | Train Loss 0.6079 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 023 | Train Loss 0.5828 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 024 | Train Loss 0.5928 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 025 | Train Loss 0.5869 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 026 | Train Loss 0.5967 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 027 | Train Loss 0.5816 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 028 | Train Loss 0.5890 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 029 | Train Loss 0.5420 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 030 | Train Loss 0.5645 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# [Letter-low] Epoch 031 | Train Loss 0.5283 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 17]
# Early stop @ epoch 32 | Best val_acc=0.9554
# [Letter-low] Fold Test Acc: 0.9467
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8275 | Val Acc 0.7178 | LR 1.0e-02 [Best Val Acc: 0.7178 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1394 | Val Acc 0.7723 | LR 1.0e-02 [Best Val Acc: 0.7723 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 0.9979 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8168 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9271 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8770 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 5]
# [Letter-low] Epoch 006 | Train Loss 0.8629 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7920 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 7]
# [Letter-low] Epoch 008 | Train Loss 0.7911 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 7]
# [Letter-low] Epoch 009 | Train Loss 0.7359 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 7]
# [Letter-low] Epoch 010 | Train Loss 0.7208 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.6945 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6790 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 11]
# [Letter-low] Epoch 013 | Train Loss 0.6953 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 014 | Train Loss 0.5906 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 015 | Train Loss 0.6110 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 016 | Train Loss 0.6569 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 017 | Train Loss 0.6297 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 018 | Train Loss 0.6167 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 019 | Train Loss 0.5757 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 13]
# [Letter-low] Epoch 020 | Train Loss 0.5885 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 021 | Train Loss 0.6635 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 022 | Train Loss 0.5502 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 023 | Train Loss 0.5980 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 024 | Train Loss 0.5902 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 025 | Train Loss 0.5469 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 026 | Train Loss 0.5662 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 027 | Train Loss 0.5441 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 028 | Train Loss 0.5445 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 029 | Train Loss 0.5434 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 030 | Train Loss 0.5151 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 031 | Train Loss 0.5428 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 032 | Train Loss 0.5611 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 033 | Train Loss 0.5127 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# [Letter-low] Epoch 034 | Train Loss 0.5412 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 20]
# Early stop @ epoch 35 | Best val_acc=0.9703
# [Letter-low] Fold Test Acc: 0.9378
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8197 | Val Acc 0.8218 | LR 1.0e-02 [Best Val Acc: 0.8218 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.0841 | Val Acc 0.8119 | LR 1.0e-02 [Best Val Acc: 0.8218 @ Epoch 1]
# [Letter-low] Epoch 003 | Train Loss 0.9647 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.8813 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8279 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 4]
# [Letter-low] Epoch 006 | Train Loss 0.7808 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7504 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 008 | Train Loss 0.7458 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 009 | Train Loss 0.7005 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 010 | Train Loss 0.6713 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.6730 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 10]
# [Letter-low] Epoch 012 | Train Loss 0.6278 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 10]
# [Letter-low] Epoch 013 | Train Loss 0.6242 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 10]
# [Letter-low] Epoch 014 | Train Loss 0.6207 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 10]
# [Letter-low] Epoch 015 | Train Loss 0.5707 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 016 | Train Loss 0.6027 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 017 | Train Loss 0.5755 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 018 | Train Loss 0.5851 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 019 | Train Loss 0.5739 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 020 | Train Loss 0.5988 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 021 | Train Loss 0.5798 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 022 | Train Loss 0.5682 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 15]
# [Letter-low] Epoch 023 | Train Loss 0.5200 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 23]
# [Letter-low] Epoch 024 | Train Loss 0.5807 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 23]
# [Letter-low] Epoch 025 | Train Loss 0.5370 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 23]
# [Letter-low] Epoch 026 | Train Loss 0.5417 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 23]
# [Letter-low] Epoch 027 | Train Loss 0.5289 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 028 | Train Loss 0.5547 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 029 | Train Loss 0.5427 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 030 | Train Loss 0.5379 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 031 | Train Loss 0.5677 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 032 | Train Loss 0.5414 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 033 | Train Loss 0.5210 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 27]
# [Letter-low] Epoch 034 | Train Loss 0.5268 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 34]
# [Letter-low] Epoch 035 | Train Loss 0.5494 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 35]
# [Letter-low] Epoch 036 | Train Loss 0.5193 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 35]
# [Letter-low] Epoch 037 | Train Loss 0.5246 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 35]
# [Letter-low] Epoch 038 | Train Loss 0.4967 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 35]
# [Letter-low] Epoch 039 | Train Loss 0.5275 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 35]
# [Letter-low] Epoch 040 | Train Loss 0.5203 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 35]
# [Letter-low] Epoch 041 | Train Loss 0.5032 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 042 | Train Loss 0.5393 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 043 | Train Loss 0.5765 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 044 | Train Loss 0.5450 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 045 | Train Loss 0.4755 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 046 | Train Loss 0.4731 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 047 | Train Loss 0.4813 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 048 | Train Loss 0.5112 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 049 | Train Loss 0.5019 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Epoch 050 | Train Loss 0.5166 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 41]
# [Letter-low] Fold Test Acc: 0.9333
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8746 | Val Acc 0.8069 | LR 1.0e-02 [Best Val Acc: 0.8069 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1524 | Val Acc 0.8317 | LR 1.0e-02 [Best Val Acc: 0.8317 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 1.0326 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9268 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8816 | Val Acc 0.8465 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 4]
# [Letter-low] Epoch 006 | Train Loss 0.8301 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7999 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 7]
# [Letter-low] Epoch 008 | Train Loss 0.7672 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 7]
# [Letter-low] Epoch 009 | Train Loss 0.7493 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 9]
# [Letter-low] Epoch 010 | Train Loss 0.7435 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.7345 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6756 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 013 | Train Loss 0.7196 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 014 | Train Loss 0.6776 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 015 | Train Loss 0.6488 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 016 | Train Loss 0.6799 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 017 | Train Loss 0.6411 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 018 | Train Loss 0.6352 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 019 | Train Loss 0.6439 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 020 | Train Loss 0.6435 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 12]
# [Letter-low] Epoch 021 | Train Loss 0.6393 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 21]
# [Letter-low] Epoch 022 | Train Loss 0.6103 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 21]
# [Letter-low] Epoch 023 | Train Loss 0.6013 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 21]
# [Letter-low] Epoch 024 | Train Loss 0.6014 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 21]
# [Letter-low] Epoch 025 | Train Loss 0.5706 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 21]
# [Letter-low] Epoch 026 | Train Loss 0.5949 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 26]
# [Letter-low] Epoch 027 | Train Loss 0.5656 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 26]
# [Letter-low] Epoch 028 | Train Loss 0.5627 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 26]
# [Letter-low] Epoch 029 | Train Loss 0.5482 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 26]
# [Letter-low] Epoch 030 | Train Loss 0.5825 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 031 | Train Loss 0.5563 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 032 | Train Loss 0.5545 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 033 | Train Loss 0.5454 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 034 | Train Loss 0.5798 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 035 | Train Loss 0.5449 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 036 | Train Loss 0.5272 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 037 | Train Loss 0.5845 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 038 | Train Loss 0.5438 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 30]
# [Letter-low] Epoch 039 | Train Loss 0.5541 | Val Acc 0.9703 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 040 | Train Loss 0.5114 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 041 | Train Loss 0.5386 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 042 | Train Loss 0.5707 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 043 | Train Loss 0.5666 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 044 | Train Loss 0.5217 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 045 | Train Loss 0.5466 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 046 | Train Loss 0.5213 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 39]
# [Letter-low] Epoch 047 | Train Loss 0.5049 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 47]
# [Letter-low] Epoch 048 | Train Loss 0.4421 | Val Acc 0.9653 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 47]
# [Letter-low] Epoch 049 | Train Loss 0.4639 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 49]
# [Letter-low] Epoch 050 | Train Loss 0.4839 | Val Acc 0.9703 | LR 1.0e-03 [Best Val Acc: 0.9703 @ Epoch 49]
# [Letter-low] Fold Test Acc: 0.9511
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8539 | Val Acc 0.7624 | LR 1.0e-02 [Best Val Acc: 0.7624 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1722 | Val Acc 0.8020 | LR 1.0e-02 [Best Val Acc: 0.8020 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 1.0543 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8663 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9316 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8570 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 5]
# [Letter-low] Epoch 006 | Train Loss 0.8268 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 5]
# [Letter-low] Epoch 007 | Train Loss 0.8037 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 7]
# [Letter-low] Epoch 008 | Train Loss 0.8285 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-low] Epoch 009 | Train Loss 0.7986 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 9]
# [Letter-low] Epoch 010 | Train Loss 0.7417 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.7488 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 10]
# [Letter-low] Epoch 012 | Train Loss 0.7322 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 10]
# [Letter-low] Epoch 013 | Train Loss 0.7102 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 10]
# [Letter-low] Epoch 014 | Train Loss 0.6837 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 015 | Train Loss 0.6942 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 016 | Train Loss 0.6845 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 017 | Train Loss 0.6983 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 018 | Train Loss 0.6861 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 019 | Train Loss 0.6408 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 020 | Train Loss 0.7022 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 021 | Train Loss 0.6783 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 022 | Train Loss 0.6607 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 023 | Train Loss 0.6232 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 024 | Train Loss 0.6643 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 14]
# [Letter-low] Epoch 025 | Train Loss 0.6141 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 25]
# [Letter-low] Epoch 026 | Train Loss 0.5967 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 25]
# [Letter-low] Epoch 027 | Train Loss 0.6143 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 25]
# [Letter-low] Epoch 028 | Train Loss 0.5801 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 25]
# [Letter-low] Epoch 029 | Train Loss 0.6151 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 29]
# [Letter-low] Epoch 030 | Train Loss 0.5889 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 29]
# [Letter-low] Epoch 031 | Train Loss 0.6481 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 29]
# [Letter-low] Epoch 032 | Train Loss 0.6104 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 29]
# [Letter-low] Epoch 033 | Train Loss 0.5666 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 29]
# [Letter-low] Epoch 034 | Train Loss 0.6130 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 34]
# [Letter-low] Epoch 035 | Train Loss 0.6002 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 34]
# [Letter-low] Epoch 036 | Train Loss 0.5782 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 34]
# [Letter-low] Epoch 037 | Train Loss 0.6097 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 37]
# [Letter-low] Epoch 038 | Train Loss 0.5629 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 37]
# [Letter-low] Epoch 039 | Train Loss 0.5563 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-low] Epoch 040 | Train Loss 0.5534 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-low] Epoch 041 | Train Loss 0.5472 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-low] Epoch 042 | Train Loss 0.5699 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-low] Epoch 043 | Train Loss 0.5354 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 43]
# [Letter-low] Epoch 044 | Train Loss 0.5759 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Epoch 045 | Train Loss 0.5564 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Epoch 046 | Train Loss 0.5582 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Epoch 047 | Train Loss 0.4994 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Epoch 048 | Train Loss 0.5381 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Epoch 049 | Train Loss 0.5353 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Epoch 050 | Train Loss 0.5337 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 44]
# [Letter-low] Fold Test Acc: 0.9733
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8490 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8168 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1254 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8168 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 0.9938 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.9423 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 3]
# [Letter-low] Epoch 005 | Train Loss 0.8638 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 3]
# [Letter-low] Epoch 006 | Train Loss 0.8223 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7890 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 008 | Train Loss 0.7985 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 009 | Train Loss 0.7652 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 010 | Train Loss 0.7234 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 6]
# [Letter-low] Epoch 011 | Train Loss 0.7335 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6952 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 11]
# [Letter-low] Epoch 013 | Train Loss 0.6974 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 11]
# [Letter-low] Epoch 014 | Train Loss 0.6798 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 11]
# [Letter-low] Epoch 015 | Train Loss 0.6566 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 15]
# [Letter-low] Epoch 016 | Train Loss 0.6676 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 15]
# [Letter-low] Epoch 017 | Train Loss 0.6647 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 17]
# [Letter-low] Epoch 018 | Train Loss 0.6513 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 18]
# [Letter-low] Epoch 019 | Train Loss 0.6227 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 18]
# [Letter-low] Epoch 020 | Train Loss 0.6267 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 20]
# [Letter-low] Epoch 021 | Train Loss 0.6356 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 20]
# [Letter-low] Epoch 022 | Train Loss 0.6387 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 20]
# [Letter-low] Epoch 023 | Train Loss 0.6146 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 20]
# [Letter-low] Epoch 024 | Train Loss 0.6369 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-low] Epoch 025 | Train Loss 0.5775 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 24]
# [Letter-low] Epoch 026 | Train Loss 0.6143 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 26]
# [Letter-low] Epoch 027 | Train Loss 0.6130 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 26]
# [Letter-low] Epoch 028 | Train Loss 0.5916 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 26]
# [Letter-low] Epoch 029 | Train Loss 0.5972 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 29]
# [Letter-low] Epoch 030 | Train Loss 0.5838 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 031 | Train Loss 0.5739 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 032 | Train Loss 0.5853 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 033 | Train Loss 0.5703 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 034 | Train Loss 0.5689 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 035 | Train Loss 0.5704 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 036 | Train Loss 0.5657 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 037 | Train Loss 0.5404 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 30]
# [Letter-low] Epoch 038 | Train Loss 0.4796 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 38]
# [Letter-low] Epoch 039 | Train Loss 0.5331 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 38]
# [Letter-low] Epoch 040 | Train Loss 0.5362 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 38]
# [Letter-low] Epoch 041 | Train Loss 0.5474 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9604 @ Epoch 38]
# [Letter-low] Epoch 042 | Train Loss 0.5399 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 043 | Train Loss 0.5551 | Val Acc 0.9653 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 044 | Train Loss 0.5336 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 045 | Train Loss 0.5275 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 046 | Train Loss 0.5086 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 047 | Train Loss 0.5008 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 048 | Train Loss 0.5104 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 049 | Train Loss 0.4828 | Val Acc 0.9604 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Epoch 050 | Train Loss 0.5196 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9653 @ Epoch 42]
# [Letter-low] Fold Test Acc: 0.9289
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8372 | Val Acc 0.7574 | LR 1.0e-02 [Best Val Acc: 0.7574 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1008 | Val Acc 0.8020 | LR 1.0e-02 [Best Val Acc: 0.8020 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 0.9571 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 3]
# [Letter-low] Epoch 004 | Train Loss 0.8964 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8210 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 5]
# [Letter-low] Epoch 006 | Train Loss 0.7876 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 5]
# [Letter-low] Epoch 007 | Train Loss 0.7752 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 5]
# [Letter-low] Epoch 008 | Train Loss 0.7132 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 5]
# [Letter-low] Epoch 009 | Train Loss 0.6653 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 5]
# [Letter-low] Epoch 010 | Train Loss 0.7074 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 10]
# [Letter-low] Epoch 011 | Train Loss 0.6944 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6622 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 12]
# [Letter-low] Epoch 013 | Train Loss 0.6518 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 13]
# [Letter-low] Epoch 014 | Train Loss 0.5887 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 14]
# [Letter-low] Epoch 015 | Train Loss 0.5881 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 15]
# [Letter-low] Epoch 016 | Train Loss 0.6348 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 15]
# [Letter-low] Epoch 017 | Train Loss 0.6123 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 15]
# [Letter-low] Epoch 018 | Train Loss 0.5813 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 15]
# [Letter-low] Epoch 019 | Train Loss 0.5479 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 19]
# [Letter-low] Epoch 020 | Train Loss 0.5869 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 19]
# [Letter-low] Epoch 021 | Train Loss 0.6310 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 022 | Train Loss 0.5318 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 023 | Train Loss 0.5660 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 024 | Train Loss 0.5722 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 025 | Train Loss 0.5856 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 026 | Train Loss 0.5505 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 027 | Train Loss 0.5789 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 028 | Train Loss 0.5492 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 029 | Train Loss 0.5424 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 030 | Train Loss 0.5757 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 031 | Train Loss 0.5361 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 032 | Train Loss 0.5319 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 033 | Train Loss 0.5391 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 034 | Train Loss 0.5417 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 21]
# [Letter-low] Epoch 035 | Train Loss 0.5201 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 35]
# [Letter-low] Epoch 036 | Train Loss 0.5383 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 35]
# [Letter-low] Epoch 037 | Train Loss 0.5784 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 35]
# [Letter-low] Epoch 038 | Train Loss 0.5235 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 35]
# [Letter-low] Epoch 039 | Train Loss 0.4592 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 39]
# [Letter-low] Epoch 040 | Train Loss 0.4596 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 39]
# [Letter-low] Epoch 041 | Train Loss 0.4298 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 41]
# [Letter-low] Epoch 042 | Train Loss 0.4438 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 42]
# [Letter-low] Epoch 043 | Train Loss 0.4666 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 42]
# [Letter-low] Epoch 044 | Train Loss 0.4607 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 42]
# [Letter-low] Epoch 045 | Train Loss 0.4271 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 42]
# [Letter-low] Epoch 046 | Train Loss 0.4185 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 46]
# [Letter-low] Epoch 047 | Train Loss 0.4393 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9604 @ Epoch 47]
# [Letter-low] Epoch 048 | Train Loss 0.4423 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9604 @ Epoch 47]
# [Letter-low] Epoch 049 | Train Loss 0.4236 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9604 @ Epoch 49]
# [Letter-low] Epoch 050 | Train Loss 0.4543 | Val Acc 0.9604 | LR 1.0e-03 [Best Val Acc: 0.9604 @ Epoch 49]
# [Letter-low] Fold Test Acc: 0.9289
#
# number of qubits 4
# number of nodes 8
# number of features 2
# train_feats shape: torch.Size([1823, 16])
# train_phases shape: torch.Size([1823, 4, 4])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1103
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-low] Epoch 001 | Train Loss 1.8403 | Val Acc 0.7079 | LR 1.0e-02 [Best Val Acc: 0.7079 @ Epoch 1]
# [Letter-low] Epoch 002 | Train Loss 1.1425 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 2]
# [Letter-low] Epoch 003 | Train Loss 0.9926 | Val Acc 0.8465 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 2]
# [Letter-low] Epoch 004 | Train Loss 0.9107 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 4]
# [Letter-low] Epoch 005 | Train Loss 0.8691 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 4]
# [Letter-low] Epoch 006 | Train Loss 0.7875 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 6]
# [Letter-low] Epoch 007 | Train Loss 0.7911 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 6]
# [Letter-low] Epoch 008 | Train Loss 0.8078 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 6]
# [Letter-low] Epoch 009 | Train Loss 0.7560 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 6]
# [Letter-low] Epoch 010 | Train Loss 0.7068 | Val Acc 0.8465 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 6]
# [Letter-low] Epoch 011 | Train Loss 0.7016 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 012 | Train Loss 0.6642 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 013 | Train Loss 0.6918 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 014 | Train Loss 0.6394 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 015 | Train Loss 0.6490 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 016 | Train Loss 0.6230 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 017 | Train Loss 0.6296 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 018 | Train Loss 0.6391 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 11]
# [Letter-low] Epoch 019 | Train Loss 0.5791 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-low] Epoch 020 | Train Loss 0.6399 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-low] Epoch 021 | Train Loss 0.6253 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-low] Epoch 022 | Train Loss 0.6154 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9406 @ Epoch 22]
# [Letter-low] Epoch 023 | Train Loss 0.5883 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 23]
# [Letter-low] Epoch 024 | Train Loss 0.6050 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 23]
# [Letter-low] Epoch 025 | Train Loss 0.6152 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 23]
# [Letter-low] Epoch 026 | Train Loss 0.6147 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 23]
# [Letter-low] Epoch 027 | Train Loss 0.5829 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 23]
# [Letter-low] Epoch 028 | Train Loss 0.5841 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 029 | Train Loss 0.5993 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 030 | Train Loss 0.5607 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 031 | Train Loss 0.5706 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 032 | Train Loss 0.5851 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 033 | Train Loss 0.5623 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 034 | Train Loss 0.5687 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 035 | Train Loss 0.5777 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 28]
# [Letter-low] Epoch 036 | Train Loss 0.5287 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 36]
# [Letter-low] Epoch 037 | Train Loss 0.5711 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 36]
# [Letter-low] Epoch 038 | Train Loss 0.5616 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 36]
# [Letter-low] Epoch 039 | Train Loss 0.5695 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 36]
# [Letter-low] Epoch 040 | Train Loss 0.4968 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 40]
# [Letter-low] Epoch 041 | Train Loss 0.5016 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 40]
# [Letter-low] Epoch 042 | Train Loss 0.4873 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 42]
# [Letter-low] Epoch 043 | Train Loss 0.4912 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 42]
# [Letter-low] Epoch 044 | Train Loss 0.5059 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 42]
# [Letter-low] Epoch 045 | Train Loss 0.4508 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9505 @ Epoch 45]
# [Letter-low] Epoch 046 | Train Loss 0.4564 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 46]
# [Letter-low] Epoch 047 | Train Loss 0.4293 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 46]
# [Letter-low] Epoch 048 | Train Loss 0.4473 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 46]
# [Letter-low] Epoch 049 | Train Loss 0.4563 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 46]
# [Letter-low] Epoch 050 | Train Loss 0.4439 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 46]
# [Letter-low] Fold Test Acc: 0.9689
#
#
# === Cross-Validation Results for Letter-low ===
# Per-fold Accuracies: [0.9644444444444444, 0.9377777777777778, 0.9466666666666667, 0.9377777777777778, 0.9333333333333333, 0.9511111111111111, 0.9733333333333334, 0.9288888888888889, 0.9288888888888889, 0.9688888888888889]
# Mean Test Acc: 0.9471 ± 0.0158
