# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'DHFR',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [32,64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'DHFR', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/DHFR.zip
# Processing...
# Done!
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([612, 4096])
# train_phases shape: torch.Size([612, 12, 12])
# train_labs shape: torch.Size([612])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6650 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5525 | Val Acc 0.6176 | LR 1.0e-02 [Best Val Acc: 0.6176 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4886 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.6471 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4405 | Val Acc 0.6324 | LR 1.0e-02 [Best Val Acc: 0.6471 @ Epoch 3]
# [DHFR] Epoch 005 | Train Loss 0.4104 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.6618 @ Epoch 5]
# [DHFR] Epoch 006 | Train Loss 0.3757 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.6912 @ Epoch 6]
# [DHFR] Epoch 007 | Train Loss 0.3765 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 7]
# [DHFR] Epoch 008 | Train Loss 0.3048 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 7]
# [DHFR] Epoch 009 | Train Loss 0.2900 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 9]
# [DHFR] Epoch 010 | Train Loss 0.2643 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 9]
# [DHFR] Epoch 011 | Train Loss 0.3032 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 9]
# [DHFR] Epoch 012 | Train Loss 0.2749 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 12]
# [DHFR] Epoch 013 | Train Loss 0.2636 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 12]
# [DHFR] Epoch 014 | Train Loss 0.2784 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 12]
# [DHFR] Epoch 015 | Train Loss 0.2686 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 12]
# [DHFR] Epoch 016 | Train Loss 0.2244 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 017 | Train Loss 0.2264 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 018 | Train Loss 0.2153 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 019 | Train Loss 0.2247 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 020 | Train Loss 0.2087 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 021 | Train Loss 0.2165 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 022 | Train Loss 0.2106 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 023 | Train Loss 0.1692 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 16]
# [DHFR] Epoch 024 | Train Loss 0.2176 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 025 | Train Loss 0.1969 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 026 | Train Loss 0.1864 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 027 | Train Loss 0.1862 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 028 | Train Loss 0.1755 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 029 | Train Loss 0.1508 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 030 | Train Loss 0.1529 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 24]
# [DHFR] Epoch 031 | Train Loss 0.1701 | Val Acc 0.8529 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 032 | Train Loss 0.1990 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 033 | Train Loss 0.1465 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 034 | Train Loss 0.1505 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 035 | Train Loss 0.2098 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 036 | Train Loss 0.1917 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 037 | Train Loss 0.1356 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 038 | Train Loss 0.1473 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 039 | Train Loss 0.1912 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 040 | Train Loss 0.1664 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 041 | Train Loss 0.1577 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 042 | Train Loss 0.1562 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 043 | Train Loss 0.1845 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 044 | Train Loss 0.1812 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# [DHFR] Epoch 045 | Train Loss 0.1404 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 31]
# Early stop @ epoch 46 | Best val_acc=0.8529
# [DHFR] Fold Test Acc: 0.7368
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([612, 4096])
# train_phases shape: torch.Size([612, 12, 12])
# train_labs shape: torch.Size([612])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6698 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5537 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.6618 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.5124 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.6912 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4716 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [DHFR] Epoch 005 | Train Loss 0.4047 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [DHFR] Epoch 006 | Train Loss 0.3979 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 6]
# [DHFR] Epoch 007 | Train Loss 0.3483 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 7]
# [DHFR] Epoch 008 | Train Loss 0.3584 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 7]
# [DHFR] Epoch 009 | Train Loss 0.2933 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 7]
# [DHFR] Epoch 010 | Train Loss 0.2903 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 10]
# [DHFR] Epoch 011 | Train Loss 0.2531 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 10]
# [DHFR] Epoch 012 | Train Loss 0.2957 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 10]
# [DHFR] Epoch 013 | Train Loss 0.2461 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 13]
# [DHFR] Epoch 014 | Train Loss 0.2219 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 13]
# [DHFR] Epoch 015 | Train Loss 0.2080 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 13]
# [DHFR] Epoch 016 | Train Loss 0.2121 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 13]
# [DHFR] Epoch 017 | Train Loss 0.2001 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 13]
# [DHFR] Epoch 018 | Train Loss 0.2656 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 13]
# [DHFR] Epoch 019 | Train Loss 0.2309 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 020 | Train Loss 0.2105 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 021 | Train Loss 0.1589 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 022 | Train Loss 0.2091 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 023 | Train Loss 0.1571 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 024 | Train Loss 0.1876 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 025 | Train Loss 0.1626 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 026 | Train Loss 0.1778 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 027 | Train Loss 0.1983 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 19]
# [DHFR] Epoch 028 | Train Loss 0.1689 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 029 | Train Loss 0.1745 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 030 | Train Loss 0.1949 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 031 | Train Loss 0.1809 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 032 | Train Loss 0.1727 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 033 | Train Loss 0.1536 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 034 | Train Loss 0.1454 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 035 | Train Loss 0.1798 | Val Acc 0.7353 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 036 | Train Loss 0.0962 | Val Acc 0.7647 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 037 | Train Loss 0.0832 | Val Acc 0.7794 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 038 | Train Loss 0.0609 | Val Acc 0.7794 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 039 | Train Loss 0.0738 | Val Acc 0.7941 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 040 | Train Loss 0.0829 | Val Acc 0.7794 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 041 | Train Loss 0.0689 | Val Acc 0.7794 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# [DHFR] Epoch 042 | Train Loss 0.0845 | Val Acc 0.7794 | LR 1.0e-03 [Best Val Acc: 0.8235 @ Epoch 28]
# Early stop @ epoch 43 | Best val_acc=0.8235
# [DHFR] Fold Test Acc: 0.6842
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([612, 4096])
# train_phases shape: torch.Size([612, 12, 12])
# train_labs shape: torch.Size([612])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6405 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5463 | Val Acc 0.6324 | LR 1.0e-02 [Best Val Acc: 0.6324 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4839 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4541 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 3]
# [DHFR] Epoch 005 | Train Loss 0.4127 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 3]
# [DHFR] Epoch 006 | Train Loss 0.3743 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 3]
# [DHFR] Epoch 007 | Train Loss 0.3579 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 7]
# [DHFR] Epoch 008 | Train Loss 0.3730 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 7]
# [DHFR] Epoch 009 | Train Loss 0.3069 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 9]
# [DHFR] Epoch 010 | Train Loss 0.3322 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 011 | Train Loss 0.2893 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 012 | Train Loss 0.3062 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 013 | Train Loss 0.2538 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 014 | Train Loss 0.2684 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 015 | Train Loss 0.2152 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 016 | Train Loss 0.2302 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 017 | Train Loss 0.2224 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 018 | Train Loss 0.2680 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 019 | Train Loss 0.2590 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 020 | Train Loss 0.2319 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 021 | Train Loss 0.2107 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 022 | Train Loss 0.1883 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 023 | Train Loss 0.1938 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 024 | Train Loss 0.1940 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# Early stop @ epoch 25 | Best val_acc=0.8088
# [DHFR] Fold Test Acc: 0.6711
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([612, 4096])
# train_phases shape: torch.Size([612, 12, 12])
# train_labs shape: torch.Size([612])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6469 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5172 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.6618 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4966 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4517 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 005 | Train Loss 0.3781 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 5]
# [DHFR] Epoch 006 | Train Loss 0.3471 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 5]
# [DHFR] Epoch 007 | Train Loss 0.3378 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 5]
# [DHFR] Epoch 008 | Train Loss 0.3508 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 8]
# [DHFR] Epoch 009 | Train Loss 0.2859 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 8]
# [DHFR] Epoch 010 | Train Loss 0.2956 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 011 | Train Loss 0.2882 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 10]
# [DHFR] Epoch 012 | Train Loss 0.2915 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 12]
# [DHFR] Epoch 013 | Train Loss 0.2420 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 12]
# [DHFR] Epoch 014 | Train Loss 0.2426 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 12]
# [DHFR] Epoch 015 | Train Loss 0.2416 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 15]
# [DHFR] Epoch 016 | Train Loss 0.2362 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 16]
# [DHFR] Epoch 017 | Train Loss 0.1953 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 16]
# [DHFR] Epoch 018 | Train Loss 0.2760 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 16]
# [DHFR] Epoch 019 | Train Loss 0.2316 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 16]
# [DHFR] Epoch 020 | Train Loss 0.2289 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8088 @ Epoch 16]
# [DHFR] Epoch 021 | Train Loss 0.1989 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 21]
# [DHFR] Epoch 022 | Train Loss 0.1746 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 22]
# [DHFR] Epoch 023 | Train Loss 0.2529 | Val Acc 0.8529 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 23]
# [DHFR] Epoch 024 | Train Loss 0.1856 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 23]
# [DHFR] Epoch 025 | Train Loss 0.1864 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 23]
# [DHFR] Epoch 026 | Train Loss 0.1581 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 23]
# [DHFR] Epoch 027 | Train Loss 0.1663 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 23]
# [DHFR] Epoch 028 | Train Loss 0.1805 | Val Acc 0.8529 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 029 | Train Loss 0.2142 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 030 | Train Loss 0.1829 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 031 | Train Loss 0.2110 | Val Acc 0.8382 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 032 | Train Loss 0.1651 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 033 | Train Loss 0.1461 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 034 | Train Loss 0.2102 | Val Acc 0.8382 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 035 | Train Loss 0.1966 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 036 | Train Loss 0.1656 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 037 | Train Loss 0.1242 | Val Acc 0.8088 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 038 | Train Loss 0.1951 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 039 | Train Loss 0.1790 | Val Acc 0.8088 | LR 1.0e-03 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 040 | Train Loss 0.1710 | Val Acc 0.8088 | LR 1.0e-03 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 041 | Train Loss 0.1147 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8529 @ Epoch 28]
# [DHFR] Epoch 042 | Train Loss 0.1087 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8529 @ Epoch 28]
# Early stop @ epoch 43 | Best val_acc=0.8529
# [DHFR] Fold Test Acc: 0.7368
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([612, 4096])
# train_phases shape: torch.Size([612, 12, 12])
# train_labs shape: torch.Size([612])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6479 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5401 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4990 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.6618 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4583 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 4]
# [DHFR] Epoch 005 | Train Loss 0.3840 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 006 | Train Loss 0.3839 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 007 | Train Loss 0.3811 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 008 | Train Loss 0.3267 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 009 | Train Loss 0.2783 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 010 | Train Loss 0.2847 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 011 | Train Loss 0.2941 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 012 | Train Loss 0.2580 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 013 | Train Loss 0.2331 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 014 | Train Loss 0.2462 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 015 | Train Loss 0.2220 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 016 | Train Loss 0.1694 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 017 | Train Loss 0.2223 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 018 | Train Loss 0.2656 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 019 | Train Loss 0.2277 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 020 | Train Loss 0.2268 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 021 | Train Loss 0.1811 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 022 | Train Loss 0.1853 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 023 | Train Loss 0.1716 | Val Acc 0.6176 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 024 | Train Loss 0.1813 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 025 | Train Loss 0.1910 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 026 | Train Loss 0.1905 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 027 | Train Loss 0.2174 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 14]
# [DHFR] Epoch 028 | Train Loss 0.1343 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 28]
# [DHFR] Epoch 029 | Train Loss 0.1472 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 29]
# [DHFR] Epoch 030 | Train Loss 0.1873 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 29]
# [DHFR] Epoch 031 | Train Loss 0.1959 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 29]
# [DHFR] Epoch 032 | Train Loss 0.2037 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 29]
# [DHFR] Epoch 033 | Train Loss 0.1479 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 29]
# [DHFR] Epoch 034 | Train Loss 0.1648 | Val Acc 0.7941 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 035 | Train Loss 0.1464 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 036 | Train Loss 0.1064 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 037 | Train Loss 0.1248 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 038 | Train Loss 0.1465 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 039 | Train Loss 0.1485 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 040 | Train Loss 0.1618 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 041 | Train Loss 0.1697 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 042 | Train Loss 0.1631 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 043 | Train Loss 0.1228 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 044 | Train Loss 0.1148 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 045 | Train Loss 0.1427 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 046 | Train Loss 0.1508 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 047 | Train Loss 0.1338 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# [DHFR] Epoch 048 | Train Loss 0.1249 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7941 @ Epoch 34]
# Early stop @ epoch 49 | Best val_acc=0.7941
# [DHFR] Fold Test Acc: 0.6974
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([612, 4096])
# train_phases shape: torch.Size([612, 12, 12])
# train_labs shape: torch.Size([612])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6547 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5241 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.5105 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 004 | Train Loss 0.4599 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 005 | Train Loss 0.4051 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 006 | Train Loss 0.3667 | Val Acc 0.6324 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 007 | Train Loss 0.3535 | Val Acc 0.6324 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 008 | Train Loss 0.3259 | Val Acc 0.6324 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 009 | Train Loss 0.2665 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 010 | Train Loss 0.3177 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [DHFR] Epoch 011 | Train Loss 0.2903 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 11]
# [DHFR] Epoch 012 | Train Loss 0.2512 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 013 | Train Loss 0.2466 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 014 | Train Loss 0.2752 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 015 | Train Loss 0.2242 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 016 | Train Loss 0.2189 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 017 | Train Loss 0.2192 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 018 | Train Loss 0.2569 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 019 | Train Loss 0.2099 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 020 | Train Loss 0.2124 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 021 | Train Loss 0.1957 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 022 | Train Loss 0.1937 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 023 | Train Loss 0.1825 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 024 | Train Loss 0.2051 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 025 | Train Loss 0.2417 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 12]
# [DHFR] Epoch 026 | Train Loss 0.2055 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 027 | Train Loss 0.1934 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 028 | Train Loss 0.1780 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 029 | Train Loss 0.1957 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 030 | Train Loss 0.1921 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 031 | Train Loss 0.2142 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 032 | Train Loss 0.1776 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 033 | Train Loss 0.1443 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 034 | Train Loss 0.2121 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 035 | Train Loss 0.1696 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 036 | Train Loss 0.1268 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 037 | Train Loss 0.1097 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 038 | Train Loss 0.1407 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 039 | Train Loss 0.2081 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# [DHFR] Epoch 040 | Train Loss 0.1769 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 26]
# Early stop @ epoch 41 | Best val_acc=0.7500
# [DHFR] Fold Test Acc: 0.8158
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([613, 4096])
# train_phases shape: torch.Size([613, 12, 12])
# train_labs shape: torch.Size([613])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6354 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5156 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4474 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4004 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 4]
# [DHFR] Epoch 005 | Train Loss 0.3598 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 006 | Train Loss 0.3302 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 6]
# [DHFR] Epoch 007 | Train Loss 0.3080 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 6]
# [DHFR] Epoch 008 | Train Loss 0.2999 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 6]
# [DHFR] Epoch 009 | Train Loss 0.2941 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 010 | Train Loss 0.2716 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 011 | Train Loss 0.2424 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 012 | Train Loss 0.2700 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 013 | Train Loss 0.2395 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 014 | Train Loss 0.2772 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 015 | Train Loss 0.2196 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 016 | Train Loss 0.2000 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 017 | Train Loss 0.2155 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 018 | Train Loss 0.2087 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 019 | Train Loss 0.2263 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 020 | Train Loss 0.2003 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 021 | Train Loss 0.1895 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 022 | Train Loss 0.2033 | Val Acc 0.6912 | LR 1.0e-03 [Best Val Acc: 0.7500 @ Epoch 9]
# [DHFR] Epoch 023 | Train Loss 0.1857 | Val Acc 0.7059 | LR 1.0e-03 [Best Val Acc: 0.7500 @ Epoch 9]
# Early stop @ epoch 24 | Best val_acc=0.7500
# [DHFR] Fold Test Acc: 0.6933
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([613, 4096])
# train_phases shape: torch.Size([613, 12, 12])
# train_labs shape: torch.Size([613])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6403 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5161 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4794 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.6765 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4150 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 4]
# [DHFR] Epoch 005 | Train Loss 0.3589 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 006 | Train Loss 0.3530 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 007 | Train Loss 0.3404 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7353 @ Epoch 5]
# [DHFR] Epoch 008 | Train Loss 0.3158 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 009 | Train Loss 0.2864 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 010 | Train Loss 0.2898 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 011 | Train Loss 0.2629 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 012 | Train Loss 0.2527 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 013 | Train Loss 0.2476 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 014 | Train Loss 0.2648 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 015 | Train Loss 0.2577 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 016 | Train Loss 0.2413 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 8]
# [DHFR] Epoch 017 | Train Loss 0.2429 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 018 | Train Loss 0.2510 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 019 | Train Loss 0.2172 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 020 | Train Loss 0.2184 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 021 | Train Loss 0.2106 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 022 | Train Loss 0.2473 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 023 | Train Loss 0.2356 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 024 | Train Loss 0.2174 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 025 | Train Loss 0.1625 | Val Acc 0.7353 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 026 | Train Loss 0.1338 | Val Acc 0.7353 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 027 | Train Loss 0.1568 | Val Acc 0.7647 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 028 | Train Loss 0.1026 | Val Acc 0.7647 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 029 | Train Loss 0.1032 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 030 | Train Loss 0.0984 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# [DHFR] Epoch 031 | Train Loss 0.0917 | Val Acc 0.7353 | LR 1.0e-03 [Best Val Acc: 0.7794 @ Epoch 17]
# Early stop @ epoch 32 | Best val_acc=0.7794
# [DHFR] Fold Test Acc: 0.8133
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([613, 4096])
# train_phases shape: torch.Size([613, 12, 12])
# train_labs shape: torch.Size([613])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6361 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5389 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.5001 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.6912 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4501 | Val Acc 0.7794 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 005 | Train Loss 0.4307 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 006 | Train Loss 0.3901 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 007 | Train Loss 0.3543 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 008 | Train Loss 0.3397 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 009 | Train Loss 0.3273 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 010 | Train Loss 0.3232 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 011 | Train Loss 0.3179 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 012 | Train Loss 0.2686 | Val Acc 0.6324 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 013 | Train Loss 0.2765 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 014 | Train Loss 0.2794 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 015 | Train Loss 0.2577 | Val Acc 0.6765 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 016 | Train Loss 0.2592 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 017 | Train Loss 0.2368 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# [DHFR] Epoch 018 | Train Loss 0.2401 | Val Acc 0.6618 | LR 1.0e-02 [Best Val Acc: 0.7794 @ Epoch 4]
# Early stop @ epoch 19 | Best val_acc=0.7794
# [DHFR] Fold Test Acc: 0.7600
#
# number of qubits 12
# number of nodes 71
# number of features 56
# train_feats shape: torch.Size([613, 4096])
# train_phases shape: torch.Size([613, 12, 12])
# train_labs shape: torch.Size([613])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [DHFR] Epoch 001 | Train Loss 0.6332 | Val Acc 0.6029 | LR 1.0e-02 [Best Val Acc: 0.6029 @ Epoch 1]
# [DHFR] Epoch 002 | Train Loss 0.5116 | Val Acc 0.6176 | LR 1.0e-02 [Best Val Acc: 0.6176 @ Epoch 2]
# [DHFR] Epoch 003 | Train Loss 0.4900 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 3]
# [DHFR] Epoch 004 | Train Loss 0.4277 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7206 @ Epoch 3]
# [DHFR] Epoch 005 | Train Loss 0.3802 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 006 | Train Loss 0.3849 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 007 | Train Loss 0.3550 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 008 | Train Loss 0.3200 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 009 | Train Loss 0.3107 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 010 | Train Loss 0.3109 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 011 | Train Loss 0.2871 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 012 | Train Loss 0.2778 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 013 | Train Loss 0.2606 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 014 | Train Loss 0.2395 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 015 | Train Loss 0.2243 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 016 | Train Loss 0.2691 | Val Acc 0.7353 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 017 | Train Loss 0.2379 | Val Acc 0.6912 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 018 | Train Loss 0.2782 | Val Acc 0.7206 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# [DHFR] Epoch 019 | Train Loss 0.2801 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 5]
# Early stop @ epoch 20 | Best val_acc=0.7647
# [DHFR] Fold Test Acc: 0.7867
#
#
# === Cross-Validation Results for DHFR ===
# Per-fold Accuracies: [0.7368421052631579, 0.6842105263157895, 0.6710526315789473, 0.7368421052631579, 0.6973684210526315, 0.8157894736842105, 0.6933333333333334, 0.8133333333333334, 0.76, 0.7866666666666666]
# Mean Test Acc: 0.7395 ± 0.0506

# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'ENZYMES',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [32,64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'ENZYMES', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/ENZYMES.zip
# Processing...
# Done!
# number of qubits 12
# number of nodes 126
# number of features 21
# train_feats shape: torch.Size([486, 4096])
# train_phases shape: torch.Size([486, 12, 12])
# train_labs shape: torch.Size([486])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=6, bias=True)
#   )
# )
# Number of parameters: 1718
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/miniconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [ENZYMES] Epoch 001 | Train Loss 1.7970 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 1]
# [ENZYMES] Epoch 002 | Train Loss 1.7103 | Val Acc 0.1667 | LR 1.0e-02 [Best Val Acc: 0.1667 @ Epoch 2]
# [ENZYMES] Epoch 003 | Train Loss 1.6510 | Val Acc 0.2222 | LR 1.0e-02 [Best Val Acc: 0.2222 @ Epoch 3]
# [ENZYMES] Epoch 004 | Train Loss 1.5967 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.3519 @ Epoch 4]
# [ENZYMES] Epoch 005 | Train Loss 1.5219 | Val Acc 0.3704 | LR 1.0e-02 [Best Val Acc: 0.3704 @ Epoch 5]
# [ENZYMES] Epoch 006 | Train Loss 1.5081 | Val Acc 0.4259 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 007 | Train Loss 1.4652 | Val Acc 0.3519 | LR 1.0e-02 [Best Val Acc: 0.4259 @ Epoch 6]
# [ENZYMES] Epoch 008 | Train Loss 1.4541 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 009 | Train Loss 1.4344 | Val Acc 0.3333 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 8]
# [ENZYMES] Epoch 010 | Train Loss 1.3950 | Val Acc 0.4444 | LR 1.0e-02 [Best Val Acc: 0.4444 @ Epoch 10]
