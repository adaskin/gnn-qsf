# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=200,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'Letter-med',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [128, 64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 32,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'Letter-med', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 32, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# [Letter-med] Epoch 001 | Train Loss 1.9582 | Val Acc 0.7129 | LR 1.0e-02 [Best Val Acc: 0.7129 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2345 | Val Acc 0.8069 | LR 1.0e-02 [Best Val Acc: 0.8069 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0463 | Val Acc 0.8119 | LR 1.0e-02 [Best Val Acc: 0.8119 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9169 | Val Acc 0.8465 | LR 1.0e-02 [Best Val Acc: 0.8465 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.8876 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8663 @ Epoch 5]
# [Letter-med] Epoch 006 | Train Loss 0.8499 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 6]
# [Letter-med] Epoch 007 | Train Loss 0.8048 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 6]
# [Letter-med] Epoch 008 | Train Loss 0.7596 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 8]
# [Letter-med] Epoch 009 | Train Loss 0.7409 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 8]
# [Letter-med] Epoch 010 | Train Loss 0.7256 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 8]
# [Letter-med] Epoch 011 | Train Loss 0.7065 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 8]
# [Letter-med] Epoch 012 | Train Loss 0.6991 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 12]
# [Letter-med] Epoch 013 | Train Loss 0.6887 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 13]
# [Letter-med] Epoch 014 | Train Loss 0.6365 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 13]
# [Letter-med] Epoch 015 | Train Loss 0.6422 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 13]
# [Letter-med] Epoch 016 | Train Loss 0.6458 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 13]
# [Letter-med] Epoch 017 | Train Loss 0.6141 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 13]
# [Letter-med] Epoch 018 | Train Loss 0.6423 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 13]
# [Letter-med] Epoch 019 | Train Loss 0.6565 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 19]
# [Letter-med] Epoch 020 | Train Loss 0.6602 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 19]
# [Letter-med] Epoch 021 | Train Loss 0.6109 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 19]
# [Letter-med] Epoch 022 | Train Loss 0.5914 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 19]
# [Letter-med] Epoch 023 | Train Loss 0.6089 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 19]
# [Letter-med] Epoch 024 | Train Loss 0.6114 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 24]
# [Letter-med] Epoch 025 | Train Loss 0.6294 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 24]
# [Letter-med] Epoch 026 | Train Loss 0.5954 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 24]
# [Letter-med] Epoch 027 | Train Loss 0.6053 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 028 | Train Loss 0.6332 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 029 | Train Loss 0.6021 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 030 | Train Loss 0.5980 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 031 | Train Loss 0.5684 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 032 | Train Loss 0.6121 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 033 | Train Loss 0.5983 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 034 | Train Loss 0.5782 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 035 | Train Loss 0.5791 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 036 | Train Loss 0.5591 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 037 | Train Loss 0.5953 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 038 | Train Loss 0.5816 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 039 | Train Loss 0.5783 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 31]
# [Letter-med] Epoch 040 | Train Loss 0.5611 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 041 | Train Loss 0.5863 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 042 | Train Loss 0.6194 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 043 | Train Loss 0.6251 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 044 | Train Loss 0.5939 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 045 | Train Loss 0.6094 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 046 | Train Loss 0.5441 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 047 | Train Loss 0.5795 | Val Acc 0.9010 | LR 1.0e-03 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 048 | Train Loss 0.5136 | Val Acc 0.9059 | LR 1.0e-03 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 049 | Train Loss 0.5233 | Val Acc 0.9010 | LR 1.0e-03 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Epoch 050 | Train Loss 0.4960 | Val Acc 0.9010 | LR 1.0e-03 [Best Val Acc: 0.9109 @ Epoch 40]
# [Letter-med] Fold Test Acc: 0.9289
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9585 | Val Acc 0.6485 | LR 1.0e-02 [Best Val Acc: 0.6485 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2660 | Val Acc 0.7426 | LR 1.0e-02 [Best Val Acc: 0.7426 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0749 | Val Acc 0.8020 | LR 1.0e-02 [Best Val Acc: 0.8020 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9543 | Val Acc 0.8416 | LR 1.0e-02 [Best Val Acc: 0.8416 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.8842 | Val Acc 0.7871 | LR 1.0e-02 [Best Val Acc: 0.8416 @ Epoch 4]
# [Letter-med] Epoch 006 | Train Loss 0.9009 | Val Acc 0.8317 | LR 1.0e-02 [Best Val Acc: 0.8416 @ Epoch 4]
# [Letter-med] Epoch 007 | Train Loss 0.8365 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.7805 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 8]
# [Letter-med] Epoch 009 | Train Loss 0.7843 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 9]
# [Letter-med] Epoch 010 | Train Loss 0.7865 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 9]
# [Letter-med] Epoch 011 | Train Loss 0.7201 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 9]
# [Letter-med] Epoch 012 | Train Loss 0.6726 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 9]
# [Letter-med] Epoch 013 | Train Loss 0.7500 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 13]
# [Letter-med] Epoch 014 | Train Loss 0.6907 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 14]
# [Letter-med] Epoch 015 | Train Loss 0.7003 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 15]
# [Letter-med] Epoch 016 | Train Loss 0.6714 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 15]
# [Letter-med] Epoch 017 | Train Loss 0.6617 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 17]
# [Letter-med] Epoch 018 | Train Loss 0.6483 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 17]
# [Letter-med] Epoch 019 | Train Loss 0.6674 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 17]
# [Letter-med] Epoch 020 | Train Loss 0.6977 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 17]
# [Letter-med] Epoch 021 | Train Loss 0.6086 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 17]
# [Letter-med] Epoch 022 | Train Loss 0.6290 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 22]
# [Letter-med] Epoch 023 | Train Loss 0.6134 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 22]
# [Letter-med] Epoch 024 | Train Loss 0.6640 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 22]
# [Letter-med] Epoch 025 | Train Loss 0.5755 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 22]
# [Letter-med] Epoch 026 | Train Loss 0.5946 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 027 | Train Loss 0.6511 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 028 | Train Loss 0.6627 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 029 | Train Loss 0.5987 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 030 | Train Loss 0.6184 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 031 | Train Loss 0.6313 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 032 | Train Loss 0.6112 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 26]
# [Letter-med] Epoch 033 | Train Loss 0.5822 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 034 | Train Loss 0.5966 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 035 | Train Loss 0.6171 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 036 | Train Loss 0.6157 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 037 | Train Loss 0.5956 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 038 | Train Loss 0.5846 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 039 | Train Loss 0.5581 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 040 | Train Loss 0.5769 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 33]
# [Letter-med] Epoch 041 | Train Loss 0.5695 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 042 | Train Loss 0.6159 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 043 | Train Loss 0.5983 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 044 | Train Loss 0.5997 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 045 | Train Loss 0.6355 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 046 | Train Loss 0.5737 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 047 | Train Loss 0.6190 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 048 | Train Loss 0.5699 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 049 | Train Loss 0.5843 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Epoch 050 | Train Loss 0.5126 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9356 @ Epoch 41]
# [Letter-med] Fold Test Acc: 0.9467
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9643 | Val Acc 0.6584 | LR 1.0e-02 [Best Val Acc: 0.6584 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2928 | Val Acc 0.6832 | LR 1.0e-02 [Best Val Acc: 0.6832 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.1223 | Val Acc 0.7772 | LR 1.0e-02 [Best Val Acc: 0.7772 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9983 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.9405 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 4]
# [Letter-med] Epoch 006 | Train Loss 0.8850 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 4]
# [Letter-med] Epoch 007 | Train Loss 0.8739 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.8369 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 8]
# [Letter-med] Epoch 009 | Train Loss 0.8070 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 8]
# [Letter-med] Epoch 010 | Train Loss 0.8064 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 8]
# [Letter-med] Epoch 011 | Train Loss 0.7631 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 8]
# [Letter-med] Epoch 012 | Train Loss 0.7459 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 8]
# [Letter-med] Epoch 013 | Train Loss 0.7438 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 014 | Train Loss 0.7052 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 14]
# [Letter-med] Epoch 015 | Train Loss 0.6648 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 14]
# [Letter-med] Epoch 016 | Train Loss 0.7359 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 14]
# [Letter-med] Epoch 017 | Train Loss 0.6655 | Val Acc 0.8366 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 14]
# [Letter-med] Epoch 018 | Train Loss 0.6747 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 18]
# [Letter-med] Epoch 019 | Train Loss 0.6579 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 19]
# [Letter-med] Epoch 020 | Train Loss 0.6912 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 19]
# [Letter-med] Epoch 021 | Train Loss 0.6422 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 19]
# [Letter-med] Epoch 022 | Train Loss 0.6321 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 19]
# [Letter-med] Epoch 023 | Train Loss 0.6093 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9109 @ Epoch 23]
# [Letter-med] Epoch 024 | Train Loss 0.6695 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 24]
# [Letter-med] Epoch 025 | Train Loss 0.6253 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 24]
# [Letter-med] Epoch 026 | Train Loss 0.5680 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 24]
# [Letter-med] Epoch 027 | Train Loss 0.6290 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 24]
# [Letter-med] Epoch 028 | Train Loss 0.6616 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 24]
# [Letter-med] Epoch 029 | Train Loss 0.6204 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 24]
# [Letter-med] Epoch 030 | Train Loss 0.6063 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 031 | Train Loss 0.5968 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 032 | Train Loss 0.6213 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 033 | Train Loss 0.6112 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 034 | Train Loss 0.6294 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 035 | Train Loss 0.6077 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 036 | Train Loss 0.6139 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 037 | Train Loss 0.5832 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 038 | Train Loss 0.5766 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 039 | Train Loss 0.5567 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 040 | Train Loss 0.5389 | Val Acc 0.9109 | LR 1.0e-03 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 041 | Train Loss 0.5764 | Val Acc 0.9109 | LR 1.0e-03 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 042 | Train Loss 0.5499 | Val Acc 0.9059 | LR 1.0e-03 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 043 | Train Loss 0.5348 | Val Acc 0.9010 | LR 1.0e-03 [Best Val Acc: 0.9208 @ Epoch 30]
# [Letter-med] Epoch 044 | Train Loss 0.5426 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 44]
# [Letter-med] Epoch 045 | Train Loss 0.5572 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 44]
# [Letter-med] Epoch 046 | Train Loss 0.5023 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 44]
# [Letter-med] Epoch 047 | Train Loss 0.5202 | Val Acc 0.9109 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 44]
# [Letter-med] Epoch 048 | Train Loss 0.4923 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 44]
# [Letter-med] Epoch 049 | Train Loss 0.5182 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 44]
# [Letter-med] Epoch 050 | Train Loss 0.4780 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9257 @ Epoch 50]
# [Letter-med] Fold Test Acc: 0.9333
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9490 | Val Acc 0.6980 | LR 1.0e-02 [Best Val Acc: 0.6980 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2426 | Val Acc 0.7574 | LR 1.0e-02 [Best Val Acc: 0.7574 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0742 | Val Acc 0.8416 | LR 1.0e-02 [Best Val Acc: 0.8416 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9778 | Val Acc 0.8465 | LR 1.0e-02 [Best Val Acc: 0.8465 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.9006 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 5]
# [Letter-med] Epoch 006 | Train Loss 0.8884 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 6]
# [Letter-med] Epoch 007 | Train Loss 0.8305 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.7521 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 7]
# [Letter-med] Epoch 009 | Train Loss 0.7722 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 7]
# [Letter-med] Epoch 010 | Train Loss 0.7389 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 011 | Train Loss 0.6805 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 012 | Train Loss 0.6999 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 013 | Train Loss 0.7126 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 014 | Train Loss 0.6922 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 015 | Train Loss 0.6660 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 016 | Train Loss 0.6843 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 017 | Train Loss 0.6237 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 018 | Train Loss 0.6180 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 019 | Train Loss 0.6516 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 020 | Train Loss 0.6501 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 021 | Train Loss 0.6503 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 022 | Train Loss 0.6241 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 023 | Train Loss 0.6235 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# [Letter-med] Epoch 024 | Train Loss 0.6188 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 10]
# Early stop @ epoch 25 | Best val_acc=0.9257
# [Letter-med] Fold Test Acc: 0.9022
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9309 | Val Acc 0.7079 | LR 1.0e-02 [Best Val Acc: 0.7079 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2071 | Val Acc 0.7921 | LR 1.0e-02 [Best Val Acc: 0.7921 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0051 | Val Acc 0.8366 | LR 1.0e-02 [Best Val Acc: 0.8366 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9339 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8366 @ Epoch 3]
# [Letter-med] Epoch 005 | Train Loss 0.8121 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 5]
# [Letter-med] Epoch 006 | Train Loss 0.8491 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 5]
# [Letter-med] Epoch 007 | Train Loss 0.8148 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.7576 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 7]
# [Letter-med] Epoch 009 | Train Loss 0.7250 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 7]
# [Letter-med] Epoch 010 | Train Loss 0.7529 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 011 | Train Loss 0.7188 | Val Acc 0.8465 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 012 | Train Loss 0.6859 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 013 | Train Loss 0.7090 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 014 | Train Loss 0.6660 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 015 | Train Loss 0.6831 | Val Acc 0.8267 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 016 | Train Loss 0.6859 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 10]
# [Letter-med] Epoch 017 | Train Loss 0.6224 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 018 | Train Loss 0.6322 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 019 | Train Loss 0.6336 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 020 | Train Loss 0.6811 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 021 | Train Loss 0.6320 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 022 | Train Loss 0.6219 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 023 | Train Loss 0.6089 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 024 | Train Loss 0.6102 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 025 | Train Loss 0.5965 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 17]
# [Letter-med] Epoch 026 | Train Loss 0.5830 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 26]
# [Letter-med] Epoch 027 | Train Loss 0.6498 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 26]
# [Letter-med] Epoch 028 | Train Loss 0.6470 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 26]
# [Letter-med] Epoch 029 | Train Loss 0.5996 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 26]
# [Letter-med] Epoch 030 | Train Loss 0.6097 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 30]
# [Letter-med] Epoch 031 | Train Loss 0.5968 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 30]
# [Letter-med] Epoch 032 | Train Loss 0.5802 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 30]
# [Letter-med] Epoch 033 | Train Loss 0.5902 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 034 | Train Loss 0.5920 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 035 | Train Loss 0.5575 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 036 | Train Loss 0.5686 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 037 | Train Loss 0.5955 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 038 | Train Loss 0.5646 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 039 | Train Loss 0.5911 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 040 | Train Loss 0.5433 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 041 | Train Loss 0.5621 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 33]
# [Letter-med] Epoch 042 | Train Loss 0.5901 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 42]
# [Letter-med] Epoch 043 | Train Loss 0.5797 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 43]
# [Letter-med] Epoch 044 | Train Loss 0.5829 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 43]
# [Letter-med] Epoch 045 | Train Loss 0.5835 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 43]
# [Letter-med] Epoch 046 | Train Loss 0.5474 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 46]
# [Letter-med] Epoch 047 | Train Loss 0.5507 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 46]
# [Letter-med] Epoch 048 | Train Loss 0.5475 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 46]
# [Letter-med] Epoch 049 | Train Loss 0.5672 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 46]
# [Letter-med] Epoch 050 | Train Loss 0.5351 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 46]
# [Letter-med] Fold Test Acc: 0.9244
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9611 | Val Acc 0.7030 | LR 1.0e-02 [Best Val Acc: 0.7030 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2748 | Val Acc 0.7970 | LR 1.0e-02 [Best Val Acc: 0.7970 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.1073 | Val Acc 0.7772 | LR 1.0e-02 [Best Val Acc: 0.7970 @ Epoch 2]
# [Letter-med] Epoch 004 | Train Loss 0.9780 | Val Acc 0.8168 | LR 1.0e-02 [Best Val Acc: 0.8168 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.9058 | Val Acc 0.8267 | LR 1.0e-02 [Best Val Acc: 0.8267 @ Epoch 5]
# [Letter-med] Epoch 006 | Train Loss 0.9016 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8663 @ Epoch 6]
# [Letter-med] Epoch 007 | Train Loss 0.8765 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.8255 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 8]
# [Letter-med] Epoch 009 | Train Loss 0.7761 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 8]
# [Letter-med] Epoch 010 | Train Loss 0.7704 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 8]
# [Letter-med] Epoch 011 | Train Loss 0.7090 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 8]
# [Letter-med] Epoch 012 | Train Loss 0.7140 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 12]
# [Letter-med] Epoch 013 | Train Loss 0.7434 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 12]
# [Letter-med] Epoch 014 | Train Loss 0.6820 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 12]
# [Letter-med] Epoch 015 | Train Loss 0.6832 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 12]
# [Letter-med] Epoch 016 | Train Loss 0.7096 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 017 | Train Loss 0.6480 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 018 | Train Loss 0.6385 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 019 | Train Loss 0.6998 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 020 | Train Loss 0.6581 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 021 | Train Loss 0.6442 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 022 | Train Loss 0.6556 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 023 | Train Loss 0.6268 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 024 | Train Loss 0.6740 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 025 | Train Loss 0.6129 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 026 | Train Loss 0.6014 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 027 | Train Loss 0.6159 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 028 | Train Loss 0.6521 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 029 | Train Loss 0.6388 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 030 | Train Loss 0.6234 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 16]
# [Letter-med] Epoch 031 | Train Loss 0.6253 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 31]
# [Letter-med] Epoch 032 | Train Loss 0.6410 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 31]
# [Letter-med] Epoch 033 | Train Loss 0.5739 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9455 @ Epoch 31]
# [Letter-med] Epoch 034 | Train Loss 0.5570 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 34]
# [Letter-med] Epoch 035 | Train Loss 0.5343 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 34]
# [Letter-med] Epoch 036 | Train Loss 0.5322 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 34]
# [Letter-med] Epoch 037 | Train Loss 0.5157 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 34]
# [Letter-med] Epoch 038 | Train Loss 0.5087 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 34]
# [Letter-med] Epoch 039 | Train Loss 0.5227 | Val Acc 0.9554 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 040 | Train Loss 0.5077 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 041 | Train Loss 0.5515 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 042 | Train Loss 0.5559 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 043 | Train Loss 0.5469 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 044 | Train Loss 0.5639 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 045 | Train Loss 0.5652 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 046 | Train Loss 0.4967 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 047 | Train Loss 0.5169 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 048 | Train Loss 0.4976 | Val Acc 0.9455 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 049 | Train Loss 0.5385 | Val Acc 0.9505 | LR 1.0e-03 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Epoch 050 | Train Loss 0.5087 | Val Acc 0.9406 | LR 1.0e-04 [Best Val Acc: 0.9554 @ Epoch 39]
# [Letter-med] Fold Test Acc: 0.9378
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9679 | Val Acc 0.6287 | LR 1.0e-02 [Best Val Acc: 0.6287 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2752 | Val Acc 0.7723 | LR 1.0e-02 [Best Val Acc: 0.7723 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0688 | Val Acc 0.8267 | LR 1.0e-02 [Best Val Acc: 0.8267 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9678 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.8788 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8614 @ Epoch 5]
# [Letter-med] Epoch 006 | Train Loss 0.8594 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 6]
# [Letter-med] Epoch 007 | Train Loss 0.8322 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.7765 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8812 @ Epoch 7]
# [Letter-med] Epoch 009 | Train Loss 0.7645 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 9]
# [Letter-med] Epoch 010 | Train Loss 0.7530 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 10]
# [Letter-med] Epoch 011 | Train Loss 0.7327 | Val Acc 0.8416 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 10]
# [Letter-med] Epoch 012 | Train Loss 0.6789 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 12]
# [Letter-med] Epoch 013 | Train Loss 0.6922 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 014 | Train Loss 0.6525 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 015 | Train Loss 0.6758 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 016 | Train Loss 0.7029 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 017 | Train Loss 0.6399 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 018 | Train Loss 0.6650 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 019 | Train Loss 0.6683 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 020 | Train Loss 0.6265 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 13]
# [Letter-med] Epoch 021 | Train Loss 0.6077 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 21]
# [Letter-med] Epoch 022 | Train Loss 0.6323 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 21]
# [Letter-med] Epoch 023 | Train Loss 0.6129 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 21]
# [Letter-med] Epoch 024 | Train Loss 0.6200 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 21]
# [Letter-med] Epoch 025 | Train Loss 0.5838 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 21]
# [Letter-med] Epoch 026 | Train Loss 0.5929 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 21]
# [Letter-med] Epoch 027 | Train Loss 0.6097 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 028 | Train Loss 0.6315 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 029 | Train Loss 0.6191 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 030 | Train Loss 0.5841 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 031 | Train Loss 0.5819 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 032 | Train Loss 0.5624 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 033 | Train Loss 0.5674 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 034 | Train Loss 0.6170 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 035 | Train Loss 0.5965 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 27]
# [Letter-med] Epoch 036 | Train Loss 0.6044 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 037 | Train Loss 0.5455 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 038 | Train Loss 0.6058 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 039 | Train Loss 0.5589 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 040 | Train Loss 0.5294 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 041 | Train Loss 0.5765 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 042 | Train Loss 0.6340 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 043 | Train Loss 0.6280 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 044 | Train Loss 0.5391 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 045 | Train Loss 0.5868 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 046 | Train Loss 0.5212 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 047 | Train Loss 0.5418 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 048 | Train Loss 0.5246 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 049 | Train Loss 0.5847 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Epoch 050 | Train Loss 0.5300 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9158 @ Epoch 36]
# [Letter-med] Fold Test Acc: 0.9467
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9574 | Val Acc 0.7327 | LR 1.0e-02 [Best Val Acc: 0.7327 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2532 | Val Acc 0.8218 | LR 1.0e-02 [Best Val Acc: 0.8218 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0335 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9182 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.8187 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 4]
# [Letter-med] Epoch 006 | Train Loss 0.8026 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 6]
# [Letter-med] Epoch 007 | Train Loss 0.8056 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.7282 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 7]
# [Letter-med] Epoch 009 | Train Loss 0.7132 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 9]
# [Letter-med] Epoch 010 | Train Loss 0.7453 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 9]
# [Letter-med] Epoch 011 | Train Loss 0.7107 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 9]
# [Letter-med] Epoch 012 | Train Loss 0.6679 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 9]
# [Letter-med] Epoch 013 | Train Loss 0.7244 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 9]
# [Letter-med] Epoch 014 | Train Loss 0.6785 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 14]
# [Letter-med] Epoch 015 | Train Loss 0.6460 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 14]
# [Letter-med] Epoch 016 | Train Loss 0.6547 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 14]
# [Letter-med] Epoch 017 | Train Loss 0.6118 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 14]
# [Letter-med] Epoch 018 | Train Loss 0.6160 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9257 @ Epoch 14]
# [Letter-med] Epoch 019 | Train Loss 0.6110 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 020 | Train Loss 0.6564 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 021 | Train Loss 0.6246 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 022 | Train Loss 0.6223 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 023 | Train Loss 0.6010 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 024 | Train Loss 0.6378 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 025 | Train Loss 0.6044 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 026 | Train Loss 0.5717 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 027 | Train Loss 0.6145 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 028 | Train Loss 0.5924 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 19]
# [Letter-med] Epoch 029 | Train Loss 0.5986 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 29]
# [Letter-med] Epoch 030 | Train Loss 0.5984 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 29]
# [Letter-med] Epoch 031 | Train Loss 0.5824 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 31]
# [Letter-med] Epoch 032 | Train Loss 0.5829 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 31]
# [Letter-med] Epoch 033 | Train Loss 0.5969 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 31]
# [Letter-med] Epoch 034 | Train Loss 0.5954 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 31]
# [Letter-med] Epoch 035 | Train Loss 0.5650 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 35]
# [Letter-med] Epoch 036 | Train Loss 0.5486 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 35]
# [Letter-med] Epoch 037 | Train Loss 0.4979 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9307 @ Epoch 37]
# [Letter-med] Epoch 038 | Train Loss 0.5012 | Val Acc 0.9406 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 039 | Train Loss 0.4810 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 040 | Train Loss 0.4715 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 041 | Train Loss 0.4797 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 042 | Train Loss 0.5140 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 043 | Train Loss 0.5110 | Val Acc 0.9356 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 044 | Train Loss 0.4840 | Val Acc 0.9208 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 045 | Train Loss 0.5478 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 046 | Train Loss 0.4924 | Val Acc 0.9158 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 047 | Train Loss 0.4978 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 048 | Train Loss 0.4908 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 049 | Train Loss 0.4846 | Val Acc 0.9307 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Epoch 050 | Train Loss 0.4838 | Val Acc 0.9257 | LR 1.0e-03 [Best Val Acc: 0.9406 @ Epoch 38]
# [Letter-med] Fold Test Acc: 0.9111
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9358 | Val Acc 0.7079 | LR 1.0e-02 [Best Val Acc: 0.7079 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2290 | Val Acc 0.7921 | LR 1.0e-02 [Best Val Acc: 0.7921 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0724 | Val Acc 0.8366 | LR 1.0e-02 [Best Val Acc: 0.8366 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9839 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.9180 | Val Acc 0.8416 | LR 1.0e-02 [Best Val Acc: 0.8911 @ Epoch 4]
# [Letter-med] Epoch 006 | Train Loss 0.8621 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9010 @ Epoch 6]
# [Letter-med] Epoch 007 | Train Loss 0.8527 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9059 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.7793 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 009 | Train Loss 0.7652 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 010 | Train Loss 0.7757 | Val Acc 0.9010 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 011 | Train Loss 0.7390 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 012 | Train Loss 0.7235 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 013 | Train Loss 0.7084 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 014 | Train Loss 0.6982 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9208 @ Epoch 8]
# [Letter-med] Epoch 015 | Train Loss 0.6691 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 15]
# [Letter-med] Epoch 016 | Train Loss 0.7064 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 15]
# [Letter-med] Epoch 017 | Train Loss 0.6510 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 15]
# [Letter-med] Epoch 018 | Train Loss 0.6422 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 15]
# [Letter-med] Epoch 019 | Train Loss 0.6696 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9307 @ Epoch 15]
# [Letter-med] Epoch 020 | Train Loss 0.6800 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 021 | Train Loss 0.6471 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 022 | Train Loss 0.6385 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 023 | Train Loss 0.6313 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 024 | Train Loss 0.6592 | Val Acc 0.9109 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 025 | Train Loss 0.6206 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 026 | Train Loss 0.5908 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9455 @ Epoch 20]
# [Letter-med] Epoch 027 | Train Loss 0.5961 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 028 | Train Loss 0.6294 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 029 | Train Loss 0.6122 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 030 | Train Loss 0.5980 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 031 | Train Loss 0.5853 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 032 | Train Loss 0.6217 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 033 | Train Loss 0.6321 | Val Acc 0.9505 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 034 | Train Loss 0.5810 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9505 @ Epoch 27]
# [Letter-med] Epoch 035 | Train Loss 0.5849 | Val Acc 0.9554 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 036 | Train Loss 0.5782 | Val Acc 0.9208 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 037 | Train Loss 0.5723 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 038 | Train Loss 0.5821 | Val Acc 0.9257 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 039 | Train Loss 0.5625 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 040 | Train Loss 0.5461 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 041 | Train Loss 0.5571 | Val Acc 0.9455 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 042 | Train Loss 0.6178 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 043 | Train Loss 0.6194 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 044 | Train Loss 0.5885 | Val Acc 0.9406 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 045 | Train Loss 0.6047 | Val Acc 0.9158 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 046 | Train Loss 0.5586 | Val Acc 0.9307 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 047 | Train Loss 0.5705 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 048 | Train Loss 0.5530 | Val Acc 0.9059 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# [Letter-med] Epoch 049 | Train Loss 0.5989 | Val Acc 0.9356 | LR 1.0e-02 [Best Val Acc: 0.9554 @ Epoch 35]
# Early stop @ epoch 50 | Best val_acc=0.9554
# [Letter-med] Fold Test Acc: 0.8933
#
# number of qubits 5
# number of nodes 9
# number of features 2
# train_feats shape: torch.Size([1823, 32])
# train_phases shape: torch.Size([1823, 5, 5])
# train_labs shape: torch.Size([1823])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=15, bias=True)
#   )
# )
# Number of parameters: 1171
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [Letter-med] Epoch 001 | Train Loss 1.9480 | Val Acc 0.5941 | LR 1.0e-02 [Best Val Acc: 0.5941 @ Epoch 1]
# [Letter-med] Epoch 002 | Train Loss 1.2565 | Val Acc 0.7525 | LR 1.0e-02 [Best Val Acc: 0.7525 @ Epoch 2]
# [Letter-med] Epoch 003 | Train Loss 1.0875 | Val Acc 0.8020 | LR 1.0e-02 [Best Val Acc: 0.8020 @ Epoch 3]
# [Letter-med] Epoch 004 | Train Loss 0.9409 | Val Acc 0.8317 | LR 1.0e-02 [Best Val Acc: 0.8317 @ Epoch 4]
# [Letter-med] Epoch 005 | Train Loss 0.8959 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8515 @ Epoch 5]
# [Letter-med] Epoch 006 | Train Loss 0.8429 | Val Acc 0.8119 | LR 1.0e-02 [Best Val Acc: 0.8515 @ Epoch 5]
# [Letter-med] Epoch 007 | Train Loss 0.8400 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8515 @ Epoch 7]
# [Letter-med] Epoch 008 | Train Loss 0.8118 | Val Acc 0.8564 | LR 1.0e-02 [Best Val Acc: 0.8564 @ Epoch 8]
# [Letter-med] Epoch 009 | Train Loss 0.7867 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 9]
# [Letter-med] Epoch 010 | Train Loss 0.7585 | Val Acc 0.8020 | LR 1.0e-02 [Best Val Acc: 0.8713 @ Epoch 9]
# [Letter-med] Epoch 011 | Train Loss 0.7334 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 11]
# [Letter-med] Epoch 012 | Train Loss 0.7475 | Val Acc 0.8317 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 11]
# [Letter-med] Epoch 013 | Train Loss 0.7175 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 13]
# [Letter-med] Epoch 014 | Train Loss 0.6911 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 13]
# [Letter-med] Epoch 015 | Train Loss 0.6594 | Val Acc 0.8762 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 15]
# [Letter-med] Epoch 016 | Train Loss 0.6901 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8762 @ Epoch 15]
# [Letter-med] Epoch 017 | Train Loss 0.6394 | Val Acc 0.8960 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 018 | Train Loss 0.6271 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 019 | Train Loss 0.6490 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 020 | Train Loss 0.6770 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 021 | Train Loss 0.6554 | Val Acc 0.8614 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 022 | Train Loss 0.6299 | Val Acc 0.8515 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 023 | Train Loss 0.6271 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 024 | Train Loss 0.6577 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 025 | Train Loss 0.6207 | Val Acc 0.8416 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 026 | Train Loss 0.5664 | Val Acc 0.8911 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 027 | Train Loss 0.6274 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 028 | Train Loss 0.6605 | Val Acc 0.8812 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 029 | Train Loss 0.6482 | Val Acc 0.8663 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 030 | Train Loss 0.6426 | Val Acc 0.8713 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# [Letter-med] Epoch 031 | Train Loss 0.6086 | Val Acc 0.8861 | LR 1.0e-02 [Best Val Acc: 0.8960 @ Epoch 17]
# Early stop @ epoch 32 | Best val_acc=0.8960
# [Letter-med] Fold Test Acc: 0.9022
#
#
# === Cross-Validation Results for Letter-med ===
# Per-fold Accuracies: [0.9288888888888889, 0.9466666666666667, 0.9333333333333333, 0.9022222222222223, 0.9244444444444444, 0.9377777777777778, 0.9466666666666667, 0.9111111111111111, 0.8933333333333333, 0.9022222222222223]
# Mean Test Acc: 0.9227 ± 0.0183
