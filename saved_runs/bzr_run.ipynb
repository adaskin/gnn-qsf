# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=20,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": 'BZR',  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        # "hidden_dims": [32, 16],  # Hidden dimensions for classical head
         "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 16,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'BZR', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 16, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([328, 4096])
# train_phases shape: torch.Size([328, 12, 12])
# train_labs shape: torch.Size([328])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5732 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4492 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.4013 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3522 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8611 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.3670 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 006 | Train Loss 0.2514 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 007 | Train Loss 0.2842 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 008 | Train Loss 0.2340 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 009 | Train Loss 0.2203 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 010 | Train Loss 0.2266 | Val Acc 0.7222 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 011 | Train Loss 0.1909 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 012 | Train Loss 0.1571 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 013 | Train Loss 0.1753 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 014 | Train Loss 0.1904 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 015 | Train Loss 0.2061 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 016 | Train Loss 0.1133 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 017 | Train Loss 0.1687 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 018 | Train Loss 0.1447 | Val Acc 0.7222 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 019 | Train Loss 0.1577 | Val Acc 0.7222 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# Early stop @ epoch 20 | Best val_acc=0.8889
# [BZR] Fold Test Acc: 0.8537
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([328, 4096])
# train_phases shape: torch.Size([328, 12, 12])
# train_labs shape: torch.Size([328])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5393 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4394 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3792 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3820 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.3466 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 006 | Train Loss 0.2616 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 007 | Train Loss 0.2564 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 7]
# [BZR] Epoch 008 | Train Loss 0.2110 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 009 | Train Loss 0.2191 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 010 | Train Loss 0.2134 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 011 | Train Loss 0.2185 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 012 | Train Loss 0.1293 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 013 | Train Loss 0.1897 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 014 | Train Loss 0.1779 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 015 | Train Loss 0.1974 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 016 | Train Loss 0.1348 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 017 | Train Loss 0.1546 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 018 | Train Loss 0.1603 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 019 | Train Loss 0.1215 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 020 | Train Loss 0.1418 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 021 | Train Loss 0.1813 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 022 | Train Loss 0.1545 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 023 | Train Loss 0.1293 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 024 | Train Loss 0.1358 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 025 | Train Loss 0.1638 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# [BZR] Epoch 026 | Train Loss 0.1333 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 12]
# Early stop @ epoch 27 | Best val_acc=0.9444
# [BZR] Fold Test Acc: 0.7561
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([328, 4096])
# train_phases shape: torch.Size([328, 12, 12])
# train_labs shape: torch.Size([328])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5429 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4260 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3801 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3512 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.2887 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 006 | Train Loss 0.2006 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 007 | Train Loss 0.2013 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 008 | Train Loss 0.2053 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 009 | Train Loss 0.1802 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 010 | Train Loss 0.1859 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 011 | Train Loss 0.1467 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 012 | Train Loss 0.1082 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 013 | Train Loss 0.1875 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 014 | Train Loss 0.1548 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 015 | Train Loss 0.1983 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 016 | Train Loss 0.1337 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 017 | Train Loss 0.1265 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 018 | Train Loss 0.1544 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# Early stop @ epoch 19 | Best val_acc=0.8889
# [BZR] Fold Test Acc: 0.7317
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([328, 4096])
# train_phases shape: torch.Size([328, 12, 12])
# train_labs shape: torch.Size([328])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5726 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4521 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.4024 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3694 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.3706 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 006 | Train Loss 0.2862 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 007 | Train Loss 0.2555 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 7]
# [BZR] Epoch 008 | Train Loss 0.2445 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 009 | Train Loss 0.2236 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 010 | Train Loss 0.2205 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 011 | Train Loss 0.1812 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 012 | Train Loss 0.1359 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 013 | Train Loss 0.2085 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 014 | Train Loss 0.1680 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 8]
# [BZR] Epoch 015 | Train Loss 0.1829 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 15]
# [BZR] Epoch 016 | Train Loss 0.1432 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 15]
# [BZR] Epoch 017 | Train Loss 0.1382 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 15]
# [BZR] Epoch 018 | Train Loss 0.1652 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 15]
# [BZR] Epoch 019 | Train Loss 0.1508 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 020 | Train Loss 0.1526 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 021 | Train Loss 0.1611 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 022 | Train Loss 0.1770 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 023 | Train Loss 0.1820 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 024 | Train Loss 0.1577 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 025 | Train Loss 0.1362 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 026 | Train Loss 0.1533 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 027 | Train Loss 0.1853 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 028 | Train Loss 0.1284 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 029 | Train Loss 0.1338 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 030 | Train Loss 0.1338 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 031 | Train Loss 0.1671 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 19]
# [BZR] Epoch 032 | Train Loss 0.0852 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 033 | Train Loss 0.1347 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 034 | Train Loss 0.1401 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 035 | Train Loss 0.1219 | Val Acc 0.8056 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 036 | Train Loss 0.0970 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 037 | Train Loss 0.0599 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 038 | Train Loss 0.0467 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 039 | Train Loss 0.0707 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 040 | Train Loss 0.0623 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 041 | Train Loss 0.0629 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 042 | Train Loss 0.0647 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 043 | Train Loss 0.0562 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 044 | Train Loss 0.0563 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 045 | Train Loss 0.0563 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# [BZR] Epoch 046 | Train Loss 0.0433 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 32]
# Early stop @ epoch 47 | Best val_acc=0.9167
# [BZR] Fold Test Acc: 0.7805
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([328, 4096])
# train_phases shape: torch.Size([328, 12, 12])
# train_labs shape: torch.Size([328])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5567 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4405 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3974 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3724 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.3584 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 006 | Train Loss 0.2906 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 007 | Train Loss 0.2612 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 008 | Train Loss 0.2040 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 009 | Train Loss 0.2274 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 010 | Train Loss 0.1887 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 011 | Train Loss 0.1812 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 4]
# [BZR] Epoch 012 | Train Loss 0.1237 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 013 | Train Loss 0.1913 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 014 | Train Loss 0.1831 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 015 | Train Loss 0.1164 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 15]
# [BZR] Epoch 016 | Train Loss 0.0957 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 017 | Train Loss 0.2030 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 018 | Train Loss 0.1624 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 019 | Train Loss 0.1198 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 020 | Train Loss 0.1438 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 021 | Train Loss 0.1327 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 022 | Train Loss 0.1757 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 023 | Train Loss 0.1279 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 024 | Train Loss 0.1369 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 025 | Train Loss 0.0915 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 026 | Train Loss 0.0956 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 027 | Train Loss 0.1457 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 028 | Train Loss 0.1218 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 029 | Train Loss 0.1091 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# [BZR] Epoch 030 | Train Loss 0.1067 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 16]
# Early stop @ epoch 31 | Best val_acc=0.9444
# [BZR] Fold Test Acc: 0.8293
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([329, 4096])
# train_phases shape: torch.Size([329, 12, 12])
# train_labs shape: torch.Size([329])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5561 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4607 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3839 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3644 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.3076 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 5]
# [BZR] Epoch 006 | Train Loss 0.2771 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 5]
# [BZR] Epoch 007 | Train Loss 0.2385 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 7]
# [BZR] Epoch 008 | Train Loss 0.2157 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 8]
# [BZR] Epoch 009 | Train Loss 0.2229 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8611 @ Epoch 9]
# [BZR] Epoch 010 | Train Loss 0.1864 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8611 @ Epoch 9]
# [BZR] Epoch 011 | Train Loss 0.1801 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8611 @ Epoch 11]
# [BZR] Epoch 012 | Train Loss 0.1805 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 013 | Train Loss 0.1623 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 014 | Train Loss 0.1259 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 015 | Train Loss 0.1039 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 016 | Train Loss 0.1332 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 017 | Train Loss 0.1049 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 018 | Train Loss 0.1534 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 019 | Train Loss 0.1450 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 020 | Train Loss 0.1379 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 021 | Train Loss 0.1669 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 022 | Train Loss 0.1329 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 023 | Train Loss 0.2046 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 024 | Train Loss 0.1675 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 12]
# [BZR] Epoch 025 | Train Loss 0.0950 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 026 | Train Loss 0.0949 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 027 | Train Loss 0.1472 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 028 | Train Loss 0.1505 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 029 | Train Loss 0.1283 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 030 | Train Loss 0.1242 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 031 | Train Loss 0.1182 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 032 | Train Loss 0.1727 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 033 | Train Loss 0.1298 | Val Acc 0.9444 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 034 | Train Loss 0.1468 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 035 | Train Loss 0.0986 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 036 | Train Loss 0.0954 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 037 | Train Loss 0.1546 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 038 | Train Loss 0.0836 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# [BZR] Epoch 039 | Train Loss 0.1104 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9444 @ Epoch 25]
# Early stop @ epoch 40 | Best val_acc=0.9444
# [BZR] Fold Test Acc: 0.8750
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([329, 4096])
# train_phases shape: torch.Size([329, 12, 12])
# train_labs shape: torch.Size([329])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5712 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4488 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3827 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3435 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.3059 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 006 | Train Loss 0.2586 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 007 | Train Loss 0.2100 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 008 | Train Loss 0.2461 | Val Acc 0.7222 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 009 | Train Loss 0.2003 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 010 | Train Loss 0.2031 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 011 | Train Loss 0.1774 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 012 | Train Loss 0.1715 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 013 | Train Loss 0.1311 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 014 | Train Loss 0.1794 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 015 | Train Loss 0.1290 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 016 | Train Loss 0.1379 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 017 | Train Loss 0.1410 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 018 | Train Loss 0.1182 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 019 | Train Loss 0.1130 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# Early stop @ epoch 20 | Best val_acc=0.8889
# [BZR] Fold Test Acc: 0.9250
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([329, 4096])
# train_phases shape: torch.Size([329, 12, 12])
# train_labs shape: torch.Size([329])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5409 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4489 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3955 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3244 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.2521 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 4]
# [BZR] Epoch 006 | Train Loss 0.2324 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 6]
# [BZR] Epoch 007 | Train Loss 0.1755 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 008 | Train Loss 0.2075 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 009 | Train Loss 0.1944 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 010 | Train Loss 0.1984 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 011 | Train Loss 0.1709 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 012 | Train Loss 0.1544 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 013 | Train Loss 0.0885 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 014 | Train Loss 0.1474 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 015 | Train Loss 0.1249 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 016 | Train Loss 0.1250 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 017 | Train Loss 0.0847 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 018 | Train Loss 0.1267 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 019 | Train Loss 0.1174 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 020 | Train Loss 0.1335 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 021 | Train Loss 0.0928 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# Early stop @ epoch 22 | Best val_acc=0.9167
# [BZR] Fold Test Acc: 0.7750
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([329, 4096])
# train_phases shape: torch.Size([329, 12, 12])
# train_labs shape: torch.Size([329])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5411 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4336 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.3563 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3035 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.2529 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 5]
# [BZR] Epoch 006 | Train Loss 0.2530 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 6]
# [BZR] Epoch 007 | Train Loss 0.2037 | Val Acc 0.9167 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 008 | Train Loss 0.2179 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 009 | Train Loss 0.2235 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 010 | Train Loss 0.1946 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 011 | Train Loss 0.1697 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 012 | Train Loss 0.1315 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 013 | Train Loss 0.1410 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 014 | Train Loss 0.1936 | Val Acc 0.7222 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 015 | Train Loss 0.1122 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 016 | Train Loss 0.1152 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 017 | Train Loss 0.1665 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 018 | Train Loss 0.1139 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 019 | Train Loss 0.1825 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 020 | Train Loss 0.1526 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 021 | Train Loss 0.1866 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.9167 @ Epoch 7]
# [BZR] Epoch 022 | Train Loss 0.1637 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 22]
# [BZR] Epoch 023 | Train Loss 0.1629 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 23]
# [BZR] Epoch 024 | Train Loss 0.0847 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 24]
# [BZR] Epoch 025 | Train Loss 0.0731 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 25]
# [BZR] Epoch 026 | Train Loss 0.0662 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 26]
# [BZR] Epoch 027 | Train Loss 0.0572 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 028 | Train Loss 0.0757 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 029 | Train Loss 0.0904 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 030 | Train Loss 0.0736 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 031 | Train Loss 0.0890 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 032 | Train Loss 0.0812 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 033 | Train Loss 0.0862 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 034 | Train Loss 0.0797 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 035 | Train Loss 0.0822 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 036 | Train Loss 0.0586 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 037 | Train Loss 0.0840 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 038 | Train Loss 0.0511 | Val Acc 0.8889 | LR 1.0e-04 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 039 | Train Loss 0.0741 | Val Acc 0.8889 | LR 1.0e-04 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 040 | Train Loss 0.0598 | Val Acc 0.8889 | LR 1.0e-04 [Best Val Acc: 0.9167 @ Epoch 27]
# [BZR] Epoch 041 | Train Loss 0.0736 | Val Acc 0.8889 | LR 1.0e-04 [Best Val Acc: 0.9167 @ Epoch 27]
# Early stop @ epoch 42 | Best val_acc=0.9167
# [BZR] Fold Test Acc: 0.7750
#
# number of qubits 12
# number of nodes 57
# number of features 56
# train_feats shape: torch.Size([329, 4096])
# train_phases shape: torch.Size([329, 12, 12])
# train_labs shape: torch.Size([329])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1650
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [BZR] Epoch 001 | Train Loss 0.5383 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 1]
# [BZR] Epoch 002 | Train Loss 0.4204 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.7778 @ Epoch 2]
# [BZR] Epoch 003 | Train Loss 0.4088 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8056 @ Epoch 3]
# [BZR] Epoch 004 | Train Loss 0.3381 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 4]
# [BZR] Epoch 005 | Train Loss 0.2777 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 5]
# [BZR] Epoch 006 | Train Loss 0.2378 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 6]
# [BZR] Epoch 007 | Train Loss 0.2388 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 6]
# [BZR] Epoch 008 | Train Loss 0.2339 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 8]
# [BZR] Epoch 009 | Train Loss 0.2208 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 9]
# [BZR] Epoch 010 | Train Loss 0.1978 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 9]
# [BZR] Epoch 011 | Train Loss 0.1857 | Val Acc 0.7222 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 9]
# [BZR] Epoch 012 | Train Loss 0.1673 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 9]
# [BZR] Epoch 013 | Train Loss 0.1528 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 9]
# [BZR] Epoch 014 | Train Loss 0.1359 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 14]
# [BZR] Epoch 015 | Train Loss 0.1039 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 15]
# [BZR] Epoch 016 | Train Loss 0.1532 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8333 @ Epoch 15]
# [BZR] Epoch 017 | Train Loss 0.1380 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8611 @ Epoch 17]
# [BZR] Epoch 018 | Train Loss 0.1606 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 019 | Train Loss 0.1645 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 020 | Train Loss 0.1510 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 021 | Train Loss 0.1745 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 022 | Train Loss 0.1541 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 023 | Train Loss 0.2014 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 024 | Train Loss 0.1193 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 025 | Train Loss 0.1018 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 026 | Train Loss 0.1127 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 18]
# [BZR] Epoch 027 | Train Loss 0.1178 | Val Acc 0.8889 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 028 | Train Loss 0.0808 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 029 | Train Loss 0.1021 | Val Acc 0.7778 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 030 | Train Loss 0.0960 | Val Acc 0.8611 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 031 | Train Loss 0.1184 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 032 | Train Loss 0.1212 | Val Acc 0.8056 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 033 | Train Loss 0.0994 | Val Acc 0.8333 | LR 1.0e-02 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 034 | Train Loss 0.1405 | Val Acc 0.8611 | LR 1.0e-03 [Best Val Acc: 0.8889 @ Epoch 27]
# [BZR] Epoch 035 | Train Loss 0.0741 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 35]
# [BZR] Epoch 036 | Train Loss 0.0548 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 35]
# [BZR] Epoch 037 | Train Loss 0.0689 | Val Acc 0.8889 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 35]
# [BZR] Epoch 038 | Train Loss 0.0585 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 38]
# [BZR] Epoch 039 | Train Loss 0.0815 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 38]
# [BZR] Epoch 040 | Train Loss 0.0562 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 40]
# [BZR] Epoch 041 | Train Loss 0.0827 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 40]
# [BZR] Epoch 042 | Train Loss 0.0465 | Val Acc 0.9167 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 043 | Train Loss 0.0614 | Val Acc 0.8611 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 044 | Train Loss 0.0878 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 045 | Train Loss 0.0392 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 046 | Train Loss 0.0698 | Val Acc 0.8611 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 047 | Train Loss 0.0431 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 048 | Train Loss 0.0235 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 049 | Train Loss 0.0248 | Val Acc 0.7778 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Epoch 050 | Train Loss 0.0302 | Val Acc 0.8333 | LR 1.0e-03 [Best Val Acc: 0.9167 @ Epoch 42]
# [BZR] Fold Test Acc: 0.8500
#
#
# === Cross-Validation Results for BZR ===
# Per-fold Accuracies: [0.8536585365853658, 0.7560975609756098, 0.7317073170731707, 0.7804878048780488, 0.8292682926829268, 0.875, 0.925, 0.775, 0.775, 0.85]
# Mean Test Acc: 0.8151 ± 0.0578
