# %%
import math
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch_geometric.datasets import TUDataset, MNISTSuperpixels, MoleculeNet
from torch_geometric.data import DataLoader
from torch_geometric.utils import to_dense_adj
from sklearn.model_selection import StratifiedKFold, train_test_split
import os

os.environ["OMP_NUM_THREADS"] = "4"  # limit OpenMP threads for Pennylane
import pennylane as qml
import warnings


# ========================
# Quantum Circuit Module
# ========================
class QuantumCircuit(nn.Module):
    def __init__(self, n_qubits, n_layers=1):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.state_dim = 2**n_qubits

        # PennyLane device
        self.dev = qml.device("lightning.qubit", wires=n_qubits, batch_obs=True)

        # count of rotation & QFT params per layer
        n_pairs = n_qubits * (n_qubits - 1) // 2
        self.rot_params_per_layer = n_qubits + n_pairs
        self.qft_params_per_layer = n_pairs

        # trainable parameters (float32 by default)
        self.ry_thetas = nn.Parameter(torch.rand(n_layers, self.rot_params_per_layer))
        self.qft_phases = nn.Parameter(torch.rand(n_layers, self.qft_params_per_layer))

        # Torch‐backed QNode
        self.qnode = qml.QNode(
            self.circuit, self.dev, interface="torch", diff_method="adjoint"
        )

    def rotation_layer(self, thetas, qubit_connections):
        idx = 0
        for i in range(self.n_qubits):
            qml.RY(thetas[idx], wires=i)
            idx += 1
        for c in range(self.n_qubits):
            for t in range(c + 1, self.n_qubits):
                if qubit_connections[c, t] != 0:
                    angle = thetas[idx]
                    qml.CRY(angle, wires=[c, t])
                idx += 1

    def parameterized_qft(self, phases, qubit_connections):
        pidx = 0
        for tgt in range(self.n_qubits):
            qml.Hadamard(wires=tgt)
            for ctrl in range(tgt + 1, self.n_qubits):
                if qubit_connections[ctrl, tgt] != 0:
                    angle = phases[pidx] * 0.9 + 0.1 * qubit_connections[ctrl, tgt]
                    qml.CRZ(angle, wires=[ctrl, tgt])
                pidx += 1

    def circuit(self, input_state, qubit_connections):
        # amplitude embedding of a 2**n_qubits vector
        norm = torch.norm(input_state)
        if torch.isclose(norm, torch.tensor(0.0)):
            warnings.warn("⚠️ Zero‐vector embedding: input to quantum circuit is 0!")

            qml.AmplitudeEmbedding(
                input_state + 1e-8, wires=range(self.n_qubits), normalize=True
            )
        else:
            qml.AmplitudeEmbedding(
                input_state, wires=range(self.n_qubits), normalize=True
            )

        for layer in range(self.n_layers):
            self.rotation_layer(self.ry_thetas[layer], qubit_connections)
            self.parameterized_qft(self.qft_phases[layer], qubit_connections)

        # measure PauliZ on each qubit
        return [qml.expval(qml.PauliZ(i)) for i in range(self.n_qubits)]

    def forward(self, input_state, qubit_connections):
        # print(input_state)
        raw_output = self.qnode(input_state, qubit_connections)
        # Normalize and clip outputs to prevent explosion
        output = torch.stack(raw_output).float()  # Ensure float32
        # print(output)
        # output = torch.clamp(output, -1.0, 1.0)  # Constrain to [-1,1]
        return output  #


# ========================
# Quantum GNN Module
# ========================
class QuantumGNN(nn.Module):
    def __init__(
        self,
        n_qubits,
        n_layers=1,
        hidden_dims=[64, 32],
        output_dim=1,
        dropout_prob=0.25,
    ):

        super().__init__()
        self.n_qubits = n_qubits

        # quantum backbone
        self.quantum_circuit = QuantumCircuit(n_qubits, n_layers)

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, features):
        padded_features, qubit_connections = (
            features  # shapes: [B, 2**n_qubits], [B, n_qubits, n_qubits]
        )
        batch_size = padded_features.size(0)

        # run each graph through the QNode
        quantum_outputs = []
        for i in range(batch_size):
            oq = self.quantum_circuit(padded_features[i], qubit_connections[i])
            # stack the n_qubit expectation values → [n_qubits]
            # quantum_outputs.append(torch.stack(oq))
            quantum_outputs.append(oq)

        # → [B, n_qubits] but ensure float32
        probs = torch.stack(quantum_outputs, dim=0).float()

        # feed classical head → logits
        return self.classical_net(probs)


# ========================
# Data Preprocessing
# ========================
class GraphPreprocessor:
    def __init__(self, dataset):
        self.dataset = dataset
        self.max_nodes = max(d.num_nodes for d in dataset)
        self.feature_dim = dataset.num_node_features
        if self.feature_dim == 0:
            self.feature_dim = 1
        self.n_qubits = math.ceil(math.log2(self.max_nodes * self.feature_dim))
        self.state_dim = 2**self.n_qubits
        self.bin_repr = self.create_bin_repr()  # [max_nodes, n_qubits] float32

    def create_bin_repr(self):
        nodes = torch.arange(self.max_nodes)
        # bit-shift into n_qubits columns, then float32
        br = (nodes.unsqueeze(1) >> torch.arange(self.n_qubits - 1, -1, -1)) & 1
        return br.float()

    # def compute_qubit_connections(self, adj):
    #     # adj: [max_nodes, max_nodes] float32, no self–loops
    #     a = adj.clone() / adj.shape[0]  # normalize by node count

    #     a.fill_diagonal_(0)
    #     # → [n_qubits, n_qubits]
    #     return torch.einsum("ij,ic,jt->ct", a, self.bin_repr, self.bin_repr)

    # MORE ROBUST PHASE INITIALIZATION
    def compute_qubit_connections(
        self, adj_matrix, n_qubits=None, base_phase=0.1, noise=0.01
    ):
        N = adj_matrix.shape[0]
        if n_qubits is None:
            n_qubits = self.n_qubits

        # Use precomputed binary representation
        node_bin = self.bin_repr[:N].to(adj_matrix.device)  # Only use first N nodes

        # Create off-diagonal mask
        off_diag_mask = ~torch.eye(N, dtype=torch.bool, device=adj_matrix.device)

        # Prepare weight matrix
        W = adj_matrix / N
        zero_off_diag = (W == 0) & off_diag_mask
        W = torch.where(zero_off_diag, base_phase, W)
        W = W * off_diag_mask.float()  # Zero out diagonal

        # Compute phase matrix using vectorized operations
        phase_matrix = node_bin.t() @ (W @ node_bin)

        # Add noise to break symmetry
        phase_matrix += noise * torch.randn_like(phase_matrix)

        return phase_matrix

    def preprocess_graph(self, data):
        # flatten & pad
        # 1) detect missing or zero-width features
        if (
            (not hasattr(data, "x"))
            or data.x == None
            or data.x.numel() == 0
            or data.x.size(1) == 0
        ):
            
            # ensure you modify the same Data object
            warnings.warn("⚠️ No node features found, using ones.")
            data.x = torch.ones(self.state_dim, 1, dtype=torch.float32)

        # 2) flatten and pad
        flat = data.x.reshape(-1).float()  # length = num_nodes*feat_dim

        # Check for NaN/Inf in features
        if torch.isnan(flat).any() or torch.isinf(flat).any():
            flat = torch.nan_to_num(flat, nan=0.0, posinf=1.0, neginf=-1.0)

        if flat.size(0) != self.state_dim:
            padded = torch.zeros(self.state_dim, dtype=torch.float32)
            L = min(flat.size(0), self.state_dim)
            padded[:L] = flat[:L]
        else:
            padded = flat
        # adjacency → dense, pad, float32..
        # if hasattr(data, "edge_attr") and data.edge_attr is not None:
        #     warnings.warn(
        #         "⚠️ Edge attributes found,  but not used in QNN. Adj can be taken as W,"
        #     )
            # adj = to_dense_adj(data.edge_index,edge_attr= data.edge_attr, max_num_nodes=data.num_nodes)[0].float()

        adj = to_dense_adj(data.edge_index, max_num_nodes=data.num_nodes)[0].float()
        padA = torch.zeros(self.max_nodes, self.max_nodes, dtype=torch.float32)
        padA[: data.num_nodes, : data.num_nodes] = adj

        pm = self.compute_qubit_connections(padA)

        # label → long for CrossEntropy
        label = data.y.long().squeeze()
        return padded, pm, label

    def preprocess_dataset(self):
        triplets = [self.preprocess_graph(d) for d in self.dataset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)

    # Add method to process subsets
    def preprocess_subset(self, subset):
        triplets = [self.preprocess_graph(d) for d in subset]
        feats, phases, labs = zip(*triplets)
        return torch.stack(feats), torch.stack(phases), torch.stack(labs)


def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for feats, phases, labs in loader:
            feats, phases, labs = feats.to(device), phases.to(device), labs.to(device)
            logits = model((feats, phases))
            preds = logits.argmax(dim=1)
            correct += (preds == labs).sum().item()
            total += labs.size(0)
    return correct / total


def train_and_eval_fold(
    train_loader,
    val_loader,
    test_loader,
    n_qubits,
    num_classes,
    dataset_name,
    n_layers,
    hidden_dims,
    lr,
    epochs,
    seed,
    dropout_prob=0.25,
    weight_decay=1e-5,
    patience=15,
):
    # reproducibility & device
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model, loss, optimizer, scheduler
    model = QuantumGNN(
        n_qubits=n_qubits,
        n_layers=n_layers,
        hidden_dims=hidden_dims,
        output_dim=num_classes,
        dropout_prob=dropout_prob,
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    print(f"Using {device} for training")
    print(f"Model: {model}")
    print(
        f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )
    print(f"Optimizer: {optimizer}")
    print(f"Loss Function: {criterion}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=patience, factor=0.1, min_lr=1e-7
    )

    best_val_acc = 0.0
    best_val_loss = float("inf")
    best_val_epoch = 0
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, epochs + 1):
        # ——— train ———
        model.train()
        total_loss = 0.0
        total_samples = 0
        for feats, phases, labs in train_loader:
            feats, phases, labs = (
                feats.to(device),
                phases.to(device),
                labs.to(device),
            )
            optimizer.zero_grad()
            logits = model((feats, phases))
            loss = criterion(logits, labs)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item() * labs.size(0)
            total_samples += labs.size(0)

        train_loss = total_loss / total_samples

        # ——— validate ———
        val_acc = evaluate(model, val_loader, device)
        scheduler.step(val_acc)

        # ——— early stopping bookkeeping ———
        if (val_acc > best_val_acc) or (
            val_acc == best_val_acc and train_loss < best_val_loss
        ):
            best_val_loss = train_loss
            best_val_acc = val_acc
            best_val_epoch = epoch
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stop @ epoch {epoch} | Best val_acc={best_val_acc:.4f}")
                break

        # optional progress print
        # if epoch % 10 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]["lr"]
        print(
            f"[{dataset_name}] Epoch {epoch:03d} | "
            f"Train Loss {train_loss:.4f} | Val Acc {val_acc:.4f} | LR {lr_now:.1e}"
            f" [Best Val Acc: {best_val_acc:.4f} @ Epoch {best_val_epoch}]"
        )

    # ——— test ———
    # restore best weights
    model.load_state_dict(best_state)
    test_acc = evaluate(model, test_loader, device)
    print(f"[{dataset_name}] Fold Test Acc: {test_acc:.4f}\n")
    return test_acc


# ========================
# Cross-Validation Function
# ========================

# assume GraphPreprocessor, QuantumGNN, cross_validate_model,
# train_and_eval_fold, evaluate are already defined/imported above


def cross_validate_model(
    dataset_name="MUTAG",
    n_splits=10,
    val_ratio=0.1,
    n_layers=2,
    hidden_dims=[32, 16],
    batch_size=16,
    lr=1e-3,
    epochs=200,
    seed=42,
):
    torch.manual_seed(seed)
    np.random.seed(seed)
    # if dataset_name == "MNISTSuperpixels":
    #     dataset = MNISTSuperpixels(root="data/MNISTSuperpixels", transform=None)
    # elif dataset_name in ("ESOL", "FreeSolv", "Lipo", "PCBA", "MUV",
    #                       "HIV", "BACE", "BBBP", "Tox21", "ToxCast",
    #                       "SIDER", "ClinTox"):
    #     dataset = MoleculeNet(root="data/MoleculeNet", name=dataset_name)
    # else:
    #
    dataset = TUDataset(
        root="data/TUDataset",
        name=dataset_name,
        use_node_attr=True,  # use_edge_attr=False,  # edge attributes not used in this implementation
    )
    # get a numpy array of all graph labels
    labels = dataset.y.cpu().numpy()  # → shape: [num_graphs]

    # build an index array to split on
    idx = np.arange(len(dataset))  # → [0,1,2,…,num_graphs-1]

    skf_outer = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    fold_accs = []

    for fold, (train_val_idx, test_idx) in enumerate(
        skf_outer.split(idx, labels), start=1
    ):
        # carve out small validation set from train_val
        tv_labels = labels[train_val_idx]
        train_idx, val_idx = train_test_split(
            train_val_idx,
            test_size=int(len(train_val_idx) * val_ratio),
            stratify=tv_labels,
            random_state=seed,
        )

        # build subsets
        train_ds = dataset[train_idx.tolist()]
        val_ds = dataset[val_idx.tolist()]
        test_ds = dataset[test_idx.tolist()]

        # preprocess graphs
        pre = GraphPreprocessor(dataset)
        print(f"number of qubits {pre.n_qubits}")
        print(f"number of nodes {pre.max_nodes}")
        print(f"number of features {pre.feature_dim}")
        train_feats, train_phases, train_labs = pre.preprocess_subset(train_ds)
        val_feats, val_phases, val_labs = pre.preprocess_subset(val_ds)
        test_feats, test_phases, test_labs = pre.preprocess_subset(test_ds)
        print(f"train_feats shape: {train_feats.shape}")
        print(f"train_phases shape: {train_phases.shape}")
        print(f"train_labs shape: {train_labs.shape}")
        # data loaders
        train_loader = DataLoader(
            TensorDataset(train_feats, train_phases, train_labs),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(val_feats, val_phases, val_labs),
            batch_size=batch_size,
            shuffle=False,
        )
        test_loader = DataLoader(
            TensorDataset(test_feats, test_phases, test_labs),
            batch_size=batch_size,
            shuffle=False,
        )

        # train & evaluate this fold
        test_acc = train_and_eval_fold(
            train_loader=train_loader,
            val_loader=val_loader,
            test_loader=test_loader,
            n_qubits=pre.n_qubits,
            num_classes=dataset.num_classes,
            dataset_name=dataset_name,
            n_layers=n_layers,
            hidden_dims=hidden_dims,
            lr=lr,
            epochs=epochs,
            seed=seed,
        )
        fold_accs.append(test_acc)

    mean_acc = np.mean(fold_accs)
    std_acc = np.std(fold_accs)
    print(f"\n=== Cross-Validation Results for {dataset_name} ===")
    print(f"Per-fold Accuracies: {fold_accs}")
    print(f"Mean Test Acc: {mean_acc:.4f} ± {std_acc:.4f}")
    return fold_accs


if __name__ == "__main__":
    # Configuration
    config = {
        "dataset_name": "MUTAG",  # Choose from MUTAG, COX2, DHFR, PTC_MR, PTC_FM
        "n_layers": 4,  # Number of quantum layers
        "hidden_dims": [32, 16],  # Hidden dimensions for classical head
        # "hidden_dims": [128, 64],  # Hidden dimensions for classical head
        # "hidden_dims": [256, 128],  # Hidden dimensions for classical head
        "batch_size": 16,
        "lr": 0.01,
        "n_splits": 10,
        "val_ratio": 0.1,
        "epochs": 50,
        "seed": 42,
    }
    print(config)
    # Run CV
    fold_accuracies = cross_validate_model(**config)
# Out:
# {'dataset_name': 'MUTAG', 'n_layers': 4, 'hidden_dims': [32, 16], 'batch_size': 16, 'lr': 0.01, 'n_splits': 10, 'val_ratio': 0.1, 'epochs': 50, 'seed': 42}
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.6108 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4662 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.3794 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.4200 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3246 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3518 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.3132 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 008 | Train Loss 0.2733 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 009 | Train Loss 0.2690 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 010 | Train Loss 0.2430 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 011 | Train Loss 0.2252 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 11]
# [MUTAG] Epoch 012 | Train Loss 0.2044 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 12]
# [MUTAG] Epoch 013 | Train Loss 0.1899 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 13]
# [MUTAG] Epoch 014 | Train Loss 0.2119 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 13]
# [MUTAG] Epoch 015 | Train Loss 0.1984 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 15]
# [MUTAG] Epoch 016 | Train Loss 0.1778 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 017 | Train Loss 0.2910 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 018 | Train Loss 0.2139 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 019 | Train Loss 0.2232 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 020 | Train Loss 0.1902 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 021 | Train Loss 0.1706 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 022 | Train Loss 0.2400 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 023 | Train Loss 0.1979 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 024 | Train Loss 0.1912 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 025 | Train Loss 0.3044 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 17]
# [MUTAG] Epoch 026 | Train Loss 0.1422 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 027 | Train Loss 0.1831 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 028 | Train Loss 0.2070 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 029 | Train Loss 0.1589 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 030 | Train Loss 0.3356 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 031 | Train Loss 0.1805 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 032 | Train Loss 0.1566 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 033 | Train Loss 0.2377 | Val Acc 0.8750 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 034 | Train Loss 0.1680 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 035 | Train Loss 0.1461 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 036 | Train Loss 0.1411 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 037 | Train Loss 0.1701 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 038 | Train Loss 0.1947 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 039 | Train Loss 0.3125 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 040 | Train Loss 0.1273 | Val Acc 0.9375 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# Early stop @ epoch 41 | Best val_acc=1.0000
# [MUTAG] Fold Test Acc: 0.9474
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5613 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.3949 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.3398 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.3565 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 3]
# [MUTAG] Epoch 005 | Train Loss 0.2784 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.2833 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.2062 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 008 | Train Loss 0.1879 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 009 | Train Loss 0.1810 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 010 | Train Loss 0.1765 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 011 | Train Loss 0.1966 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 012 | Train Loss 0.1808 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 12]
# [MUTAG] Epoch 013 | Train Loss 0.1457 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 13]
# [MUTAG] Epoch 014 | Train Loss 0.1447 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 13]
# [MUTAG] Epoch 015 | Train Loss 0.1415 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 15]
# [MUTAG] Epoch 016 | Train Loss 0.1402 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 15]
# [MUTAG] Epoch 017 | Train Loss 0.1944 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 15]
# [MUTAG] Epoch 018 | Train Loss 0.1251 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 019 | Train Loss 0.1291 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 020 | Train Loss 0.1698 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 021 | Train Loss 0.1117 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 022 | Train Loss 0.2130 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 023 | Train Loss 0.1532 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 024 | Train Loss 0.1747 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 025 | Train Loss 0.1717 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 026 | Train Loss 0.1162 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 027 | Train Loss 0.2178 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 028 | Train Loss 0.1461 | Val Acc 0.8750 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 029 | Train Loss 0.1569 | Val Acc 0.8750 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 030 | Train Loss 0.3006 | Val Acc 0.8750 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 031 | Train Loss 0.1347 | Val Acc 0.8750 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 18]
# [MUTAG] Epoch 032 | Train Loss 0.1058 | Val Acc 0.8750 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 18]
# Early stop @ epoch 33 | Best val_acc=0.9375
# [MUTAG] Fold Test Acc: 0.7368
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5704 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4310 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.3654 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 2]
# [MUTAG] Epoch 004 | Train Loss 0.3953 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.2613 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [MUTAG] Epoch 006 | Train Loss 0.2774 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [MUTAG] Epoch 007 | Train Loss 0.2520 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [MUTAG] Epoch 008 | Train Loss 0.2080 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 8]
# [MUTAG] Epoch 009 | Train Loss 0.2209 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 010 | Train Loss 0.1586 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 011 | Train Loss 0.1893 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 012 | Train Loss 0.2050 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 013 | Train Loss 0.1600 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 014 | Train Loss 0.1546 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 015 | Train Loss 0.1798 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 016 | Train Loss 0.1379 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 017 | Train Loss 0.1796 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 018 | Train Loss 0.1486 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 019 | Train Loss 0.1692 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 020 | Train Loss 0.1834 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 021 | Train Loss 0.1298 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 022 | Train Loss 0.2070 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 023 | Train Loss 0.1698 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 9]
# [MUTAG] Epoch 024 | Train Loss 0.1394 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 025 | Train Loss 0.1740 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 026 | Train Loss 0.1249 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 027 | Train Loss 0.1530 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 028 | Train Loss 0.1381 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 029 | Train Loss 0.1174 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 030 | Train Loss 0.2790 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 031 | Train Loss 0.1330 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 032 | Train Loss 0.1202 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 033 | Train Loss 0.1495 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 034 | Train Loss 0.1196 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 035 | Train Loss 0.1475 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 036 | Train Loss 0.1251 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 037 | Train Loss 0.1360 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# [MUTAG] Epoch 038 | Train Loss 0.1853 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8750 @ Epoch 24]
# Early stop @ epoch 39 | Best val_acc=0.8750
# [MUTAG] Fold Test Acc: 0.8421
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5841 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4681 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.4196 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.4137 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3434 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3305 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.2740 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 5]
# [MUTAG] Epoch 008 | Train Loss 0.2445 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 8]
# [MUTAG] Epoch 009 | Train Loss 0.2469 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 8]
# [MUTAG] Epoch 010 | Train Loss 0.2381 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 8]
# [MUTAG] Epoch 011 | Train Loss 0.2571 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 8]
# [MUTAG] Epoch 012 | Train Loss 0.2346 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 8]
# [MUTAG] Epoch 013 | Train Loss 0.1501 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 014 | Train Loss 0.1760 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 015 | Train Loss 0.1653 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 016 | Train Loss 0.1693 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 017 | Train Loss 0.1903 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 018 | Train Loss 0.1675 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 019 | Train Loss 0.1971 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 020 | Train Loss 0.1704 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 021 | Train Loss 0.2209 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 022 | Train Loss 0.1562 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 023 | Train Loss 0.1714 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 024 | Train Loss 0.1770 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 025 | Train Loss 0.1604 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 13]
# [MUTAG] Epoch 026 | Train Loss 0.1232 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 26]
# [MUTAG] Epoch 027 | Train Loss 0.1534 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 26]
# [MUTAG] Epoch 028 | Train Loss 0.1480 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 26]
# [MUTAG] Epoch 029 | Train Loss 0.1703 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 26]
# [MUTAG] Epoch 030 | Train Loss 0.3057 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 26]
# [MUTAG] Epoch 031 | Train Loss 0.1185 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 31]
# [MUTAG] Epoch 032 | Train Loss 0.1245 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 31]
# [MUTAG] Epoch 033 | Train Loss 0.1758 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 31]
# [MUTAG] Epoch 034 | Train Loss 0.1240 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 31]
# [MUTAG] Epoch 035 | Train Loss 0.1183 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.8125 @ Epoch 35]
# [MUTAG] Epoch 036 | Train Loss 0.1544 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 35]
# [MUTAG] Epoch 037 | Train Loss 0.1225 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 35]
# [MUTAG] Epoch 038 | Train Loss 0.1852 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 35]
# [MUTAG] Epoch 039 | Train Loss 0.2358 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 35]
# [MUTAG] Epoch 040 | Train Loss 0.1164 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 40]
# [MUTAG] Epoch 041 | Train Loss 0.1138 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 41]
# [MUTAG] Epoch 042 | Train Loss 0.1503 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 41]
# [MUTAG] Epoch 043 | Train Loss 0.1787 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 41]
# [MUTAG] Epoch 044 | Train Loss 0.0984 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Epoch 045 | Train Loss 0.1103 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Epoch 046 | Train Loss 0.1133 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Epoch 047 | Train Loss 0.1286 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Epoch 048 | Train Loss 0.2239 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Epoch 049 | Train Loss 0.1309 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Epoch 050 | Train Loss 0.1582 | Val Acc 0.8125 | LR 1.0e-04 [Best Val Acc: 0.8125 @ Epoch 44]
# [MUTAG] Fold Test Acc: 0.8421
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5556 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4530 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.3941 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.4090 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3329 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3364 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 6]
# [MUTAG] Epoch 007 | Train Loss 0.2685 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 7]
# [MUTAG] Epoch 008 | Train Loss 0.2263 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 8]
# [MUTAG] Epoch 009 | Train Loss 0.3127 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 8]
# [MUTAG] Epoch 010 | Train Loss 0.2633 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 10]
# [MUTAG] Epoch 011 | Train Loss 0.2377 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 11]
# [MUTAG] Epoch 012 | Train Loss 0.1936 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 11]
# [MUTAG] Epoch 013 | Train Loss 0.1857 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 11]
# [MUTAG] Epoch 014 | Train Loss 0.1617 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 11]
# [MUTAG] Epoch 015 | Train Loss 0.2109 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 15]
# [MUTAG] Epoch 016 | Train Loss 0.1993 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 16]
# [MUTAG] Epoch 017 | Train Loss 0.2005 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 16]
# [MUTAG] Epoch 018 | Train Loss 0.1588 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 16]
# [MUTAG] Epoch 019 | Train Loss 0.1632 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 16]
# [MUTAG] Epoch 020 | Train Loss 0.1630 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 16]
# [MUTAG] Epoch 021 | Train Loss 0.1538 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 21]
# [MUTAG] Epoch 022 | Train Loss 0.2039 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 21]
# [MUTAG] Epoch 023 | Train Loss 0.1766 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 21]
# [MUTAG] Epoch 024 | Train Loss 0.1786 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 21]
# [MUTAG] Epoch 025 | Train Loss 0.3692 | Val Acc 1.0000 | LR 1.0e-02 [Best Val Acc: 1.0000 @ Epoch 21]
# [MUTAG] Epoch 026 | Train Loss 0.1375 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 027 | Train Loss 0.1438 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 26]
# [MUTAG] Epoch 028 | Train Loss 0.1374 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 28]
# [MUTAG] Epoch 029 | Train Loss 0.1205 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 29]
# [MUTAG] Epoch 030 | Train Loss 0.3269 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 29]
# [MUTAG] Epoch 031 | Train Loss 0.1323 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 29]
# [MUTAG] Epoch 032 | Train Loss 0.1013 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 033 | Train Loss 0.1405 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 034 | Train Loss 0.1377 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 035 | Train Loss 0.1211 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 036 | Train Loss 0.1573 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 037 | Train Loss 0.1067 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 038 | Train Loss 0.1454 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 039 | Train Loss 0.2835 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 040 | Train Loss 0.1067 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 041 | Train Loss 0.1028 | Val Acc 1.0000 | LR 1.0e-03 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 042 | Train Loss 0.1309 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 043 | Train Loss 0.1300 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 044 | Train Loss 0.1067 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 045 | Train Loss 0.1089 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 046 | Train Loss 0.1062 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 32]
# [MUTAG] Epoch 047 | Train Loss 0.0968 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 47]
# [MUTAG] Epoch 048 | Train Loss 0.2052 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 47]
# [MUTAG] Epoch 049 | Train Loss 0.1060 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 47]
# [MUTAG] Epoch 050 | Train Loss 0.1424 | Val Acc 1.0000 | LR 1.0e-04 [Best Val Acc: 1.0000 @ Epoch 47]
# [MUTAG] Fold Test Acc: 0.6842
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5892 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4201 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.4188 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8125 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.3670 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3457 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3750 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.2573 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 008 | Train Loss 0.2648 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 009 | Train Loss 0.2776 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 010 | Train Loss 0.2526 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 011 | Train Loss 0.2159 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 8]
# [MUTAG] Epoch 012 | Train Loss 0.2074 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 12]
# [MUTAG] Epoch 013 | Train Loss 0.2404 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 12]
# [MUTAG] Epoch 014 | Train Loss 0.1394 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 14]
# [MUTAG] Epoch 015 | Train Loss 0.2678 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 14]
# [MUTAG] Epoch 016 | Train Loss 0.2124 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 017 | Train Loss 0.1791 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 018 | Train Loss 0.2009 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 019 | Train Loss 0.2058 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 020 | Train Loss 0.1222 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 021 | Train Loss 0.1957 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 022 | Train Loss 0.2727 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 023 | Train Loss 0.1675 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 024 | Train Loss 0.1593 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 025 | Train Loss 0.2400 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 026 | Train Loss 0.2074 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 027 | Train Loss 0.2770 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 028 | Train Loss 0.1621 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 029 | Train Loss 0.1563 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# [MUTAG] Epoch 030 | Train Loss 0.3424 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 16]
# Early stop @ epoch 31 | Best val_acc=0.9375
# [MUTAG] Fold Test Acc: 0.8421
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5845 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4224 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.4284 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 2]
# [MUTAG] Epoch 004 | Train Loss 0.3916 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3380 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 006 | Train Loss 0.3087 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 007 | Train Loss 0.2827 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 008 | Train Loss 0.2481 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 009 | Train Loss 0.2968 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 010 | Train Loss 0.2227 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 011 | Train Loss 0.2516 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 012 | Train Loss 0.1616 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 013 | Train Loss 0.2390 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 014 | Train Loss 0.2336 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 015 | Train Loss 0.2640 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 016 | Train Loss 0.1992 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 017 | Train Loss 0.2159 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# [MUTAG] Epoch 018 | Train Loss 0.1851 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 4]
# Early stop @ epoch 19 | Best val_acc=0.9375
# [MUTAG] Fold Test Acc: 0.8421
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5612 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.6875 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.3949 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.3934 | Val Acc 0.6875 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 2]
# [MUTAG] Epoch 004 | Train Loss 0.3644 | Val Acc 0.7500 | LR 1.0e-02 [Best Val Acc: 0.7500 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3271 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3422 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.8750 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.2565 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 7]
# [MUTAG] Epoch 008 | Train Loss 0.2286 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 7]
# [MUTAG] Epoch 009 | Train Loss 0.2152 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 7]
# [MUTAG] Epoch 010 | Train Loss 0.1950 | Val Acc 0.9375 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 011 | Train Loss 0.2144 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 012 | Train Loss 0.1993 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 013 | Train Loss 0.1825 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 014 | Train Loss 0.1634 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 015 | Train Loss 0.2254 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 016 | Train Loss 0.1841 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 017 | Train Loss 0.1749 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 018 | Train Loss 0.1427 | Val Acc 0.8750 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 019 | Train Loss 0.2002 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 020 | Train Loss 0.1430 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 021 | Train Loss 0.1745 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 022 | Train Loss 0.1786 | Val Acc 0.8125 | LR 1.0e-02 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 023 | Train Loss 0.1799 | Val Acc 0.7500 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 10]
# [MUTAG] Epoch 024 | Train Loss 0.1410 | Val Acc 0.8125 | LR 1.0e-03 [Best Val Acc: 0.9375 @ Epoch 10]
# Early stop @ epoch 25 | Best val_acc=0.9375
# [MUTAG] Fold Test Acc: 0.8947
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.6080 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.6471 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4512 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.6471 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.4240 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.6471 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.3803 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.7647 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.2864 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3055 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.2630 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 7]
# [MUTAG] Epoch 008 | Train Loss 0.2652 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 7]
# [MUTAG] Epoch 009 | Train Loss 0.2187 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 9]
# [MUTAG] Epoch 010 | Train Loss 0.2075 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 9]
# [MUTAG] Epoch 011 | Train Loss 0.2634 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 9]
# [MUTAG] Epoch 012 | Train Loss 0.1710 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 12]
# [MUTAG] Epoch 013 | Train Loss 0.1886 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 12]
# [MUTAG] Epoch 014 | Train Loss 0.1742 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 12]
# [MUTAG] Epoch 015 | Train Loss 0.2086 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 12]
# [MUTAG] Epoch 016 | Train Loss 0.1608 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 12]
# [MUTAG] Epoch 017 | Train Loss 0.3246 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 12]
# [MUTAG] Epoch 018 | Train Loss 0.1665 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 18]
# [MUTAG] Epoch 019 | Train Loss 0.1936 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 18]
# [MUTAG] Epoch 020 | Train Loss 0.1583 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 021 | Train Loss 0.1675 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 022 | Train Loss 0.1923 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 023 | Train Loss 0.1821 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 024 | Train Loss 0.1786 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 025 | Train Loss 0.3656 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 026 | Train Loss 0.1613 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 027 | Train Loss 0.2357 | Val Acc 0.9412 | LR 1.0e-02 [Best Val Acc: 0.9412 @ Epoch 20]
# [MUTAG] Epoch 028 | Train Loss 0.1473 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 28]
# [MUTAG] Epoch 029 | Train Loss 0.2373 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 28]
# [MUTAG] Epoch 030 | Train Loss 0.3594 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 28]
# [MUTAG] Epoch 031 | Train Loss 0.2326 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 28]
# [MUTAG] Epoch 032 | Train Loss 0.1379 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 32]
# [MUTAG] Epoch 033 | Train Loss 0.1600 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 32]
# [MUTAG] Epoch 034 | Train Loss 0.1396 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 32]
# [MUTAG] Epoch 035 | Train Loss 0.1465 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 32]
# [MUTAG] Epoch 036 | Train Loss 0.1217 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 36]
# [MUTAG] Epoch 037 | Train Loss 0.1366 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 36]
# [MUTAG] Epoch 038 | Train Loss 0.1729 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 36]
# [MUTAG] Epoch 039 | Train Loss 0.3366 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 36]
# [MUTAG] Epoch 040 | Train Loss 0.1210 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 40]
# [MUTAG] Epoch 041 | Train Loss 0.1387 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 40]
# [MUTAG] Epoch 042 | Train Loss 0.1871 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 40]
# [MUTAG] Epoch 043 | Train Loss 0.1607 | Val Acc 0.9412 | LR 1.0e-03 [Best Val Acc: 0.9412 @ Epoch 40]
# [MUTAG] Epoch 044 | Train Loss 0.1144 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Epoch 045 | Train Loss 0.1179 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Epoch 046 | Train Loss 0.1200 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Epoch 047 | Train Loss 0.1486 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Epoch 048 | Train Loss 0.2317 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Epoch 049 | Train Loss 0.1334 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Epoch 050 | Train Loss 0.1580 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 44]
# [MUTAG] Fold Test Acc: 0.9444
#
# number of qubits 8
# number of nodes 28
# number of features 7
# train_feats shape: torch.Size([153, 256])
# train_phases shape: torch.Size([153, 8, 8])
# train_labs shape: torch.Size([153])
# Using cpu for training
# Model: QuantumGNN(
#   (quantum_circuit): QuantumCircuit()
#   (classical_net): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Number of parameters: 1202
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 1e-05
# )
# Loss Function: CrossEntropyLoss()
# /home/adaskin/anaconda3/lib/python3.12/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# [MUTAG] Epoch 001 | Train Loss 0.5761 | Val Acc 0.6471 | LR 1.0e-02 [Best Val Acc: 0.6471 @ Epoch 1]
# [MUTAG] Epoch 002 | Train Loss 0.4191 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 2]
# [MUTAG] Epoch 003 | Train Loss 0.3951 | Val Acc 0.7059 | LR 1.0e-02 [Best Val Acc: 0.7059 @ Epoch 3]
# [MUTAG] Epoch 004 | Train Loss 0.4416 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 4]
# [MUTAG] Epoch 005 | Train Loss 0.3158 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 5]
# [MUTAG] Epoch 006 | Train Loss 0.3562 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8235 @ Epoch 5]
# [MUTAG] Epoch 007 | Train Loss 0.2980 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 7]
# [MUTAG] Epoch 008 | Train Loss 0.2645 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 7]
# [MUTAG] Epoch 009 | Train Loss 0.2968 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 7]
# [MUTAG] Epoch 010 | Train Loss 0.2679 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 10]
# [MUTAG] Epoch 011 | Train Loss 0.2533 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 10]
# [MUTAG] Epoch 012 | Train Loss 0.2202 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 10]
# [MUTAG] Epoch 013 | Train Loss 0.2200 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 10]
# [MUTAG] Epoch 014 | Train Loss 0.2061 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 10]
# [MUTAG] Epoch 015 | Train Loss 0.2388 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 15]
# [MUTAG] Epoch 016 | Train Loss 0.1752 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 017 | Train Loss 0.2731 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 018 | Train Loss 0.2180 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 019 | Train Loss 0.2105 | Val Acc 0.7647 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 020 | Train Loss 0.2086 | Val Acc 0.8235 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 021 | Train Loss 0.2425 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 022 | Train Loss 0.2341 | Val Acc 0.8824 | LR 1.0e-02 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 023 | Train Loss 0.2044 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 024 | Train Loss 0.1630 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 025 | Train Loss 0.2268 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 16]
# [MUTAG] Epoch 026 | Train Loss 0.1520 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 027 | Train Loss 0.1571 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 028 | Train Loss 0.1691 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 029 | Train Loss 0.1766 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 030 | Train Loss 0.2786 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 031 | Train Loss 0.1815 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 032 | Train Loss 0.1566 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 033 | Train Loss 0.1738 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 034 | Train Loss 0.1597 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 035 | Train Loss 0.1525 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 036 | Train Loss 0.2028 | Val Acc 0.8235 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 037 | Train Loss 0.1679 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 038 | Train Loss 0.1953 | Val Acc 0.8824 | LR 1.0e-03 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 039 | Train Loss 0.2743 | Val Acc 0.8235 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 26]
# [MUTAG] Epoch 040 | Train Loss 0.1303 | Val Acc 0.8824 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 041 | Train Loss 0.1372 | Val Acc 0.8235 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 042 | Train Loss 0.1594 | Val Acc 0.8235 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 043 | Train Loss 0.1699 | Val Acc 0.8235 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 044 | Train Loss 0.1120 | Val Acc 0.8235 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 045 | Train Loss 0.1328 | Val Acc 0.8235 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 046 | Train Loss 0.1469 | Val Acc 0.8824 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 40]
# [MUTAG] Epoch 047 | Train Loss 0.1206 | Val Acc 0.8824 | LR 1.0e-04 [Best Val Acc: 0.8824 @ Epoch 47]
# [MUTAG] Epoch 048 | Train Loss 0.2115 | Val Acc 0.9412 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 48]
# [MUTAG] Epoch 049 | Train Loss 0.1642 | Val Acc 0.8824 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 48]
# [MUTAG] Epoch 050 | Train Loss 0.1489 | Val Acc 0.8824 | LR 1.0e-04 [Best Val Acc: 0.9412 @ Epoch 48]
# [MUTAG] Fold Test Acc: 0.8889
#
#
# === Cross-Validation Results for MUTAG ===
# Per-fold Accuracies: [0.9473684210526315, 0.7368421052631579, 0.8421052631578947, 0.8421052631578947, 0.6842105263157895, 0.8421052631578947, 0.8421052631578947, 0.8947368421052632, 0.9444444444444444, 0.8888888888888888]
# Mean Test Acc: 0.8465 ± 0.0790
